# %%
from google.colab import drive
from google.colab.patches import cv2_imshow
import os
import cv2
import random
import shutil
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tqdm.auto import tqdm
import csv

# %%
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
shutil.rmtree("/content/indexes", ignore_errors=True)

# %%
os.makedirs("/content/indexes")
os.makedirs("/content/indexes/fine_tuning")
os.makedirs("/content/indexes/fine_tuning/tree")
os.makedirs("/content/indexes/fine_tuning/forest")
os.makedirs("/content/indexes/feature_extraction")
os.makedirs("/content/indexes/feature_extraction/tree")
os.makedirs("/content/indexes/feature_extraction/forest")

# %% [markdown]
# # Tree

# %%
# %cp --verbose -R "/content/drive/MyDrive/CV_Birds/indexes/fine_tuning/tree/cosine" "/content/indexes/fine_tuning/tree/cosine"

# %%
len(os.listdir('/content/drive/MyDrive/CV_Birds/indexes/fine_tuning/tree/euclidean'))
# Out:
# 9821

# %%
# %cp --verbose -R "/content/drive/MyDrive/CV_Birds/indexes/fine_tuning/tree/euclidean" "/content/indexes/fine_tuning/tree/euclidean"

# %%
# %cp --verbose -R "/content/drive/MyDrive/CV_Birds/indexes/feature_extraction/tree/cosine" "/content/indexes/feature_extraction/tree/cosine"

# %%
# %cp --verbose -R "/content/drive/MyDrive/CV_Birds/indexes/feature_extraction/tree/euclidean" "/content/indexes/feature_extraction/tree/euclidean"

# %% [markdown]
# # Forest

# %%
len(os.listdir('/content/drive/MyDrive/CV_Birds/indexes/fine_tuning/forest/cosine'))
# Out:
# 34846

# %%
# %cp --verbose -R "/content/drive/MyDrive/CV_Birds/indexes/fine_tuning/forest/cosine" "/content/indexes/fine_tuning/forest/cosine"

# %%
# %cp --verbose -R "/content/drive/MyDrive/CV_Birds/indexes/fine_tuning/forest/euclidean" "/content/indexes/fine_tuning/forest/euclidean"

# %%
# %cp --verbose -R "/content/drive/MyDrive/CV_Birds/indexes/feature_extraction/forest/cosine" "/content/indexes/feature_extraction/forest/cosine"

# %%
# %cp --verbose -R "/content/drive/MyDrive/CV_Birds/indexes/feature_extraction/forest/euclidean" "/content/indexes/feature_extraction/forest/euclidean"

# %%
# !zip -r "/content/drive/MyDrive/CV_Birds/FinalIndexes.zip" "indexes"
