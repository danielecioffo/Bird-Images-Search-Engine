# %% [markdown]
# # Test with Feature extraction, no distractor, simple tree, 5 random pivots, cosine similarity

# %% [markdown]
# ## Import libraries

# %%
from google.colab import drive
from pathlib import Path
from matplotlib import pyplot as plt 
import pandas as pd
import numpy as np
import os
import csv
import concurrent.futures
import time

# %% [markdown]
# ## Utility functions

# %% [markdown]
# ### Create annot and load descriptors

# %%
def create_annot(path):
  image_list = list(Path(path).glob('*/*.jpg'))
  # the identity name is in the path (the name of the parent directory)
  names_list = [i.parent.name for i in image_list]  # get the identity of each image
  # keep info in a pandas DataFrame
  annot = pd.DataFrame({'identity': names_list, 'image_path': image_list})
  return annot

def concatenate_annots(list_of_paths):
  concat_annot = pd.DataFrame()
  with concurrent.futures.ThreadPoolExecutor() as executor:
    annots = [executor.submit(create_annot, path) for path in list_of_paths]
    for annot in annots:
      new_annot = annot.result()
      concat_annot = concat_annot.append(new_annot, ignore_index = True)
    return concat_annot

# %%
def load_descriptors(path):
  with open(path, 'rb') as file:
    return np.load(file)

def concatenate_descriptors(list_of_paths):
  concat_descriptors = None
  with concurrent.futures.ThreadPoolExecutor() as executor:
    descriptors = [executor.submit(load_descriptors, path) for path in list_of_paths]
    for descriptor in descriptors:
      new_descriptor = descriptor.result()
      if concat_descriptors is None:
        concat_descriptors = new_descriptor
      else:
        concat_descriptors = np.concatenate([concat_descriptors, new_descriptor])
    return concat_descriptors

# %% [markdown]
# ### Create pivots

# %%
def generate_pivots(descriptors, n, strategy="rnd"):
  pivots_id = np.random.choice(np.arange(len(descriptors)), size=n)
  return descriptors[pivots_id]

def generate_list_of_pivots(descriptors, t, n, strategy="rnd"):
  list_of_pivots = []
  with concurrent.futures.ThreadPoolExecutor() as executor:
    pivots = [executor.submit(generate_pivots, descriptors, n, strategy) for i in range(t)]
    for pivot in concurrent.futures.as_completed(pivots):
      new_pivot = pivot.result()
      list_of_pivots.append(new_pivot)
    return list_of_pivots

# %% [markdown]
# ### Save test results

# %%
def save_results(dir, file_name, results):
  with open(os.path.join(dir, file_name +".csv"), 'w') as f:
    writer = csv.writer(f)
    # write the header
    writer.writerow(["CLASS", "AP", "QUERY TIME"])
    # write the data
    for r in results:
      writer.writerow(r)

# %% [markdown]
# ## Test Performance

# %%
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Create annot and load descriptors for the database

# %%
db_annot = create_annot('/content/drive/MyDrive/CV_Birds/train')
db_annot
# Out:
#                       identity                                         image_path
# 0        AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/train/AFRICAN ...
# 1        AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/train/AFRICAN ...
# 2        AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/train/AFRICAN ...
# 3        AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/train/AFRICAN ...
# 4        AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/train/AFRICAN ...
# ...                        ...                                                ...
# 47327  YELLOW HEADED BLACKBIRD  /content/drive/MyDrive/CV_Birds/train/YELLOW H...
# 47328  YELLOW HEADED BLACKBIRD  /content/drive/MyDrive/CV_Birds/train/YELLOW H...
# 47329  YELLOW HEADED BLACKBIRD  /content/drive/MyDrive/CV_Birds/train/YELLOW H...
# 47330  YELLOW HEADED BLACKBIRD  /content/drive/MyDrive/CV_Birds/train/YELLOW H...
# 47331  YELLOW HEADED BLACKBIRD  /content/drive/MyDrive/CV_Birds/train/YELLOW H...
#
# [47332 rows x 2 columns]

# %%
db_descriptors = load_descriptors('/content/drive/MyDrive/CV_Birds/features/training/ResNet50v2/resnet_fe_features.npy')
db_descriptors.shape
# Out:
# (47332, 2048)

# %% [markdown]
# ### Create annot and load descriptors for the test set

# %%
query_annot = create_annot('/content/drive/MyDrive/CV_Birds/test')
query_annot
# Out:
#                      identity                                         image_path
# 0       AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/test/AFRICAN C...
# 1       AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/test/AFRICAN C...
# 2       AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/test/AFRICAN C...
# 3       AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/test/AFRICAN C...
# 4       AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/test/AFRICAN C...
# ...                       ...                                                ...
# 1620  YELLOW HEADED BLACKBIRD  /content/drive/MyDrive/CV_Birds/test/YELLOW HE...
# 1621  YELLOW HEADED BLACKBIRD  /content/drive/MyDrive/CV_Birds/test/YELLOW HE...
# 1622  YELLOW HEADED BLACKBIRD  /content/drive/MyDrive/CV_Birds/test/YELLOW HE...
# 1623  YELLOW HEADED BLACKBIRD  /content/drive/MyDrive/CV_Birds/test/YELLOW HE...
# 1624  YELLOW HEADED BLACKBIRD  /content/drive/MyDrive/CV_Birds/test/YELLOW HE...
#
# [1625 rows x 2 columns]

# %%
query_descriptors = load_descriptors('/content/drive/MyDrive/CV_Birds/features/test/ResNet50v2/resnet50_fe_features.npy')
query_descriptors.shape
# Out:
# (1625, 2048)

# %% [markdown]
# To run our tests we select only the first image of each species within the test set. Please note that within the test set we have 5 images per species.

# %%
queries_indexes = [x for x in range(325*5) if x%5 == 0]

# %% [markdown]
# ### Compute mAP

# %%
birds_db = db_annot
counts = birds_db.groupby('identity').count()
print("Minimum number of images per species:", int(counts.min()))
print("Maximum number of images per species:", int(counts.max()))
print("Average number of images:", float(counts.sum()/325))
# Out:
# Minimum number of images per species: 116
# Maximum number of images per species: 249
# Average number of images: 145.63692307692307

# %% [markdown]
# Since at most we have 249 images per species, we use $n=250$.

# %%
n = 250

# %% [markdown]
# The formula for Average Precision is the following:
#
# > $AP@n=\frac{1}{GTP}\sum_{k=1}^{n}P@k×rel@k$
#
# where $GTP$ refers to the total number of ground truth positives, $n$ refers to the total number of images we are interested in, $P@k$ refers to the precision@k and $rel@k$ is a relevance function.
#
# The relevance function is an indicator function which equals 1 if the document at rank $k$ is relevant and equals to 0 otherwise.

# %%
def compute_ap(query_index, retrieved_ids):
  query_identity = query_annot['identity'][query_index]
  print(query_index//5, query_identity)
  GTP = len(db_annot.loc[db_annot['identity'] == query_identity])
  relevant = 0
  precision_summation = 0
  for k, id in enumerate(retrieved_ids):
    if db_annot['identity'][id] == query_identity: # relevant result
      relevant = relevant + 1
      precision_at_k = relevant/(k+1)
      precision_summation = precision_summation + precision_at_k
  return (query_identity, precision_summation/GTP)

# %% [markdown]
# For each query, $Q$, we can calculate a corresponding $AP$. Then, the $mAP$ is simply the mean of all the queries that were made.
# > $mAP = \frac{1}{N}\sum_{i=1}^{N}AP_i$
#
# In our case, $N=325$ (one query per species)

# %%
# !rm -r /content/drive/MyDrive/CV_Birds/performance/feature_extraction/index/FE-no-distr_tree_5nd_cosine/tree_structure/*npy
# !rm -r /content/drive/MyDrive/CV_Birds/performance/feature_extraction/index/FE-no-distr_tree_5nd_cosine/tree_structure/*structure*
# Out:
# rm: cannot remove '/content/drive/MyDrive/CV_Birds/performance/feature_extraction/index/FE-no-distr_tree_5nd_cosine/tree_structure/*npy': No such file or directory
# rm: cannot remove '/content/drive/MyDrive/CV_Birds/performance/feature_extraction/index/FE-no-distr_tree_5nd_cosine/tree_structure/*structure*': No such file or directory

# %%
def get_descriptor_from_id(id_object):
  return db_descriptors[id_object]

# %%
# %cd "/content/drive/MyDrive/CV_Birds/Notebooks/PP-Index"
# %run PPIndex.ipynb
# Out:
# /content/drive/.shortcut-targets-by-id/1rI5YNBuaSlCB__w522WEkHjw-nFuvIo0/CV_Birds/Notebooks/PP-Index

# %% [markdown]
# #### Test performance

# %%
# !rm /content/drive/MyDrive/CV_Birds/performance/feature_extraction/index/FE-no-distr_tree_5rnd_cosine/*
# !rm -r /content/drive/MyDrive/CV_Birds/performance/feature_extraction/index/FE-no-distr_tree_5rnd_cosine/tree_structure/*
# !rm /content/*
# Out:
# rm: cannot remove '/content/drive/MyDrive/CV_Birds/performance/feature_extraction/index/FE-no-distr_tree_5rnd_cosine/tree_structure': Is a directory
# rm: cannot remove '/content/drive/MyDrive/CV_Birds/performance/feature_extraction/index/FE-no-distr_tree_5rnd_cosine/tree_structure/*': No such file or directory
# rm: cannot remove '/content/drive': Is a directory
# rm: cannot remove '/content/sample_data': Is a directory

# %%
rnd_pivots = generate_pivots(db_descriptors, 5, "rnd")
rnd_pp_tree = PrefixTree(rnd_pivots, length=3, distance_metric='cosine', base_directory='/content')
if rnd_pp_tree.is_empty():
  rnd_pp_tree.insert_objects_into_tree(range(len(db_descriptors)))
  rnd_pp_tree.save()
# Out:
# [WARNING]: Tree is still empty
# Inserting objects into tree_structure ...
# --- Insertion into tree tree_structure completed: 57.513 seconds ---

# %%
def rnd_pivots_queries(query_index, n):
  start_time = time.time()
  ids, distances = rnd_pp_tree.find_nearest_neighbors(query_descriptors[query_index], n)
  end_time = time.time()
  ids = ids.tolist()
  return compute_ap(query_index, ids) + (end_time - start_time,)

# %%
aps = []
for query_index in queries_indexes:
  aps.append(rnd_pivots_queries(query_index, n))

 #with concurrent.futures.ThreadPoolExecutor() as executor:
  #average_precisions = [executor.submit(rnd_pivots_queries, query_index, n) for query_index in queries_indexes]
  #for ap in concurrent.futures.as_completed(average_precisions):
   # average_precision = ap.result()
    #aps.append(average_precision)
# Out:
# 0 AFRICAN CROWNED CRANE
# 1 AFRICAN FIREFINCH
# 2 ALBATROSS
# 3 ALEXANDRINE PARAKEET
# 4 AMERICAN AVOCET
# 5 AMERICAN BITTERN
# 6 AMERICAN COOT
# 7 AMERICAN GOLDFINCH
# 8 AMERICAN KESTREL
# 9 AMERICAN PIPIT
# 10 AMERICAN REDSTART
# 11 ANHINGA
# 12 ANNAS HUMMINGBIRD
# 13 ANTBIRD
# 14 ARARIPE MANAKIN
# 15 ASIAN CRESTED IBIS
# 16 BALD EAGLE
# 17 BALD IBIS
# 18 BALI STARLING
# 19 BALTIMORE ORIOLE
# 20 BANANAQUIT
# 21 BANDED BROADBILL
# 22 BANDED PITA
# 23 BAR-TAILED GODWIT
# 24 BARN OWL
# 25 BARN SWALLOW
# 26 BARRED PUFFBIRD
# 27 BAY-BREASTED WARBLER
# 28 BEARDED BARBET
# 29 BEARDED BELLBIRD
# 30 BEARDED REEDLING
# 31 BELTED KINGFISHER
# 32 BIRD OF PARADISE
# 33 BLACK & YELLOW bROADBILL
# 34 BLACK BAZA
# 35 BLACK FRANCOLIN
# 36 BLACK SKIMMER
# 37 BLACK SWAN
# 38 BLACK TAIL CRAKE
# 39 BLACK THROATED BUSHTIT
# 40 BLACK THROATED WARBLER
# 41 BLACK VULTURE
# 42 BLACK-CAPPED CHICKADEE
# 43 BLACK-NECKED GREBE
# 44 BLACK-THROATED SPARROW
# 45 BLACKBURNIAM WARBLER
# 46 BLONDE CRESTED WOODPECKER
# 47 BLUE COAU
# 48 BLUE GROUSE
# 49 BLUE HERON
# 50 BLUE THROATED TOUCANET
# 51 BOBOLINK
# 52 BORNEAN BRISTLEHEAD
# 53 BORNEAN LEAFBIRD
# 54 BORNEAN PHEASANT
# 55 BRANDT CORMARANT
# 56 BROWN CREPPER
# 57 BROWN NOODY
# 58 BROWN THRASHER
# 59 BULWERS PHEASANT
# 60 CACTUS WREN
# 61 CALIFORNIA CONDOR
# 62 CALIFORNIA GULL
# 63 CALIFORNIA QUAIL
# 64 CANARY
# 65 CAPE GLOSSY STARLING
# 66 CAPE MAY WARBLER
# 67 CAPPED HERON
# 68 CAPUCHINBIRD
# 69 CARMINE BEE-EATER
# 70 CASPIAN TERN
# 71 CASSOWARY
# 72 CEDAR WAXWING
# 73 CERULEAN WARBLER
# 74 CHARA DE COLLAR
# 75 CHESTNET BELLIED EUPHONIA
# 76 CHIPPING SPARROW
# 77 CHUKAR PARTRIDGE
# 78 CINNAMON TEAL
# 79 CLARKS NUTCRACKER
# 80 COCK OF THE  ROCK
# 81 COCKATOO
# 82 COLLARED ARACARI
# 83 COMMON FIRECREST
# 84 COMMON GRACKLE
# 85 COMMON HOUSE MARTIN
# 86 COMMON LOON
# 87 COMMON POORWILL
# 88 COMMON STARLING
# 89 COUCHS KINGBIRD
# 90 CRESTED AUKLET
# 91 CRESTED CARACARA
# 92 CRESTED NUTHATCH
# 93 CRIMSON SUNBIRD
# 94 CROW
# 95 CROWNED PIGEON
# 96 CUBAN TODY
# 97 CUBAN TROGON
# 98 CURL CRESTED ARACURI
# 99 D-ARNAUDS BARBET
# 100 DARK EYED JUNCO
# 101 DOUBLE BARRED FINCH
# 102 DOUBLE BRESTED CORMARANT
# 103 DOWNY WOODPECKER
# 104 EASTERN BLUEBIRD
# 105 EASTERN MEADOWLARK
# 106 EASTERN ROSELLA
# 107 EASTERN TOWEE
# 108 ELEGANT TROGON
# 109 ELLIOTS  PHEASANT
# 110 EMPEROR PENGUIN
# 111 EMU
# 112 ENGGANO MYNA
# 113 EURASIAN GOLDEN ORIOLE
# 114 EURASIAN MAGPIE
# 115 EVENING GROSBEAK
# 116 FAIRY BLUEBIRD
# 117 FIRE TAILLED MYZORNIS
# 118 FLAME TANAGER
# 119 FLAMINGO
# 120 FRIGATE
# 121 GAMBELS QUAIL
# 122 GANG GANG COCKATOO
# 123 GILA WOODPECKER
# 124 GILDED FLICKER
# 125 GLOSSY IBIS
# 126 GO AWAY BIRD
# 127 GOLD WING WARBLER
# 128 GOLDEN CHEEKED WARBLER
# 129 GOLDEN CHLOROPHONIA
# 130 GOLDEN EAGLE
# 131 GOLDEN PHEASANT
# 132 GOLDEN PIPIT
# 133 GOULDIAN FINCH
# 134 GRAY CATBIRD
# 135 GRAY KINGBIRD
# 136 GRAY PARTRIDGE
# 137 GREAT GRAY OWL
# 138 GREAT KISKADEE
# 139 GREAT POTOO
# 140 GREATOR SAGE GROUSE
# 141 GREEN BROADBILL
# 142 GREEN JAY
# 143 GREEN MAGPIE
# 144 GREY PLOVER
# 145 GROVED BILLED ANI
# 146 GUINEA TURACO
# 147 GUINEAFOWL
# 148 GYRFALCON
# 149 HARLEQUIN DUCK
# 150 HARPY EAGLE
# 151 HAWAIIAN GOOSE
# 152 HELMET VANGA
# 153 HIMALAYAN MONAL
# 154 HOATZIN
# 155 HOODED MERGANSER
# 156 HOOPOES
# 157 HORNBILL
# 158 HORNED GUAN
# 159 HORNED LARK
# 160 HORNED SUNGEM
# 161 HOUSE FINCH
# 162 HOUSE SPARROW
# 163 HYACINTH MACAW
# 164 IMPERIAL SHAQ
# 165 INCA TERN
# 166 INDIAN BUSTARD
# 167 INDIAN PITTA
# 168 INDIAN ROLLER
# 169 INDIGO BUNTING
# 170 IWI
# 171 JABIRU
# 172 JAVA SPARROW
# 173 KAGU
# 174 KAKAPO
# 175 KILLDEAR
# 176 KING VULTURE
# 177 KIWI
# 178 KOOKABURRA
# 179 LARK BUNTING
# 180 LAZULI BUNTING
# 181 LILAC ROLLER
# 182 LONG-EARED OWL
# 183 MAGPIE GOOSE
# 184 MALABAR HORNBILL
# 185 MALACHITE KINGFISHER
# 186 MALAGASY WHITE EYE
# 187 MALEO
# 188 MALLARD DUCK
# 189 MANDRIN DUCK
# 190 MANGROVE CUCKOO
# 191 MARABOU STORK
# 192 MASKED BOOBY
# 193 MASKED LAPWING
# 194 MIKADO  PHEASANT
# 195 MOURNING DOVE
# 196 MYNA
# 197 NICOBAR PIGEON
# 198 NOISY FRIARBIRD
# 199 NORTHERN CARDINAL
# 200 NORTHERN FLICKER
# 201 NORTHERN FULMAR
# 202 NORTHERN GANNET
# 203 NORTHERN GOSHAWK
# 204 NORTHERN JACANA
# 205 NORTHERN MOCKINGBIRD
# 206 NORTHERN PARULA
# 207 NORTHERN RED BISHOP
# 208 NORTHERN SHOVELER
# 209 OCELLATED TURKEY
# 210 OKINAWA RAIL
# 211 ORANGE BRESTED BUNTING
# 212 ORIENTAL BAY OWL
# 213 OSPREY
# 214 OSTRICH
# 215 OVENBIRD
# 216 OYSTER CATCHER
# 217 PAINTED BUNTIG
# 218 PALILA
# 219 PARADISE TANAGER
# 220 PARAKETT  AKULET
# 221 PARUS MAJOR
# 222 PATAGONIAN SIERRA FINCH
# 223 PEACOCK
# 224 PELICAN
# 225 PEREGRINE FALCON
# 226 PHILIPPINE EAGLE
# 227 PINK ROBIN
# 228 POMARINE JAEGER
# 229 PUFFIN
# 230 PURPLE FINCH
# 231 PURPLE GALLINULE
# 232 PURPLE MARTIN
# 233 PURPLE SWAMPHEN
# 234 PYGMY KINGFISHER
# 235 QUETZAL
# 236 RAINBOW LORIKEET
# 237 RAZORBILL
# 238 RED BEARDED BEE EATER
# 239 RED BELLIED PITTA
# 240 RED BROWED FINCH
# 241 RED FACED CORMORANT
# 242 RED FACED WARBLER
# 243 RED FODY
# 244 RED HEADED DUCK
# 245 RED HEADED WOODPECKER
# 246 RED HONEY CREEPER
# 247 RED NAPED TROGON
# 248 RED TAILED HAWK
# 249 RED TAILED THRUSH
# 250 RED WINGED BLACKBIRD
# 251 RED WISKERED BULBUL
# 252 REGENT BOWERBIRD
# 253 RING-NECKED PHEASANT
# 254 ROADRUNNER
# 255 ROBIN
# 256 ROCK DOVE
# 257 ROSY FACED LOVEBIRD
# 258 ROUGH LEG BUZZARD
# 259 ROYAL FLYCATCHER
# 260 RUBY THROATED HUMMINGBIRD
# 261 RUDY KINGFISHER
# 262 RUFOUS KINGFISHER
# 263 RUFUOS MOTMOT
# 264 SAMATRAN THRUSH
# 265 SAND MARTIN
# 266 SANDHILL CRANE
# 267 SATYR TRAGOPAN
# 268 SCARLET CROWNED FRUIT DOVE
# 269 SCARLET IBIS
# 270 SCARLET MACAW
# 271 SCARLET TANAGER
# 272 SHOEBILL
# 273 SHORT BILLED DOWITCHER
# 274 SMITHS LONGSPUR
# 275 SNOWY EGRET
# 276 SNOWY OWL
# 277 SORA
# 278 SPANGLED COTINGA
# 279 SPLENDID WREN
# 280 SPOON BILED SANDPIPER
# 281 SPOONBILL
# 282 SPOTTED CATBIRD
# 283 SRI LANKA BLUE MAGPIE
# 284 STEAMER DUCK
# 285 STORK BILLED KINGFISHER
# 286 STRAWBERRY FINCH
# 287 STRIPED OWL
# 288 STRIPPED MANAKIN
# 289 STRIPPED SWALLOW
# 290 SUPERB STARLING
# 291 SWINHOES PHEASANT
# 292 TAIWAN MAGPIE
# 293 TAKAHE
# 294 TASMANIAN HEN
# 295 TEAL DUCK
# 296 TIT MOUSE
# 297 TOUCHAN
# 298 TOWNSENDS WARBLER
# 299 TREE SWALLOW
# 300 TROPICAL KINGBIRD
# 301 TRUMPTER SWAN
# 302 TURKEY VULTURE
# 303 TURQUOISE MOTMOT
# 304 UMBRELLA BIRD
# 305 VARIED THRUSH
# 306 VENEZUELIAN TROUPIAL
# 307 VERMILION FLYCATHER
# 308 VICTORIA CROWNED PIGEON
# 309 VIOLET GREEN SWALLOW
# 310 VULTURINE GUINEAFOWL
# 311 WALL CREAPER
# 312 WATTLED CURASSOW
# 313 WHIMBREL
# 314 WHITE BROWED CRAKE
# 315 WHITE CHEEKED TURACO
# 316 WHITE NECKED RAVEN
# 317 WHITE TAILED TROPIC
# 318 WHITE THROATED BEE EATER
# 319 WILD TURKEY
# 320 WILSONS BIRD OF PARADISE
# 321 WOOD DUCK
# 322 YELLOW BELLIED FLOWERPECKER
# 323 YELLOW CACIQUE
#  ('ORANGE BRESTED BUNTING', 0.020178152061716508, 1.0884876251220703),
#  ('ORIENTAL BAY OWL', 0.009845225545057436, 0.6872742176055908),
#  ('OSPREY', 0.0034142240214754243, 0.65641188621521),
#  ('OSTRICH', 0.0, 0.7063717842102051),
#  ('OVENBIRD', 0.0002253349892834871, 0.8500411510467529),
#  ('OYSTER CATCHER', 0.01165980314346163, 0.5723340511322021),
#  ('PAINTED BUNTIG', 0.0016398406994450568, 1.0768795013427734),
#  ('PALILA', 0.0008333333333333334, 0.5594782829284668),
#  ('PARADISE TANAGER', 0.012236351067392437, 1.0717015266418457),
#  ('PARAKETT  AKULET', 3.827018752391887e-05, 0.6830103397369385),
#  ('PARUS MAJOR', 0.0, 1.0857164859771729),
#  ('PATAGONIAN SIERRA FINCH', 0.00045309682881947437, 0.7476437091827393),
#  ('PEACOCK', 0.06964051735871164, 0.7357077598571777),
#  ('PELICAN', 0.0, 0.5878708362579346),
#  ('PEREGRINE FALCON', 0.002090034017744861, 0.4225621223449707),
#  ('PHILIPPINE EAGLE', 0.0, 0.46285200119018555),
#  ('PINK ROBIN', 0.01626100769803489, 1.1197991371154785),
#  ('POMARINE JAEGER', 0.003171027585346065, 0.4220309257507324),
#  ('PUFFIN', 3.5216227637695446e-05, 0.47821664810180664),
#  ('PURPLE FINCH', 0.014415154624101286, 0.586172342300415),
#  ('PURPLE GALLINULE', 0.00033967391304347825, 1.1056580543518066),
#  ('PURPLE MARTIN', 0.0, 0.589224100112915),
#  ('PURPLE SWAMPHEN', 0.0024407792424394237, 0.8862011432647705),
#  ('PYGMY KINGFISHER', 0.001480879444020333, 0.9344897270202637),
#  ('QUETZAL', 0.003614046342563005, 0.646735429763794),
#  ('RAINBOW LORIKEET', 0.00034226032955788434, 0.9753003120422363),
#  ('RAZORBILL', 0.004406552564170614, 0.5605394840240479),
#  ('RED BEARDED BEE EATER', 0.00045408051086447365, 0.4696967601776123),
#  ('RED BELLIED PITTA', 0.004965873019894197, 0.6223740577697754),
#  ('RED BROWED FINCH', 0.007529270928875625, 0.6906347274780273),
#  ('RED FACED CORMORANT', 0.0008436618305474252, 0.7249898910522461),
#  ('RED FACED WARBLER', 0.00010002448664622174, 1.0436146259307861),
#  ('RED FODY', 0.08120069186267811, 1.114398717880249),
#  ('RED HEADED DUCK', 4.025764895330113e-05, 0.6728689670562744),
#  ('RED HEADED WOODPECKER', 0.0040022883295194505, 0.8169186115264893),
#  ('RED HONEY CREEPER', 0.0030140110785272073, 0.46173572540283203),
#  ('RED NAPED TROGON', 0.0034166970572234025, 0.6557159423828125),
#  ('RED TAILED HAWK', 0.0030845582819421552, 0.4585075378417969),
#  ('RED TAILED THRUSH', 0.0, 0.8252992630004883),
#  ('RED WINGED BLACKBIRD', 0.0024490263017662144, 0.4781484603881836),
#  ('RED WISKERED BULBUL', 3.729395092116059e-05, 1.0765771865844727),
#  ('REGENT BOWERBIRD', 0.0007458267859989523, 0.9104816913604736),
#  ('RING-NECKED PHEASANT', 0.00016893848708344597, 0.4196445941925049),
#  ('ROADRUNNER', 0.0009584793939632649, 0.4932539463043213),
#  ('ROBIN', 0.008562989051313055, 0.7642912864685059),
#  ('ROCK DOVE', 0.0023992912686480257, 1.0587399005889893),
#  ('ROSY FACED LOVEBIRD', 6.481301445330222e-05, 0.9857580661773682),
#  ('ROUGH LEG BUZZARD', 0.00034234851078397807, 0.40413618087768555),
#  ('ROYAL FLYCATCHER', 0.0007314023513002689, 1.1183760166168213),
#  ('RUBY THROATED HUMMINGBIRD', 0.001030381941845188, 0.5008394718170166),
#  ('RUDY KINGFISHER', 0.0008587985857732947, 1.4473283290863037),
#  ('RUFOUS KINGFISHER', 0.037519062181748004, 2.2497992515563965),
#  ('RUFUOS MOTMOT', 0.0017536325127476046, 0.9488704204559326),
#  ('SAMATRAN THRUSH', 0.011027299601207734, 0.46604061126708984),
#  ('SAND MARTIN', 0.0033112582781456954, 0.8915259838104248),
#  ('SANDHILL CRANE', 0.001418800708478844, 1.0965189933776855),
#  ('SATYR TRAGOPAN', 0.0033596659230941826, 0.7987911701202393),
#  ('SCARLET CROWNED FRUIT DOVE', 0.0001935839270773244, 0.45913052558898926),
#  ('SCARLET IBIS', 0.001206432229642429, 0.6453232765197754),
#  ('SCARLET MACAW', 0.004145974000119303, 0.6469724178314209),
#  ('SCARLET TANAGER', 6.313131313131313e-05, 0.6456437110900879),
#  ('SHOEBILL', 0.0007099567099567099, 0.4569575786590576),
#  ('SHORT BILLED DOWITCHER', 0.002994889083479157, 1.0671501159667969),
#  ('SMITHS LONGSPUR', 0.0001278929286064862, 0.837874174118042),
#  ('SNOWY EGRET', 0.009115408691160233, 0.9393455982208252),
#  ('SNOWY OWL', 0.008371364119950382, 1.0698471069335938),
#  ('SORA', 0.0009277455845263029, 0.4376974105834961),
#  ('SPANGLED COTINGA', 0.0013665811807390602, 0.48708224296569824),
#  ('SPLENDID WREN', 0.0007481695793384106, 1.1030771732330322),
#  ('SPOON BILED SANDPIPER', 0.000911643648173909, 1.0754380226135254),
#  ('SPOONBILL', 0.00015077888061759028, 0.7290852069854736),
#  ('SPOTTED CATBIRD', 0.002009647517160497, 0.8765835762023926),
#  ('SRI LANKA BLUE MAGPIE', 9.650614104484731e-05, 0.6394085884094238),
#  ('STEAMER DUCK', 0.0010784797031185463, 0.8829481601715088),
#  ('STORK BILLED KINGFISHER', 0.0, 0.4156472682952881),
#  ('STRAWBERRY FINCH', 0.006606868322098089, 0.9391365051269531),
#  ('STRIPED OWL', 0.0165957419117139, 0.908301830291748),
#  ('STRIPPED MANAKIN', 0.0026027952864353357, 1.0685782432556152),
#  ('STRIPPED SWALLOW', 0.0050640234194717715, 0.5653440952301025),
#  ('SUPERB STARLING', 0.0023148148148148147, 0.7920770645141602),
#  ('SWINHOES PHEASANT', 0.00046750484538502976, 0.6693515777587891),
#  ('TAIWAN MAGPIE', 0.007352941176470588, 0.725705623626709),
#  ('TAKAHE', 5.592841163310962e-05, 0.7601742744445801),
#  ('TASMANIAN HEN', 0.003367521033297902, 0.7575247287750244),
#  ('TEAL DUCK', 0.0008953618831532261, 0.4639856815338135),
#  ('TIT MOUSE', 0.010403126412288482, 1.0780491828918457),
#  ('TOUCHAN', 0.0001441753171856978, 0.4759213924407959),
#  ('TOWNSENDS WARBLER', 0.0002560447682398902, 0.7188291549682617),
#  ('TREE SWALLOW', 0.0, 0.47710156440734863),
#  ('TROPICAL KINGBIRD', 0.0003654970760233918, 0.749521017074585),
#  ('TRUMPTER SWAN', 0.031649877451694626, 0.4528172016143799),
#  ('TURKEY VULTURE', 0.0, 0.6496894359588623),
#  ('TURQUOISE MOTMOT', 0.001078972833780526, 0.7491500377655029),
#  ('UMBRELLA BIRD', 0.008965942038200362, 0.903616189956665),
#  ('VARIED THRUSH', 0.00024025008228218135, 0.8608384132385254),
#  ('VENEZUELIAN TROUPIAL', 0.001457559227453727, 0.8195047378540039),
#  ('VERMILION FLYCATHER', 0.003402996303459731, 1.1890277862548828),
#  ('VICTORIA CROWNED PIGEON', 2.7507289431699398e-05, 0.8006124496459961),
#  ('VIOLET GREEN SWALLOW', 0.00017814878366028398, 0.5842387676239014),
#  ('VULTURINE GUINEAFOWL', 0.0033198093181598773, 0.8647584915161133),
#  ('WALL CREAPER', 0.0, 0.6367640495300293),
#  ('WATTLED CURASSOW', 0.00019842951447324698, 0.8555736541748047),
#  ('WHIMBREL', 0.003080290528153203, 0.8250241279602051),
#  ('WHITE BROWED CRAKE', 3.587572648346129e-05, 0.766627311706543),
#  ('WHITE CHEEKED TURACO', 0.003744140753944676, 1.5789518356323242),
#  ('WHITE NECKED RAVEN', 0.004617117117117117, 0.9990243911743164),
#  ('WHITE TAILED TROPIC', 0.00032731933353051366, 0.5598030090332031),
#  ('WHITE THROATED BEE EATER', 0.0, 1.0749425888061523),
#  ('WILD TURKEY', 0.005174664784292043, 0.7172110080718994),
#  ('WILSONS BIRD OF PARADISE', 0.0004409171075837742, 0.6895523071289062),
#  ('WOOD DUCK', 0.00010867202782003912, 0.868527889251709),
#  ('YELLOW BELLIED FLOWERPECKER', 0.00012912897780241377, 1.0940139293670654),
#  ('YELLOW CACIQUE', 0.0012365591397849461, 0.653139591217041),
#  ('YELLOW HEADED BLACKBIRD', 0.013836146602026839, 0.9489948749542236)]

# %%
ap_at_n = np.array([ap[1] for ap in aps])
query_time = np.array(([ap[2] for ap in aps]))

# %%
mAP_at_n = np.mean(ap_at_n, axis=0)
avg_query_time = np.mean(query_time, axis=0)
print("mAP:", mAP_at_n)
print("avg. query time: ", avg_query_time)
# Out:
# mAP: 0.004993917220686415
# avg. query time:  0.7500516407306378

# %% [markdown]
# ## store results

# %%
save_results('/content/drive/MyDrive/CV_Birds/performance/feature_extraction/index/FE-no-distr_tree_5rnd_cosine', "FE-no-distr_tree_5rnd_cosine", aps)

# %%
# !cp /content/tree* /content/drive/MyDrive/CV_Birds/performance/feature_extraction/index/FE-no-distr_tree_5rnd_cosine/tree_structure
