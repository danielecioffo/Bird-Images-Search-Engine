# %% [markdown]
# ## Import libraries

# %%
from google.colab import drive
from pathlib import Path
from matplotlib import pyplot as plt 
import pandas as pd
import numpy as np
import time
import os
import csv
import concurrent.futures

# %% [markdown]
# ## Utility functions

# %% [markdown]
# ### Create annot and load descriptors

# %%
def create_annot(path):
  image_list = list(Path(path).glob('*/*.jpg'))
  # the identity name is in the path (the name of the parent directory)
  names_list = [i.parent.name for i in image_list]  # get the identity of each image
  # keep info in a pandas DataFrame
  annot = pd.DataFrame({'identity': names_list, 'image_path': image_list})
  return annot

def concatenate_annots(list_of_paths):
  concat_annot = pd.DataFrame()
  with concurrent.futures.ThreadPoolExecutor() as executor:
    annots = [create_annot(path) for path in list_of_paths]
    for annot in annots:
      concat_annot = concat_annot.append(annot, ignore_index = True)
    return concat_annot

# %%
def load_descriptors(path):
  with open(path, 'rb') as file:
    return np.load(file)

def concatenate_descriptors(list_of_paths):
  concat_descriptors = None
  with concurrent.futures.ThreadPoolExecutor() as executor:
    descriptors = [executor.submit(load_descriptors, path) for path in list_of_paths]
    for descriptor in descriptors:
      new_descriptor = descriptor.result()
      if concat_descriptors is None:
        concat_descriptors = new_descriptor
      else:
        concat_descriptors = np.concatenate([concat_descriptors, new_descriptor])
    return concat_descriptors

# %% [markdown]
# ### Create pivots

# %%
def generate_pivots(descriptors, n, strategy="rnd"):
  if strategy != "rnd":
    print(strategy, "was not implemented. Random pivots were returned")
  pivots_id = np.random.choice(np.arange(len(descriptors)), size=n)
  return descriptors[pivots_id]

def generate_list_of_pivots(descriptors, t, n, strategy="rnd"):
  list_of_pivots = []
  with concurrent.futures.ThreadPoolExecutor() as executor:
    pivots = [executor.submit(generate_pivots, descriptors, n, strategy) for i in range(t)]
    for pivot in concurrent.futures.as_completed(pivots):
      new_pivot = pivot.result()
      list_of_pivots.append(new_pivot)
    return list_of_pivots

# %% [markdown]
# ### Save test results

# %%
def save_results(dir, file_name, results):
  with open(os.path.join(dir, file_name +".csv"), 'w') as f:
    writer = csv.writer(f)
    # write the header
    writer.writerow(["CLASS", "AP", "QUERY TIME"])
    # write the data
    for r in results:
      writer.writerow(r)

# %% [markdown]
# ## Test Performance

# %%
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Create annot and load descriptors for the database

# %%
db_annot = concatenate_annots(['/content/drive/MyDrive/CV_Birds/train', '/content/drive/MyDrive/CV_Birds/mirflickr25k'])
db_annot
# Out:
#                     identity                                         image_path
# 0      AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/train/AFRICAN ...
# 1      AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/train/AFRICAN ...
# 2      AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/train/AFRICAN ...
# 3      AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/train/AFRICAN ...
# 4      AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/train/AFRICAN ...
# ...                      ...                                                ...
# 72327              mirflickr  /content/drive/MyDrive/CV_Birds/mirflickr25k/m...
# 72328              mirflickr  /content/drive/MyDrive/CV_Birds/mirflickr25k/m...
# 72329              mirflickr  /content/drive/MyDrive/CV_Birds/mirflickr25k/m...
# 72330              mirflickr  /content/drive/MyDrive/CV_Birds/mirflickr25k/m...
# 72331              mirflickr  /content/drive/MyDrive/CV_Birds/mirflickr25k/m...
#
# [72332 rows x 2 columns]

# %%
db_descriptors = concatenate_descriptors(['/content/drive/MyDrive/CV_Birds/features/training/ResNet50v2/resnet_fe_features.npy','/content/drive/MyDrive/CV_Birds/features/distractor/ResNet50v2/resnet50_fe_features.npy'])
db_descriptors.shape
# Out:
# (72332, 2048)

# %% [markdown]
# ### Create annot and load descriptors for the test set

# %%
query_annot = create_annot('/content/drive/MyDrive/CV_Birds/test')
query_annot
# Out:
#                      identity                                         image_path
# 0       AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/test/AFRICAN C...
# 1       AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/test/AFRICAN C...
# 2       AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/test/AFRICAN C...
# 3       AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/test/AFRICAN C...
# 4       AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/test/AFRICAN C...
# ...                       ...                                                ...
# 1620  YELLOW HEADED BLACKBIRD  /content/drive/MyDrive/CV_Birds/test/YELLOW HE...
# 1621  YELLOW HEADED BLACKBIRD  /content/drive/MyDrive/CV_Birds/test/YELLOW HE...
# 1622  YELLOW HEADED BLACKBIRD  /content/drive/MyDrive/CV_Birds/test/YELLOW HE...
# 1623  YELLOW HEADED BLACKBIRD  /content/drive/MyDrive/CV_Birds/test/YELLOW HE...
# 1624  YELLOW HEADED BLACKBIRD  /content/drive/MyDrive/CV_Birds/test/YELLOW HE...
#
# [1625 rows x 2 columns]

# %%
query_descriptors = load_descriptors('/content/drive/MyDrive/CV_Birds/features/test/ResNet50v2/resnet50_fe_features.npy')
query_descriptors.shape
# Out:
# (1625, 2048)

# %% [markdown]
# To run our tests we select only the first image of each species within the test set. Please note that within the test set we have 5 images per species.

# %%
queries_indexes = [x for x in range(325*5) if x%5 == 0]

# %% [markdown]
# ### Create PP-Index

# %%
def get_descriptor_from_id(id_object):
  return db_descriptors[id_object]

# %%
# %cd "/content/drive/MyDrive/CV_Birds/Notebooks/PP-Index"
# %run PPIndex.ipynb
# Out:
# /content/drive/.shortcut-targets-by-id/1rI5YNBuaSlCB__w522WEkHjw-nFuvIo0/CV_Birds/Notebooks/PP-Index

# %%
pivots = generate_pivots(db_descriptors, 5, "rnd")
rnd_pp_tree = PrefixTree(pivots, length=3, distance_metric='euclidean', base_directory="/content", tree_file='tree_structure')
if rnd_pp_tree.is_empty():
  rnd_pp_tree.insert_objects_into_tree(range(len(db_descriptors)))
  rnd_pp_tree.save()
# Out:
# [WARNING]: Tree is still empty
# Inserting objects into tree_structure ...
# --- Insertion into tree tree_structure completed: 75.027 seconds ---

# %% [markdown]
# ### Compute mAP

# %%
birds_db = db_annot.loc[db_annot['identity'] != 'mirflickr']
counts = birds_db.groupby('identity').count()
print("Minimum number of images per species:", int(counts.min()))
print("Maximum number of images per species:", int(counts.max()))
print("Average number of images:", float(counts.sum()/325))
# Out:
# Minimum number of images per species: 116
# Maximum number of images per species: 249
# Average number of images: 145.63692307692307

# %% [markdown]
# Since at most we have 249 images per species, we use $n=250$.

# %%
n = 250

# %% [markdown]
# The formula for Average Precision is the following:
#
# > $AP@n=\frac{1}{GTP}\sum_{k=1}^{n}P@k×rel@k$
#
# where $GTP$ refers to the total number of ground truth positives, $n$ refers to the total number of images we are interested in, $P@k$ refers to the precision@k and $rel@k$ is a relevance function.
#
# The relevance function is an indicator function which equals 1 if the document at rank $k$ is relevant and equals to 0 otherwise.

# %%
def compute_ap(query_index, retrieved_ids):
  query_identity = query_annot['identity'][query_index]
  print(query_index//5, query_identity)
  GTP = len(db_annot.loc[db_annot['identity'] == query_identity])
  relevant = 0
  precision_summation = 0
  for k, id in enumerate(retrieved_ids):
    if db_annot['identity'][id] == query_identity: # relevant result
      relevant = relevant + 1
      precision_at_k = relevant/(k+1)
      precision_summation = precision_summation + precision_at_k
  return (query_identity, precision_summation/GTP)

# %% [markdown]
# For each query, $Q$, we can calculate a corresponding $AP$. Then, the $mAP$ is simply the mean of all the queries that were made.
# > $mAP = \frac{1}{N}\sum_{i=1}^{N}AP_i$
#
# In our case, $N=325$ (one query per species)

# %%
def rnd_pivots_queries(query_index, n):
  start_time = time.time()
  ids, distances = rnd_pp_tree.find_nearest_neighbors(query_descriptors[query_index], n)
  end_time = time.time()
  ids = ids.tolist()
  return compute_ap(query_index, ids) + (end_time - start_time,)

# %%
aps = []
for query_index in queries_indexes:
  aps.append(rnd_pivots_queries(query_index, n))
# Out:
# 0 AFRICAN CROWNED CRANE
# 1 AFRICAN FIREFINCH
# 2 ALBATROSS
# 3 ALEXANDRINE PARAKEET
# 4 AMERICAN AVOCET
# 5 AMERICAN BITTERN
# 6 AMERICAN COOT
# 7 AMERICAN GOLDFINCH
# 8 AMERICAN KESTREL
# 9 AMERICAN PIPIT
# 10 AMERICAN REDSTART
# 11 ANHINGA
# 12 ANNAS HUMMINGBIRD
# 13 ANTBIRD
# 14 ARARIPE MANAKIN
# 15 ASIAN CRESTED IBIS
# 16 BALD EAGLE
# 17 BALD IBIS
# 18 BALI STARLING
# 19 BALTIMORE ORIOLE
# 20 BANANAQUIT
# 21 BANDED BROADBILL
# 22 BANDED PITA
# 23 BAR-TAILED GODWIT
# 24 BARN OWL
# 25 BARN SWALLOW
# 26 BARRED PUFFBIRD
# 27 BAY-BREASTED WARBLER
# 28 BEARDED BARBET
# 29 BEARDED BELLBIRD
# 30 BEARDED REEDLING
# 31 BELTED KINGFISHER
# 32 BIRD OF PARADISE
# 33 BLACK & YELLOW bROADBILL
# 34 BLACK BAZA
# 35 BLACK FRANCOLIN
# 36 BLACK SKIMMER
# 37 BLACK SWAN
# 38 BLACK TAIL CRAKE
# 39 BLACK THROATED BUSHTIT
# 40 BLACK THROATED WARBLER
# 41 BLACK VULTURE
# 42 BLACK-CAPPED CHICKADEE
# 43 BLACK-NECKED GREBE
# 44 BLACK-THROATED SPARROW
# 45 BLACKBURNIAM WARBLER
# 46 BLONDE CRESTED WOODPECKER
# 47 BLUE COAU
# 48 BLUE GROUSE
# 49 BLUE HERON
# 50 BLUE THROATED TOUCANET
# 51 BOBOLINK
# 52 BORNEAN BRISTLEHEAD
# 53 BORNEAN LEAFBIRD
# 54 BORNEAN PHEASANT
# 55 BRANDT CORMARANT
# 56 BROWN CREPPER
# 57 BROWN NOODY
# 58 BROWN THRASHER
# 59 BULWERS PHEASANT
# 60 CACTUS WREN
# 61 CALIFORNIA CONDOR
# 62 CALIFORNIA GULL
# 63 CALIFORNIA QUAIL
# 64 CANARY
# 65 CAPE GLOSSY STARLING
# 66 CAPE MAY WARBLER
# 67 CAPPED HERON
# 68 CAPUCHINBIRD
# 69 CARMINE BEE-EATER
# 70 CASPIAN TERN
# 71 CASSOWARY
# 72 CEDAR WAXWING
# 73 CERULEAN WARBLER
# 74 CHARA DE COLLAR
# 75 CHESTNET BELLIED EUPHONIA
# 76 CHIPPING SPARROW
# 77 CHUKAR PARTRIDGE
# 78 CINNAMON TEAL
# 79 CLARKS NUTCRACKER
# 80 COCK OF THE  ROCK
# 81 COCKATOO
# 82 COLLARED ARACARI
# 83 COMMON FIRECREST
# 84 COMMON GRACKLE
# 85 COMMON HOUSE MARTIN
# 86 COMMON LOON
# 87 COMMON POORWILL
# 88 COMMON STARLING
# 89 COUCHS KINGBIRD
# 90 CRESTED AUKLET
# 91 CRESTED CARACARA
# 92 CRESTED NUTHATCH
# 93 CRIMSON SUNBIRD
# 94 CROW
# 95 CROWNED PIGEON
# 96 CUBAN TODY
# 97 CUBAN TROGON
# 98 CURL CRESTED ARACURI
# 99 D-ARNAUDS BARBET
# 100 DARK EYED JUNCO
# 101 DOUBLE BARRED FINCH
# 102 DOUBLE BRESTED CORMARANT
# 103 DOWNY WOODPECKER
# 104 EASTERN BLUEBIRD
# 105 EASTERN MEADOWLARK
# 106 EASTERN ROSELLA
# 107 EASTERN TOWEE
# 108 ELEGANT TROGON
# 109 ELLIOTS  PHEASANT
# 110 EMPEROR PENGUIN
# 111 EMU
# 112 ENGGANO MYNA
# 113 EURASIAN GOLDEN ORIOLE
# 114 EURASIAN MAGPIE
# 115 EVENING GROSBEAK
# 116 FAIRY BLUEBIRD
# 117 FIRE TAILLED MYZORNIS
# 118 FLAME TANAGER
# 119 FLAMINGO
# 120 FRIGATE
# 121 GAMBELS QUAIL
# 122 GANG GANG COCKATOO
# 123 GILA WOODPECKER
# 124 GILDED FLICKER
# 125 GLOSSY IBIS
# 126 GO AWAY BIRD
# 127 GOLD WING WARBLER
# 128 GOLDEN CHEEKED WARBLER
# 129 GOLDEN CHLOROPHONIA
# 130 GOLDEN EAGLE
# 131 GOLDEN PHEASANT
# 132 GOLDEN PIPIT
# 133 GOULDIAN FINCH
# 134 GRAY CATBIRD
# 135 GRAY KINGBIRD
# 136 GRAY PARTRIDGE
# 137 GREAT GRAY OWL
# 138 GREAT KISKADEE
# 139 GREAT POTOO
# 140 GREATOR SAGE GROUSE
# 141 GREEN BROADBILL
# 142 GREEN JAY
# 143 GREEN MAGPIE
# 144 GREY PLOVER
# 145 GROVED BILLED ANI
# 146 GUINEA TURACO
# 147 GUINEAFOWL
# 148 GYRFALCON
# 149 HARLEQUIN DUCK
# 150 HARPY EAGLE
# 151 HAWAIIAN GOOSE
# 152 HELMET VANGA
# 153 HIMALAYAN MONAL
# 154 HOATZIN
# 155 HOODED MERGANSER
# 156 HOOPOES
# 157 HORNBILL
# 158 HORNED GUAN
# 159 HORNED LARK
# 160 HORNED SUNGEM
# 161 HOUSE FINCH
# 162 HOUSE SPARROW
# 163 HYACINTH MACAW
# 164 IMPERIAL SHAQ
# 165 INCA TERN
# 166 INDIAN BUSTARD
# 167 INDIAN PITTA
# 168 INDIAN ROLLER
# 169 INDIGO BUNTING
# 170 IWI
# 171 JABIRU
# 172 JAVA SPARROW
# 173 KAGU
# 174 KAKAPO
# 175 KILLDEAR
# 176 KING VULTURE
# 177 KIWI
# 178 KOOKABURRA
# 179 LARK BUNTING
# 180 LAZULI BUNTING
# 181 LILAC ROLLER
# 182 LONG-EARED OWL
# 183 MAGPIE GOOSE
# 184 MALABAR HORNBILL
# 185 MALACHITE KINGFISHER
# 186 MALAGASY WHITE EYE
# 187 MALEO
# 188 MALLARD DUCK
# 189 MANDRIN DUCK
# 190 MANGROVE CUCKOO
# 191 MARABOU STORK
# 192 MASKED BOOBY
# 193 MASKED LAPWING
# 194 MIKADO  PHEASANT
# 195 MOURNING DOVE
# 196 MYNA
# 197 NICOBAR PIGEON
# 198 NOISY FRIARBIRD
# 199 NORTHERN CARDINAL
# 200 NORTHERN FLICKER
# 201 NORTHERN FULMAR
# 202 NORTHERN GANNET
# 203 NORTHERN GOSHAWK
# 204 NORTHERN JACANA
# 205 NORTHERN MOCKINGBIRD
# 206 NORTHERN PARULA
# 207 NORTHERN RED BISHOP
# 208 NORTHERN SHOVELER
# 209 OCELLATED TURKEY
# 210 OKINAWA RAIL
# 211 ORANGE BRESTED BUNTING
# 212 ORIENTAL BAY OWL
# 213 OSPREY
# 214 OSTRICH
# 215 OVENBIRD
# 216 OYSTER CATCHER
# 217 PAINTED BUNTIG
# 218 PALILA
# 219 PARADISE TANAGER
# 220 PARAKETT  AKULET
# 221 PARUS MAJOR
# 222 PATAGONIAN SIERRA FINCH
# 223 PEACOCK
# 224 PELICAN
# 225 PEREGRINE FALCON
# 226 PHILIPPINE EAGLE
# 227 PINK ROBIN
# 228 POMARINE JAEGER
# 229 PUFFIN
# 230 PURPLE FINCH
# 231 PURPLE GALLINULE
# 232 PURPLE MARTIN
# 233 PURPLE SWAMPHEN
# 234 PYGMY KINGFISHER
# 235 QUETZAL
# 236 RAINBOW LORIKEET
# 237 RAZORBILL
# 238 RED BEARDED BEE EATER
# 239 RED BELLIED PITTA
# 240 RED BROWED FINCH
# 241 RED FACED CORMORANT
# 242 RED FACED WARBLER
# 243 RED FODY
# 244 RED HEADED DUCK
# 245 RED HEADED WOODPECKER
# 246 RED HONEY CREEPER
# 247 RED NAPED TROGON
# 248 RED TAILED HAWK
# 249 RED TAILED THRUSH
# 250 RED WINGED BLACKBIRD
# 251 RED WISKERED BULBUL
# 252 REGENT BOWERBIRD
# 253 RING-NECKED PHEASANT
# 254 ROADRUNNER
# 255 ROBIN
# 256 ROCK DOVE
# 257 ROSY FACED LOVEBIRD
# 258 ROUGH LEG BUZZARD
# 259 ROYAL FLYCATCHER
# 260 RUBY THROATED HUMMINGBIRD
# 261 RUDY KINGFISHER
# 262 RUFOUS KINGFISHER
# 263 RUFUOS MOTMOT
# 264 SAMATRAN THRUSH
# 265 SAND MARTIN
# 266 SANDHILL CRANE
# 267 SATYR TRAGOPAN
# 268 SCARLET CROWNED FRUIT DOVE
# 269 SCARLET IBIS
# 270 SCARLET MACAW
# 271 SCARLET TANAGER
# 272 SHOEBILL
# 273 SHORT BILLED DOWITCHER
# 274 SMITHS LONGSPUR
# 275 SNOWY EGRET
# 276 SNOWY OWL
# 277 SORA
# 278 SPANGLED COTINGA
# 279 SPLENDID WREN
# 280 SPOON BILED SANDPIPER
# 281 SPOONBILL
# 282 SPOTTED CATBIRD
# 283 SRI LANKA BLUE MAGPIE
# 284 STEAMER DUCK
# 285 STORK BILLED KINGFISHER
# 286 STRAWBERRY FINCH
# 287 STRIPED OWL
# 288 STRIPPED MANAKIN
# 289 STRIPPED SWALLOW
# 290 SUPERB STARLING
# 291 SWINHOES PHEASANT
# 292 TAIWAN MAGPIE
# 293 TAKAHE
# 294 TASMANIAN HEN
# 295 TEAL DUCK
# 296 TIT MOUSE
# 297 TOUCHAN
# 298 TOWNSENDS WARBLER
# 299 TREE SWALLOW
# 300 TROPICAL KINGBIRD
# 301 TRUMPTER SWAN
# 302 TURKEY VULTURE
# 303 TURQUOISE MOTMOT
# 304 UMBRELLA BIRD
# 305 VARIED THRUSH
# 306 VENEZUELIAN TROUPIAL
#  ('RED WISKERED BULBUL', 0.0, 1.1118357181549072),
#  ('REGENT BOWERBIRD', 0.00012807527882135412, 1.844388484954834),
#  ('RING-NECKED PHEASANT', 5.482456140350877e-05, 1.0645012855529785),
#  ('ROADRUNNER', 5.020080321285141e-05, 1.059912919998169),
#  ('ROBIN', 0.008229482151307583, 2.258931875228882),
#  ('ROCK DOVE', 0.003858350951374207, 1.6408751010894775),
#  ('ROSY FACED LOVEBIRD', 0.00030724329224491963, 2.285583257675171),
#  ('ROUGH LEG BUZZARD', 5.0152966547971315e-05, 1.6648590564727783),
#  ('ROYAL FLYCATCHER', 0.00016973508309007975, 0.8729541301727295),
#  ('RUBY THROATED HUMMINGBIRD', 9.620009620009621e-05, 0.3811802864074707),
#  ('RUDY KINGFISHER', 0.006603451439426441, 0.87388014793396),
#  ('RUFOUS KINGFISHER', 0.027743564071607416, 0.965531587600708),
#  ('RUFUOS MOTMOT', 9.728343061676395e-05, 0.9862105846405029),
#  ('SAMATRAN THRUSH', 0.008065170716380392, 2.3313210010528564),
#  ('SAND MARTIN', 0.0, 0.38712310791015625),
#  ('SANDHILL CRANE', 4.546281142025823e-05, 1.0466926097869873),
#  ('SATYR TRAGOPAN', 0.007271336646902654, 1.3674595355987549),
#  ('SCARLET CROWNED FRUIT DOVE', 9.759231120829164e-05, 0.9395856857299805),
#  ('SCARLET IBIS', 0.00360966645863671, 2.3423590660095215),
#  ('SCARLET MACAW', 0.0012506937506937506, 0.9641075134277344),
#  ('SCARLET TANAGER', 0.0035053243450999514, 2.232609272003174),
#  ('SHOEBILL', 0.0011246444953353734, 1.0741384029388428),
#  ('SHORT BILLED DOWITCHER', 0.001338550103131227, 1.6426153182983398),
#  ('SMITHS LONGSPUR', 0.00012254901960784314, 0.9400265216827393),
#  ('SNOWY EGRET', 0.013335608329441037, 1.8417575359344482),
#  ('SNOWY OWL', 0.009289367921081473, 1.6399552822113037),
#  ('SORA', 0.0005534561788106882, 0.4569432735443115),
#  ('SPANGLED COTINGA', 0.0012042404075371107, 3.284156084060669),
#  ('SPLENDID WREN', 0.0, 1.8982069492340088),
#  ('SPOON BILED SANDPIPER', 0.0006420426940207014, 1.1615777015686035),
#  ('SPOONBILL', 0.00019074256638633544, 2.257078170776367),
#  ('SPOTTED CATBIRD', 0.001153630667258133, 3.2966930866241455),
#  ('SRI LANKA BLUE MAGPIE', 0.0024303580607408317, 1.8454718589782715),
#  ('STEAMER DUCK', 0.0007856326063873235, 3.3515796661376953),
#  ('STORK BILLED KINGFISHER', 0.007542087542087541, 2.3608949184417725),
#  ('STRAWBERRY FINCH', 0.004814987051571385, 1.856818437576294),
#  ('STRIPED OWL', 0.0033579575697919007, 3.2872588634490967),
#  ('STRIPPED MANAKIN', 0.0029484211775878447, 0.8719382286071777),
#  ('STRIPPED SWALLOW', 0.002351315129614307, 2.243664264678955),
#  ('SUPERB STARLING', 0.0, 1.7643463611602783),
#  ('SWINHOES PHEASANT', 6.77690431011114e-05, 2.3949317932128906),
#  ('TAIWAN MAGPIE', 0.007352941176470588, 0.9426529407501221),
#  ('TAKAHE', 0.00022522522522522523, 0.8699436187744141),
#  ('TASMANIAN HEN', 0.00041184041184041183, 1.0743932723999023),
#  ('TEAL DUCK', 0.00022598222697527563, 0.9295270442962646),
#  ('TIT MOUSE', 0.0017097932069462026, 1.0173358917236328),
#  ('TOUCHAN', 0.0002853946220654606, 0.9659466743469238),
#  ('TOWNSENDS WARBLER', 6.0606060606060605e-05, 1.0094759464263916),
#  ('TREE SWALLOW', 0.00017822135091783995, 0.9506449699401855),
#  ('TROPICAL KINGBIRD', 4.892367906066536e-05, 1.8404903411865234),
#  ('TRUMPTER SWAN', 0.00879754129850173, 0.44432616233825684),
#  ('TURKEY VULTURE', 0.006795302013422819, 2.294973134994507),
#  ('TURQUOISE MOTMOT', 0.0006312820093557799, 2.25710129737854),
#  ('UMBRELLA BIRD', 0.008249282527614674, 3.251335859298706),
#  ('VARIED THRUSH', 2.2926314824155166e-05, 1.0061719417572021),
#  ('VENEZUELIAN TROUPIAL', 0.00010225994477962983, 0.946230411529541),
#  ('VERMILION FLYCATHER', 0.001557978955138434, 0.4931168556213379),
#  ('VICTORIA CROWNED PIGEON', 4.789730817128078e-05, 1.0811786651611328),
#  ('VIOLET GREEN SWALLOW', 0.0, 2.2261528968811035),
#  ('VULTURINE GUINEAFOWL', 8.766162612316459e-05, 1.836902379989624),
#  ('WALL CREAPER', 0.004944439015916444, 2.2169485092163086),
#  ('WATTLED CURASSOW', 0.0002498750624687656, 1.8316760063171387),
#  ('WHIMBREL', 0.0017713365539452496, 3.2528810501098633),
#  ('WHITE BROWED CRAKE', 3.006253006253006e-05, 2.350897789001465),
#  ('WHITE CHEEKED TURACO', 0.0008013422482658453, 0.9660348892211914),
#  ('WHITE NECKED RAVEN', 0.004252136752136751, 3.297405958175659),
#  ('WHITE TAILED TROPIC', 0.003242856508313277, 1.8674755096435547),
#  ('WHITE THROATED BEE EATER', 0.0001914957760948577, 0.4501307010650635),
#  ('WILD TURKEY', 0.004452168458069079, 3.327204942703247),
#  ('WILSONS BIRD OF PARADISE', 0.0015495086923658352, 3.2830796241760254),
#  ('WOOD DUCK', 0.0012289499500517701, 1.0187530517578125),
#  ('YELLOW BELLIED FLOWERPECKER', 3.1511943026407014e-05, 1.8762164115905762),
#  ('YELLOW CACIQUE', 0.00048089817675071135, 2.2773916721343994),
#  ('YELLOW HEADED BLACKBIRD', 0.010619283992260604, 1.853041172027588)]

# %%
ap_at_n = np.array([ap[1] for ap in aps])
query_time = np.array(([ap[2] for ap in aps]))

# %%
mAP_at_n = np.mean(ap_at_n, axis=0)
avg_query_time = np.mean(query_time, axis=0)
print("mAP:", mAP_at_n)
print("avg. query time: ", avg_query_time)
# Out:
# mAP: 0.002962908424998027
# avg. query time:  1.6777417865166298

# %%
save_results('/content/drive/MyDrive/CV_Birds/performance/feature_extraction/index/FE-distr_tree_5rnd_euclidean', 'FE-distr_tree_5rnd_euclidean_results', aps)

# %%
# !mv /content/tree_structure* /content/drive/MyDrive/CV_Birds/performance/feature_extraction/index/FE-distr_tree_5rnd_euclidean/tree_structure/
