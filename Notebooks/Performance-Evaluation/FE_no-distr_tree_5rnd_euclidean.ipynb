# %% [markdown]
# ## Import libraries

# %%
from google.colab import drive
from pathlib import Path
from matplotlib import pyplot as plt 
import pandas as pd
import numpy as np
import time
import os
import csv
import concurrent.futures

# %% [markdown]
# ## Utility functions

# %% [markdown]
# ### Create annot and load descriptors

# %%
def create_annot(path):
  image_list = list(Path(path).glob('*/*.jpg'))
  # the identity name is in the path (the name of the parent directory)
  names_list = [i.parent.name for i in image_list]  # get the identity of each image
  # keep info in a pandas DataFrame
  annot = pd.DataFrame({'identity': names_list, 'image_path': image_list})
  return annot

def concatenate_annots(list_of_paths):
  concat_annot = pd.DataFrame()
  with concurrent.futures.ThreadPoolExecutor() as executor:
    annots = [executor.submit(create_annot, path) for path in list_of_paths]
    for annot in annots:
      new_annot = annot.result()
      concat_annot = concat_annot.append(new_annot, ignore_index = True)
    return concat_annot

# %%
def load_descriptors(path):
  with open(path, 'rb') as file:
    return np.load(file)

def concatenate_descriptors(list_of_paths):
  concat_descriptors = None
  with concurrent.futures.ThreadPoolExecutor() as executor:
    descriptors = [executor.submit(load_descriptors, path) for path in list_of_paths]
    for descriptor in descriptors:
      new_descriptor = descriptor.result()
      if concat_descriptors is None:
        concat_descriptors = new_descriptor
      else:
        concat_descriptors = np.concatenate([concat_descriptors, new_descriptor])
    return concat_descriptors

# %% [markdown]
# ### Create pivots

# %%
def generate_pivots(descriptors, n, strategy="rnd"):
  if strategy == "kMED":
    kmedoids = sklearn_extra.cluster.KMedoids(n_clusters=n).fit(descriptors)
    return kmedoids.cluster_centers_
  if strategy != "rnd":
    print(strategy, "was not implemented. Random pivots were returned")
  pivots_id = np.random.choice(np.arange(len(descriptors)), size=n)
  return descriptors[pivots_id]

def generate_list_of_pivots(descriptors, t, n, strategy="rnd"):
  list_of_pivots = []
  with concurrent.futures.ThreadPoolExecutor() as executor:
    pivots = [executor.submit(generate_pivots, descriptors, n, strategy) for i in range(t)]
    for pivot in concurrent.futures.as_completed(pivots):
      new_pivot = pivot.result()
      list_of_pivots.append(new_pivot)
    return list_of_pivots

# %% [markdown]
# ### Save test results

# %%
def save_results(dir, file_name, results):
  with open(os.path.join(dir, file_name +".csv"), 'w') as f:
    writer = csv.writer(f)
    # write the header
    writer.writerow(["CLASS", "AP", "QUERY TIME"])
    # write the data
    for r in results:
      writer.writerow(r)

# %% [markdown]
# ## Test Performance

# %%
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Create annot and load descriptors for the database

# %%
db_annot = create_annot('/content/drive/MyDrive/CV_Birds/train')
db_annot
# Out:
#                       identity                                         image_path
# 0        AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/train/AFRICAN ...
# 1        AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/train/AFRICAN ...
# 2        AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/train/AFRICAN ...
# 3        AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/train/AFRICAN ...
# 4        AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/train/AFRICAN ...
# ...                        ...                                                ...
# 47327  YELLOW HEADED BLACKBIRD  /content/drive/MyDrive/CV_Birds/train/YELLOW H...
# 47328  YELLOW HEADED BLACKBIRD  /content/drive/MyDrive/CV_Birds/train/YELLOW H...
# 47329  YELLOW HEADED BLACKBIRD  /content/drive/MyDrive/CV_Birds/train/YELLOW H...
# 47330  YELLOW HEADED BLACKBIRD  /content/drive/MyDrive/CV_Birds/train/YELLOW H...
# 47331  YELLOW HEADED BLACKBIRD  /content/drive/MyDrive/CV_Birds/train/YELLOW H...
#
# [47332 rows x 2 columns]

# %%
db_descriptors = load_descriptors('/content/drive/MyDrive/CV_Birds/features/training/ResNet50v2/resnet_fe_features.npy')
db_descriptors.shape
# Out:
# (47332, 2048)

# %% [markdown]
# ### Create annot and load descriptors for the test set

# %%
query_annot = create_annot('/content/drive/MyDrive/CV_Birds/test')
query_annot
# Out:
#                      identity                                         image_path
# 0       AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/test/AFRICAN C...
# 1       AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/test/AFRICAN C...
# 2       AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/test/AFRICAN C...
# 3       AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/test/AFRICAN C...
# 4       AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/test/AFRICAN C...
# ...                       ...                                                ...
# 1620  YELLOW HEADED BLACKBIRD  /content/drive/MyDrive/CV_Birds/test/YELLOW HE...
# 1621  YELLOW HEADED BLACKBIRD  /content/drive/MyDrive/CV_Birds/test/YELLOW HE...
# 1622  YELLOW HEADED BLACKBIRD  /content/drive/MyDrive/CV_Birds/test/YELLOW HE...
# 1623  YELLOW HEADED BLACKBIRD  /content/drive/MyDrive/CV_Birds/test/YELLOW HE...
# 1624  YELLOW HEADED BLACKBIRD  /content/drive/MyDrive/CV_Birds/test/YELLOW HE...
#
# [1625 rows x 2 columns]

# %%
query_descriptors = load_descriptors('/content/drive/MyDrive/CV_Birds/features/test/ResNet50v2/resnet50_fe_features.npy')
query_descriptors.shape
# Out:
# (1625, 2048)

# %% [markdown]
# To run our tests we select only the first image of each species within the test set. Please note that within the test set we have 5 images per species.

# %%
queries_indexes = [x for x in range(325*5) if x%5 == 0]

# %% [markdown]
# ### Create PP-Index

# %%
# !rm /content/drive/MyDrive/CV_Birds/performance/feature_extraction/index/FE-no-distr_tree_5rnd_euclidean/*
# !rm -r /content/drive/MyDrive/CV_Birds/performance/feature_extraction/index/FE-no-distr_tree_5rnd_euclidean/tree_structure/*
# Out:
# rm: cannot remove '/content/drive/MyDrive/CV_Birds/performance/feature_extraction/index/FE-no-distr_tree_5rnd_euclidean/tree_structure': Is a directory

# %%
def get_descriptor_from_id(id_object):
  return db_descriptors[id_object]

# %%
# %cd "/content/drive/MyDrive/CV_Birds/Notebooks/PP-Index"
# %run PPIndex.ipynb
# Out:
# /content/drive/.shortcut-targets-by-id/1rI5YNBuaSlCB__w522WEkHjw-nFuvIo0/CV_Birds/Notebooks/PP-Index

# %%
# same pivots of other test
with open('/content/drive/MyDrive/CV_Birds/performance/feature_extraction/index/pivots.npy', 'rb') as f:
  pivots = np.load(f, allow_pickle=True)
pivots
# Out:
# array([[46.1681   ,  4.6321344, 12.098874 , ...,  0.       ,  0.       ,
#          0.       ],
#        [17.718864 ,  6.980528 , 17.920225 , ...,  0.       ,  0.       ,
#          0.       ],
#        [19.636652 ,  0.       ,  1.7356032, ...,  0.       ,  0.       ,
#          0.       ],
#        [41.63208  , 10.3063345, 18.537355 , ...,  0.       ,  0.       ,
#          0.       ],
#        [38.335625 ,  9.505913 , 12.09403  , ...,  0.       ,  0.       ,
#          0.       ]], dtype=float32)

# %%
rnd_pp_tree = PrefixTree(pivots, length=3, distance_metric='euclidean', base_directory="/content", tree_file='tree_structure')
if rnd_pp_tree.is_empty():
  rnd_pp_tree.insert_objects_into_tree(range(len(db_descriptors)))
  rnd_pp_tree.save()
# Out:
# [WARNING]: Tree is still empty
# Inserting objects into tree_structure ...
# --- Insertion into tree tree_structure completed: 47.010 seconds ---

# %% [markdown]
# ### Compute mAP

# %%
birds_db = db_annot.loc[db_annot['identity'] != 'mirflickr']
counts = birds_db.groupby('identity').count()
print("Minimum number of images per species:", int(counts.min()))
print("Maximum number of images per species:", int(counts.max()))
print("Average number of images:", float(counts.sum()/325))
# Out:
# Minimum number of images per species: 116
# Maximum number of images per species: 249
# Average number of images: 145.63692307692307

# %% [markdown]
# Since at most we have 249 images per species, we use $n=250$.

# %%
n = 250

# %% [markdown]
# The formula for Average Precision is the following:
#
# > $AP@n=\frac{1}{GTP}\sum_{k=1}^{n}P@k×rel@k$
#
# where $GTP$ refers to the total number of ground truth positives, $n$ refers to the total number of images we are interested in, $P@k$ refers to the precision@k and $rel@k$ is a relevance function.
#
# The relevance function is an indicator function which equals 1 if the document at rank $k$ is relevant and equals to 0 otherwise.

# %%
def compute_ap(query_index, retrieved_ids):
  query_identity = query_annot['identity'][query_index]
  print(query_index//5, query_identity)
  GTP = len(db_annot.loc[db_annot['identity'] == query_identity])
  relevant = 0
  precision_summation = 0
  for k, id in enumerate(retrieved_ids):
    if db_annot['identity'][id] == query_identity: # relevant result
      relevant = relevant + 1
      precision_at_k = relevant/(k+1)
      precision_summation = precision_summation + precision_at_k
  return (query_identity, precision_summation/GTP)

# %% [markdown]
# For each query, $Q$, we can calculate a corresponding $AP$. Then, the $mAP$ is simply the mean of all the queries that were made.
# > $mAP = \frac{1}{N}\sum_{i=1}^{N}AP_i$
#
# In our case, $N=325$ (one query per species)

# %%
def rnd_pivots_queries(query_index, n):
  start_time = time.time()
  ids, distances = rnd_pp_tree.find_nearest_neighbors(query_descriptors[query_index], n)
  end_time = time.time()
  ids = ids.tolist()
  return compute_ap(query_index, ids) + (end_time - start_time,)

# %%
aps = []
for query_index in queries_indexes:
  aps.append(rnd_pivots_queries(query_index, n))
# Out:
# 0 AFRICAN CROWNED CRANE
# 1 AFRICAN FIREFINCH
# 2 ALBATROSS
# 3 ALEXANDRINE PARAKEET
# 4 AMERICAN AVOCET
# 5 AMERICAN BITTERN
# 6 AMERICAN COOT
# 7 AMERICAN GOLDFINCH
# 8 AMERICAN KESTREL
# 9 AMERICAN PIPIT
# 10 AMERICAN REDSTART
# 11 ANHINGA
# 12 ANNAS HUMMINGBIRD
# 13 ANTBIRD
# 14 ARARIPE MANAKIN
# 15 ASIAN CRESTED IBIS
# 16 BALD EAGLE
# 17 BALD IBIS
# 18 BALI STARLING
# 19 BALTIMORE ORIOLE
# 20 BANANAQUIT
# 21 BANDED BROADBILL
# 22 BANDED PITA
# 23 BAR-TAILED GODWIT
# 24 BARN OWL
# 25 BARN SWALLOW
# 26 BARRED PUFFBIRD
# 27 BAY-BREASTED WARBLER
# 28 BEARDED BARBET
# 29 BEARDED BELLBIRD
# 30 BEARDED REEDLING
# 31 BELTED KINGFISHER
# 32 BIRD OF PARADISE
# 33 BLACK & YELLOW bROADBILL
# 34 BLACK BAZA
# 35 BLACK FRANCOLIN
# 36 BLACK SKIMMER
# 37 BLACK SWAN
# 38 BLACK TAIL CRAKE
# 39 BLACK THROATED BUSHTIT
# 40 BLACK THROATED WARBLER
# 41 BLACK VULTURE
# 42 BLACK-CAPPED CHICKADEE
# 43 BLACK-NECKED GREBE
# 44 BLACK-THROATED SPARROW
# 45 BLACKBURNIAM WARBLER
# 46 BLONDE CRESTED WOODPECKER
# 47 BLUE COAU
# 48 BLUE GROUSE
# 49 BLUE HERON
# 50 BLUE THROATED TOUCANET
# 51 BOBOLINK
# 52 BORNEAN BRISTLEHEAD
# 53 BORNEAN LEAFBIRD
# 54 BORNEAN PHEASANT
# 55 BRANDT CORMARANT
# 56 BROWN CREPPER
# 57 BROWN NOODY
# 58 BROWN THRASHER
# 59 BULWERS PHEASANT
# 60 CACTUS WREN
# 61 CALIFORNIA CONDOR
# 62 CALIFORNIA GULL
# 63 CALIFORNIA QUAIL
# 64 CANARY
# 65 CAPE GLOSSY STARLING
# 66 CAPE MAY WARBLER
# 67 CAPPED HERON
# 68 CAPUCHINBIRD
# 69 CARMINE BEE-EATER
# 70 CASPIAN TERN
# 71 CASSOWARY
# 72 CEDAR WAXWING
# 73 CERULEAN WARBLER
# 74 CHARA DE COLLAR
# 75 CHESTNET BELLIED EUPHONIA
# 76 CHIPPING SPARROW
# 77 CHUKAR PARTRIDGE
# 78 CINNAMON TEAL
# 79 CLARKS NUTCRACKER
# 80 COCK OF THE  ROCK
# 81 COCKATOO
# 82 COLLARED ARACARI
# 83 COMMON FIRECREST
# 84 COMMON GRACKLE
# 85 COMMON HOUSE MARTIN
# 86 COMMON LOON
# 87 COMMON POORWILL
# 88 COMMON STARLING
# 89 COUCHS KINGBIRD
# 90 CRESTED AUKLET
# 91 CRESTED CARACARA
# 92 CRESTED NUTHATCH
# 93 CRIMSON SUNBIRD
# 94 CROW
# 95 CROWNED PIGEON
# 96 CUBAN TODY
# 97 CUBAN TROGON
# 98 CURL CRESTED ARACURI
# 99 D-ARNAUDS BARBET
# 100 DARK EYED JUNCO
# 101 DOUBLE BARRED FINCH
# 102 DOUBLE BRESTED CORMARANT
# 103 DOWNY WOODPECKER
# 104 EASTERN BLUEBIRD
# 105 EASTERN MEADOWLARK
# 106 EASTERN ROSELLA
# 107 EASTERN TOWEE
# 108 ELEGANT TROGON
# 109 ELLIOTS  PHEASANT
# 110 EMPEROR PENGUIN
# 111 EMU
# 112 ENGGANO MYNA
# 113 EURASIAN GOLDEN ORIOLE
# 114 EURASIAN MAGPIE
# 115 EVENING GROSBEAK
# 116 FAIRY BLUEBIRD
# 117 FIRE TAILLED MYZORNIS
# 118 FLAME TANAGER
# 119 FLAMINGO
# 120 FRIGATE
# 121 GAMBELS QUAIL
# 122 GANG GANG COCKATOO
# 123 GILA WOODPECKER
# 124 GILDED FLICKER
# 125 GLOSSY IBIS
# 126 GO AWAY BIRD
# 127 GOLD WING WARBLER
# 128 GOLDEN CHEEKED WARBLER
# 129 GOLDEN CHLOROPHONIA
# 130 GOLDEN EAGLE
# 131 GOLDEN PHEASANT
# 132 GOLDEN PIPIT
# 133 GOULDIAN FINCH
# 134 GRAY CATBIRD
# 135 GRAY KINGBIRD
# 136 GRAY PARTRIDGE
# 137 GREAT GRAY OWL
# 138 GREAT KISKADEE
# 139 GREAT POTOO
# 140 GREATOR SAGE GROUSE
# 141 GREEN BROADBILL
# 142 GREEN JAY
# 143 GREEN MAGPIE
# 144 GREY PLOVER
# 145 GROVED BILLED ANI
# 146 GUINEA TURACO
# 147 GUINEAFOWL
# 148 GYRFALCON
# 149 HARLEQUIN DUCK
# 150 HARPY EAGLE
# 151 HAWAIIAN GOOSE
# 152 HELMET VANGA
# 153 HIMALAYAN MONAL
# 154 HOATZIN
# 155 HOODED MERGANSER
# 156 HOOPOES
# 157 HORNBILL
# 158 HORNED GUAN
# 159 HORNED LARK
# 160 HORNED SUNGEM
# 161 HOUSE FINCH
# 162 HOUSE SPARROW
# 163 HYACINTH MACAW
# 164 IMPERIAL SHAQ
# 165 INCA TERN
# 166 INDIAN BUSTARD
# 167 INDIAN PITTA
# 168 INDIAN ROLLER
# 169 INDIGO BUNTING
# 170 IWI
# 171 JABIRU
# 172 JAVA SPARROW
# 173 KAGU
# 174 KAKAPO
# 175 KILLDEAR
# 176 KING VULTURE
# 177 KIWI
# 178 KOOKABURRA
# 179 LARK BUNTING
# 180 LAZULI BUNTING
# 181 LILAC ROLLER
# 182 LONG-EARED OWL
# 183 MAGPIE GOOSE
# 184 MALABAR HORNBILL
# 185 MALACHITE KINGFISHER
# 186 MALAGASY WHITE EYE
# 187 MALEO
# 188 MALLARD DUCK
# 189 MANDRIN DUCK
# 190 MANGROVE CUCKOO
# 191 MARABOU STORK
# 192 MASKED BOOBY
# 193 MASKED LAPWING
# 194 MIKADO  PHEASANT
# 195 MOURNING DOVE
# 196 MYNA
# 197 NICOBAR PIGEON
# 198 NOISY FRIARBIRD
# 199 NORTHERN CARDINAL
# 200 NORTHERN FLICKER
# 201 NORTHERN FULMAR
# 202 NORTHERN GANNET
# 203 NORTHERN GOSHAWK
# 204 NORTHERN JACANA
# 205 NORTHERN MOCKINGBIRD
# 206 NORTHERN PARULA
# 207 NORTHERN RED BISHOP
# 208 NORTHERN SHOVELER
# 209 OCELLATED TURKEY
# 210 OKINAWA RAIL
# 211 ORANGE BRESTED BUNTING
# 212 ORIENTAL BAY OWL
# 213 OSPREY
# 214 OSTRICH
# 215 OVENBIRD
# 216 OYSTER CATCHER
# 217 PAINTED BUNTIG
# 218 PALILA
# 219 PARADISE TANAGER
# 220 PARAKETT  AKULET
# 221 PARUS MAJOR
# 222 PATAGONIAN SIERRA FINCH
# 223 PEACOCK
# 224 PELICAN
# 225 PEREGRINE FALCON
# 226 PHILIPPINE EAGLE
# 227 PINK ROBIN
# 228 POMARINE JAEGER
# 229 PUFFIN
# 230 PURPLE FINCH
# 231 PURPLE GALLINULE
# 232 PURPLE MARTIN
# 233 PURPLE SWAMPHEN
# 234 PYGMY KINGFISHER
# 235 QUETZAL
# 236 RAINBOW LORIKEET
# 237 RAZORBILL
# 238 RED BEARDED BEE EATER
# 239 RED BELLIED PITTA
# 240 RED BROWED FINCH
# 241 RED FACED CORMORANT
# 242 RED FACED WARBLER
# 243 RED FODY
# 244 RED HEADED DUCK
# 245 RED HEADED WOODPECKER
# 246 RED HONEY CREEPER
# 247 RED NAPED TROGON
# 248 RED TAILED HAWK
# 249 RED TAILED THRUSH
# 250 RED WINGED BLACKBIRD
# 251 RED WISKERED BULBUL
# 252 REGENT BOWERBIRD
# 253 RING-NECKED PHEASANT
# 254 ROADRUNNER
# 255 ROBIN
# 256 ROCK DOVE
# 257 ROSY FACED LOVEBIRD
# 258 ROUGH LEG BUZZARD
# 259 ROYAL FLYCATCHER
# 260 RUBY THROATED HUMMINGBIRD
# 261 RUDY KINGFISHER
# 262 RUFOUS KINGFISHER
# 263 RUFUOS MOTMOT
# 264 SAMATRAN THRUSH
# 265 SAND MARTIN
# 266 SANDHILL CRANE
# 267 SATYR TRAGOPAN
# 268 SCARLET CROWNED FRUIT DOVE
# 269 SCARLET IBIS
# 270 SCARLET MACAW
# 271 SCARLET TANAGER
# 272 SHOEBILL
# 273 SHORT BILLED DOWITCHER
# 274 SMITHS LONGSPUR
# 275 SNOWY EGRET
# 276 SNOWY OWL
# 277 SORA
# 278 SPANGLED COTINGA
# 279 SPLENDID WREN
# 280 SPOON BILED SANDPIPER
# 281 SPOONBILL
# 282 SPOTTED CATBIRD
# 283 SRI LANKA BLUE MAGPIE
# 284 STEAMER DUCK
# 285 STORK BILLED KINGFISHER
# 286 STRAWBERRY FINCH
# 287 STRIPED OWL
# 288 STRIPPED MANAKIN
# 289 STRIPPED SWALLOW
# 290 SUPERB STARLING
# 291 SWINHOES PHEASANT
# 292 TAIWAN MAGPIE
# 293 TAKAHE
# 294 TASMANIAN HEN
# 295 TEAL DUCK
# 296 TIT MOUSE
# 297 TOUCHAN
# 298 TOWNSENDS WARBLER
# 299 TREE SWALLOW
# 300 TROPICAL KINGBIRD
# 301 TRUMPTER SWAN
# 302 TURKEY VULTURE
# 303 TURQUOISE MOTMOT
# 304 UMBRELLA BIRD
# 305 VARIED THRUSH
# 306 VENEZUELIAN TROUPIAL
# 307 VERMILION FLYCATHER
# 308 VICTORIA CROWNED PIGEON
# 309 VIOLET GREEN SWALLOW
# 310 VULTURINE GUINEAFOWL
# 311 WALL CREAPER
# 312 WATTLED CURASSOW
# 313 WHIMBREL
# 314 WHITE BROWED CRAKE
# 315 WHITE CHEEKED TURACO
# 316 WHITE NECKED RAVEN
# 317 WHITE TAILED TROPIC
# 318 WHITE THROATED BEE EATER
# 319 WILD TURKEY
# 320 WILSONS BIRD OF PARADISE
# 321 WOOD DUCK
# 322 YELLOW BELLIED FLOWERPECKER
# 323 YELLOW CACIQUE
# 324 YELLOW HEADED BLACKBIRD

# %%
aps
# Out:
# [('AFRICAN CROWNED CRANE', 0.007605518383346851, 4.1408851146698),
#  ('AFRICAN FIREFINCH', 0.0002505863253298698, 3.7223854064941406),
#  ('ALBATROSS', 0.00038894532574254207, 2.863150119781494),
#  ('ALEXANDRINE PARAKEET', 0.000219845513963161, 3.660921096801758),
#  ('AMERICAN AVOCET', 0.00010743446497636442, 1.1712167263031006),
#  ('AMERICAN BITTERN', 0.0007411120777962841, 0.9067449569702148),
#  ('AMERICAN COOT', 0.001491090188317085, 1.440786600112915),
#  ('ORIENTAL BAY OWL', 0.011440051590341024, 2.887690544128418),
#  ('OSPREY', 0.0, 0.8798754215240479),
#  ('OSTRICH', 5.456430403230207e-05, 0.876840353012085),
#  ('OVENBIRD', 0.0009574380661105053, 0.9108467102050781),
#  ('OYSTER CATCHER', 0.004474483505638044, 2.9405460357666016),
#  ('PAINTED BUNTIG', 0.0037099223860605846, 3.575885057449341),
#  ('PALILA', 0.0002525252525252525, 3.6082546710968018),
#  ('PARADISE TANAGER', 0.028164960268406005, 3.6707170009613037),
#  ('PARAKETT  AKULET', 0.0002747252747252747, 3.6250061988830566),
#  ('PARUS MAJOR', 0.0, 2.8942582607269287),
#  ('PATAGONIAN SIERRA FINCH', 4.180602006688963e-05, 1.4013690948486328),
#  ('PEACOCK', 0.06205184257014864, 0.9031929969787598),
#  ('PELICAN', 0.0010416666666666667, 2.8688693046569824),
#  ('PEREGRINE FALCON', 0.0004367131467971804, 1.1579179763793945),
#  ('PHILIPPINE EAGLE', 0.013310973026492257, 3.639749526977539),
#  ('PINK ROBIN', 0.010627230694354315, 3.6730167865753174),
#  ('POMARINE JAEGER', 0.009563204026608214, 2.934293746948242),
#  ('PUFFIN', 4.2896362388469456e-05, 2.8846731185913086),
#  ('PURPLE FINCH', 0.0008721693619308188, 2.895848512649536),
#  ('PURPLE GALLINULE', 0.0002474767080745342, 1.1401848793029785),
#  ('PURPLE MARTIN', 0.0, 1.3480732440948486),
#  ('PURPLE SWAMPHEN', 0.00030426366663710667, 0.41553688049316406),
#  ('PYGMY KINGFISHER', 0.0018098513441483421, 3.584287166595459),
#  ('QUETZAL', 0.003688197767145135, 0.9214143753051758),
#  ('RAINBOW LORIKEET', 0.00010585371017254155, 1.4300191402435303),
#  ('RAZORBILL', 0.000496049863899934, 2.8815386295318604),
#  ('RED BEARDED BEE EATER', 0.00037609766268657265, 0.4022786617279053),
#  ('RED BELLIED PITTA', 0.0011711687377527083, 0.9020500183105469),
#  ('RED BROWED FINCH', 0.007974265518790878, 2.888991594314575),
#  ('RED FACED CORMORANT', 5.7474567503879534e-05, 0.6597566604614258),
#  ('RED FACED WARBLER', 0.00013969302083153396, 2.911654233932495),
#  ('RED FODY', 0.03474686818419584, 3.6366074085235596),
#  ('RED HEADED DUCK', 0.0, 3.614901542663574),
#  ('RED HEADED WOODPECKER', 0.00020111467479888532, 2.8596513271331787),
#  ('RED HONEY CREEPER', 0.004893822110803242, 0.41544342041015625),
#  ('RED NAPED TROGON', 0.005934373339534351, 3.5953516960144043),
#  ('RED TAILED HAWK', 0.0007835025360362559, 2.8698740005493164),
#  ('RED TAILED THRUSH', 0.0002712073202870749, 1.18084716796875),
#  ('RED WINGED BLACKBIRD', 0.0017274020333399585, 1.1461069583892822),
#  ('RED WISKERED BULBUL', 0.0, 2.885272741317749),
#  ('REGENT BOWERBIRD', 0.00028907526749098083, 3.621774673461914),
#  ('RING-NECKED PHEASANT', 0.00011804331402669353, 1.1795012950897217),
#  ('TEAL DUCK', 0.0002990478317038549, 1.1544523239135742),
#  ('TIT MOUSE', 0.0017646841141584692, 3.644509792327881),
#  ('TOUCHAN', 0.0002881205673758865, 3.598423719406128),
#  ('TOWNSENDS WARBLER', 5.411255411255411e-05, 1.170949935913086),
#  ('TREE SWALLOW', 3.890747801727492e-05, 3.6091301441192627),
#  ('TROPICAL KINGBIRD', 3.1709791983764585e-05, 0.8481307029724121),
#  ('TRUMPTER SWAN', 0.015701197365861598, 2.849561929702759),
#  ('TURKEY VULTURE', 0.007004841808793984, 0.8794987201690674),
#  ('TURQUOISE MOTMOT', 0.000540111976282189, 2.8960154056549072),
#  ('UMBRELLA BIRD', 0.0016459973813430623, 1.4962258338928223),
#  ('VARIED THRUSH', 0.0002415792941329581, 1.141430377960205),
#  ('VENEZUELIAN TROUPIAL', 0.0001586248721495053, 3.595726251602173),
#  ('VERMILION FLYCATHER', 0.0011877207031203423, 3.61258602142334),
#  ('VICTORIA CROWNED PIGEON', 0.0002545139035113226, 0.8018746376037598),
#  ('VIOLET GREEN SWALLOW', 2.2717462913741793e-05, 0.5996286869049072),
#  ('VULTURINE GUINEAFOWL', 0.0004841261393221918, 0.6814353466033936),
#  ('WALL CREAPER', 0.005120332954464012, 2.899693250656128),
#  ('WATTLED CURASSOW', 0.0, 3.6061782836914062),
#  ('WHIMBREL', 0.0008719398621221903, 0.9223387241363525),
#  ('WHITE BROWED CRAKE', 2.7631942525559546e-05, 0.42651891708374023),
#  ('WHITE CHEEKED TURACO', 0.0012933559720935928, 3.594984531402588),
#  ('WHITE NECKED RAVEN', 0.00426706827309237, 1.4751574993133545),
#  ('WHITE TAILED TROPIC', 0.0030880230880230885, 1.4014544486999512),
#  ('WHITE THROATED BEE EATER', 9.592437579685132e-05, 2.903214454650879),
#  ('WILD TURKEY', 0.0015203848715577345, 0.9220514297485352),
#  ('WILSONS BIRD OF PARADISE', 0.0, 1.4784553050994873),
#  ('WOOD DUCK', 0.0014368394233823603, 3.6034164428710938),
#  ('YELLOW BELLIED FLOWERPECKER', 5.0999592003263974e-05, 3.5640764236450195),
#  ('YELLOW CACIQUE', 0.0, 3.614295482635498),
#  ('YELLOW HEADED BLACKBIRD', 0.01135909146830802, 1.4051098823547363)]

# %%
ap_at_n = np.array([ap[1] for ap in aps])
query_time = np.array(([ap[2] for ap in aps]))

# %%
mAP_at_n = np.mean(ap_at_n, axis=0)
avg_query_time = np.mean(query_time, axis=0)
print("mAP:", mAP_at_n)
print("avg. query time: ", avg_query_time)
# Out:
# mAP: 0.0038791863862901003
# avg. query time:  2.12892470066364

# %%
save_results('/content/drive/MyDrive/CV_Birds/performance/feature_extraction/index/FE-no-distr_tree_5rnd_euclidean', 'FE-no-distr_tree_5rnd_euclidean_results', aps)

# %%
# !cp /content/tree_structure* /content/drive/MyDrive/CV_Birds/performance/feature_extraction/index/FE-no-distr_tree_5rnd_euclidean/tree_structure/
