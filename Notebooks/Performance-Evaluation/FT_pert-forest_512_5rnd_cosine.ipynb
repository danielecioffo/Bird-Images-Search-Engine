# %% [markdown]
# ## Import libraries

# %%
from google.colab import drive
from pathlib import Path
from matplotlib import pyplot as plt 
import pandas as pd
import numpy as np
import time
import os
import csv
import concurrent.futures

# %% [markdown]
# ## Utility functions

# %% [markdown]
# ### Create annot and load descriptors

# %%
def create_annot(path):
  image_list = list(Path(path).glob('*/*.jpg'))
  # the identity name is in the path (the name of the parent directory)
  names_list = [i.parent.name for i in image_list]  # get the identity of each image
  # keep info in a pandas DataFrame
  annot = pd.DataFrame({'identity': names_list, 'image_path': image_list})
  return annot

def concatenate_annots(list_of_paths):
  concat_annot = pd.DataFrame()
  with concurrent.futures.ThreadPoolExecutor() as executor:
    annots = [executor.submit(create_annot, path) for path in list_of_paths]
    for annot in annots:
      new_annot = annot.result()
      concat_annot = concat_annot.append(new_annot, ignore_index = True)
    return concat_annot

# %%
def load_descriptors(path):
  with open(path, 'rb') as file:
    return np.load(file)

def concatenate_descriptors(list_of_paths):
  concat_descriptors = None
  with concurrent.futures.ThreadPoolExecutor() as executor:
    descriptors = [executor.submit(load_descriptors, path) for path in list_of_paths]
    for descriptor in descriptors:
      new_descriptor = descriptor.result()
      if concat_descriptors is None:
        concat_descriptors = new_descriptor
      else:
        concat_descriptors = np.concatenate([concat_descriptors, new_descriptor])
    return concat_descriptors

# %% [markdown]
# ### Create pivots

# %%
def generate_pivots(descriptors, n, strategy="rnd"):
  if strategy == "kMED":
    kmedoids = sklearn_extra.cluster.KMedoids(n_clusters=n).fit(descriptors)
    return kmedoids.cluster_centers_
  if strategy != "rnd":
    print(strategy, "was not implemented. Random pivots were returned")
  pivots_id = np.random.choice(np.arange(len(descriptors)), size=n)
  return descriptors[pivots_id]

def generate_list_of_pivots(descriptors, t, n, strategy="rnd"):
  list_of_pivots = []
  with concurrent.futures.ThreadPoolExecutor() as executor:
    pivots = [executor.submit(generate_pivots, descriptors, n, strategy) for i in range(t)]
    for pivot in concurrent.futures.as_completed(pivots):
      new_pivot = pivot.result()
      list_of_pivots.append(new_pivot)
    return list_of_pivots

# %% [markdown]
# ### Save test results

# %%
def save_results(dir, file_name, results):
  with open(os.path.join(dir, file_name +".csv"), 'w') as f:
    writer = csv.writer(f)
    # write the header
    writer.writerow(["CLASS", "AP", "QUERY TIME"])
    # write the data
    for r in results:
      writer.writerow(r)

# %% [markdown]
# ## Test Performance

# %%
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Create annot and load descriptors for the database

# %%
db_annot = concatenate_annots(['/content/drive/MyDrive/CV_Birds/train', '/content/drive/MyDrive/CV_Birds/mirflickr25k'])
db_annot
# Out:
#                     identity                                         image_path
# 0      AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/train/AFRICAN ...
# 1      AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/train/AFRICAN ...
# 2      AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/train/AFRICAN ...
# 3      AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/train/AFRICAN ...
# 4      AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/train/AFRICAN ...
# ...                      ...                                                ...
# 72327              mirflickr  /content/drive/MyDrive/CV_Birds/mirflickr25k/m...
# 72328              mirflickr  /content/drive/MyDrive/CV_Birds/mirflickr25k/m...
# 72329              mirflickr  /content/drive/MyDrive/CV_Birds/mirflickr25k/m...
# 72330              mirflickr  /content/drive/MyDrive/CV_Birds/mirflickr25k/m...
# 72331              mirflickr  /content/drive/MyDrive/CV_Birds/mirflickr25k/m...
#
# [72332 rows x 2 columns]

# %%
db_descriptors = concatenate_descriptors(['/content/drive/MyDrive/CV_Birds/features/training/ResNet152v2/OneDense512_Dropout_fine_tuning.npy','/content/drive/MyDrive/CV_Birds/features/distractor/ResNet152v2/OneDense512_Dropout_fine_tuning.npy'])
db_descriptors.shape
# Out:
# (72332, 512)

# %% [markdown]
# ### Create annot and load descriptors for the test set

# %%
query_annot = create_annot('/content/drive/MyDrive/CV_Birds/test')
query_annot
# Out:
#                      identity                                         image_path
# 0       AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/test/AFRICAN C...
# 1       AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/test/AFRICAN C...
# 2       AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/test/AFRICAN C...
# 3       AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/test/AFRICAN C...
# 4       AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/test/AFRICAN C...
# ...                       ...                                                ...
# 1620  YELLOW HEADED BLACKBIRD  /content/drive/MyDrive/CV_Birds/test/YELLOW HE...
# 1621  YELLOW HEADED BLACKBIRD  /content/drive/MyDrive/CV_Birds/test/YELLOW HE...
# 1622  YELLOW HEADED BLACKBIRD  /content/drive/MyDrive/CV_Birds/test/YELLOW HE...
# 1623  YELLOW HEADED BLACKBIRD  /content/drive/MyDrive/CV_Birds/test/YELLOW HE...
# 1624  YELLOW HEADED BLACKBIRD  /content/drive/MyDrive/CV_Birds/test/YELLOW HE...
#
# [1625 rows x 2 columns]

# %%
query_descriptors = load_descriptors('/content/drive/MyDrive/CV_Birds/features/test/ResNet152v2/OneDense512_Dropout_fine_tuning.npy')
query_descriptors.shape
# Out:
# (1625, 512)

# %% [markdown]
# To run our tests we select only the first image of each species within the test set. Please note that within the test set we have 5 images per species.

# %%
queries_indexes = [x for x in range(325*5) if x%5 == 0]

# %% [markdown]
# ### Create PP-Index

# %%
# !rm /content/drive/MyDrive/CV_Birds/performance/fine_tuning/index/FT_pert-forest_512_5rnd_cosine/*
# !rm -r /content/drive/MyDrive/CV_Birds/performance/fine_tuning/index/FT_pert-forest_512_5rnd_cosine/pert_forest_structure/*
# Out:
# rm: cannot remove '/content/drive/MyDrive/CV_Birds/performance/fine_tuning/index/FT_pert-forest_512_5rnd_cosine/pert_forest_structure': Is a directory

# %%
def get_descriptor_from_id(id_object):
  return db_descriptors[id_object]

# %%
# %cd "/content/drive/MyDrive/CV_Birds/Notebooks/PP-Index"
# %run PPIndex.ipynb
# Out:
# /content/drive/.shortcut-targets-by-id/1rI5YNBuaSlCB__w522WEkHjw-nFuvIo0/CV_Birds/Notebooks/PP-Index

# %%
pivots = generate_list_of_pivots(db_descriptors, t=3, n=5, strategy="rnd")
rnd_pp_forest = PrefixForest(pivots, length=3, distance_metric='cosine', base_directory="/content", forest_file='pert_forest_structure')
rnd_pp_forest.insert_objects_into_forest(range(len(db_descriptors)))
rnd_pp_forest.save()
# Out:
# [WARNING]: Tree is still empty
# [WARNING]: Tree is still empty
# [WARNING]: Tree is still empty
# [WARNING]: Forest is still empty
# Inserting objects into tree1 ...
# Inserting objects into tree2 ...
# Inserting objects into tree3 ...
# --- Insertion into tree tree2 completed: 241.511 seconds ---
# --- Insertion into tree tree1 completed: 258.744 seconds ---
# --- Insertion into tree tree3 completed: 262.447 seconds ---

# %% [markdown]
# ### Compute mAP

# %%
birds_db = db_annot.loc[db_annot['identity'] != 'mirflickr']
counts = birds_db.groupby('identity').count()
print("Minimum number of images per species:", int(counts.min()))
print("Maximum number of images per species:", int(counts.max()))
print("Average number of images:", float(counts.sum()/325))
# Out:
# Minimum number of images per species: 116
# Maximum number of images per species: 249
# Average number of images: 145.63692307692307

# %% [markdown]
# Since at most we have 249 images per species, we use $n=250$.

# %%
n = 250

# %% [markdown]
# The formula for Average Precision is the following:
#
# > $AP@n=\frac{1}{GTP}\sum_{k=1}^{n}P@k×rel@k$
#
# where $GTP$ refers to the total number of ground truth positives, $n$ refers to the total number of images we are interested in, $P@k$ refers to the precision@k and $rel@k$ is a relevance function.
#
# The relevance function is an indicator function which equals 1 if the document at rank $k$ is relevant and equals to 0 otherwise.

# %%
def compute_ap(query_index, retrieved_ids):
  query_identity = query_annot['identity'][query_index]
  print(query_index//5, query_identity)
  GTP = len(db_annot.loc[db_annot['identity'] == query_identity])
  relevant = 0
  precision_summation = 0
  for k, id in enumerate(retrieved_ids):
    if db_annot['identity'][id] == query_identity: # relevant result
      relevant = relevant + 1
      precision_at_k = relevant/(k+1)
      precision_summation = precision_summation + precision_at_k
  return (query_identity, precision_summation/GTP)

# %% [markdown]
# For each query, $Q$, we can calculate a corresponding $AP$. Then, the $mAP$ is simply the mean of all the queries that were made.
# > $mAP = \frac{1}{N}\sum_{i=1}^{N}AP_i$
#
# In our case, $N=325$ (one query per species)

# %%
def rnd_pivots_queries(query_index, n):
  start_time = time.time()
  ids, distances = rnd_pp_forest.find_nearest_neighbors(query_descriptors[query_index], n, perturbations=3)
  end_time = time.time()
  ids = ids.tolist()
  return compute_ap(query_index, ids) + (end_time - start_time,)

# %%
aps = []
for query_index in queries_indexes:
  aps.append(rnd_pivots_queries(query_index, n))
# Out:
# 0 AFRICAN CROWNED CRANE
# 1 AFRICAN FIREFINCH
# 2 ALBATROSS
# 3 ALEXANDRINE PARAKEET
# 4 AMERICAN AVOCET
# 5 AMERICAN BITTERN
# 6 AMERICAN COOT
# 7 AMERICAN GOLDFINCH
# 8 AMERICAN KESTREL
# 9 AMERICAN PIPIT
# 10 AMERICAN REDSTART
# 11 ANHINGA
# 12 ANNAS HUMMINGBIRD
# 13 ANTBIRD
# 14 ARARIPE MANAKIN
# 15 ASIAN CRESTED IBIS
# 16 BALD EAGLE
# 17 BALD IBIS
# 18 BALI STARLING
# 19 BALTIMORE ORIOLE
# 20 BANANAQUIT
# 21 BANDED BROADBILL
# 22 BANDED PITA
# 23 BAR-TAILED GODWIT
# 24 BARN OWL
# 25 BARN SWALLOW
# 26 BARRED PUFFBIRD
# 27 BAY-BREASTED WARBLER
# 28 BEARDED BARBET
# 29 BEARDED BELLBIRD
# 30 BEARDED REEDLING
# 31 BELTED KINGFISHER
# 32 BIRD OF PARADISE
# 33 BLACK & YELLOW bROADBILL
# 34 BLACK BAZA
# 35 BLACK FRANCOLIN
# 36 BLACK SKIMMER
# 37 BLACK SWAN
# 38 BLACK TAIL CRAKE
# 39 BLACK THROATED BUSHTIT
# 40 BLACK THROATED WARBLER
# 41 BLACK VULTURE
# 42 BLACK-CAPPED CHICKADEE
# 43 BLACK-NECKED GREBE
# 44 BLACK-THROATED SPARROW
# 45 BLACKBURNIAM WARBLER
# 46 BLONDE CRESTED WOODPECKER
# 47 BLUE COAU
# 48 BLUE GROUSE
# 49 BLUE HERON
# 50 BLUE THROATED TOUCANET
# 51 BOBOLINK
# 52 BORNEAN BRISTLEHEAD
# 53 BORNEAN LEAFBIRD
# 54 BORNEAN PHEASANT
# 55 BRANDT CORMARANT
# 56 BROWN CREPPER
# 57 BROWN NOODY
# 58 BROWN THRASHER
# 59 BULWERS PHEASANT
# 60 CACTUS WREN
# 61 CALIFORNIA CONDOR
# 62 CALIFORNIA GULL
# 63 CALIFORNIA QUAIL
# 64 CANARY
# 65 CAPE GLOSSY STARLING
# 66 CAPE MAY WARBLER
# 67 CAPPED HERON
# 68 CAPUCHINBIRD
# 69 CARMINE BEE-EATER
# 70 CASPIAN TERN
# 71 CASSOWARY
# 72 CEDAR WAXWING
# 73 CERULEAN WARBLER
# 74 CHARA DE COLLAR
# 75 CHESTNET BELLIED EUPHONIA
# 76 CHIPPING SPARROW
# 77 CHUKAR PARTRIDGE
# 78 CINNAMON TEAL
# 79 CLARKS NUTCRACKER
# 80 COCK OF THE  ROCK
# 81 COCKATOO
# 82 COLLARED ARACARI
# 83 COMMON FIRECREST
# 84 COMMON GRACKLE
# 85 COMMON HOUSE MARTIN
# 86 COMMON LOON
# 87 COMMON POORWILL
# 88 COMMON STARLING
# 89 COUCHS KINGBIRD
# 90 CRESTED AUKLET
# 91 CRESTED CARACARA
# 92 CRESTED NUTHATCH
# 93 CRIMSON SUNBIRD
# 94 CROW
# 95 CROWNED PIGEON
# 96 CUBAN TODY
# 97 CUBAN TROGON
# 98 CURL CRESTED ARACURI
# 99 D-ARNAUDS BARBET
# 100 DARK EYED JUNCO
# 101 DOUBLE BARRED FINCH
# 102 DOUBLE BRESTED CORMARANT
# 103 DOWNY WOODPECKER
# 104 EASTERN BLUEBIRD
# 105 EASTERN MEADOWLARK
# 106 EASTERN ROSELLA
# 107 EASTERN TOWEE
# 108 ELEGANT TROGON
# 109 ELLIOTS  PHEASANT
# 110 EMPEROR PENGUIN
# 111 EMU
# 112 ENGGANO MYNA
# 113 EURASIAN GOLDEN ORIOLE
# 114 EURASIAN MAGPIE
# 115 EVENING GROSBEAK
# 116 FAIRY BLUEBIRD
# 117 FIRE TAILLED MYZORNIS
# 118 FLAME TANAGER
# 119 FLAMINGO
# 120 FRIGATE
# 121 GAMBELS QUAIL
# 122 GANG GANG COCKATOO
# 123 GILA WOODPECKER
# 124 GILDED FLICKER
# 125 GLOSSY IBIS
# 126 GO AWAY BIRD
# 127 GOLD WING WARBLER
# 128 GOLDEN CHEEKED WARBLER
# 129 GOLDEN CHLOROPHONIA
# 130 GOLDEN EAGLE
# 131 GOLDEN PHEASANT
# 132 GOLDEN PIPIT
# 133 GOULDIAN FINCH
# 134 GRAY CATBIRD
# 135 GRAY KINGBIRD
# 136 GRAY PARTRIDGE
# 137 GREAT GRAY OWL
# 138 GREAT KISKADEE
# 139 GREAT POTOO
# 140 GREATOR SAGE GROUSE
# 141 GREEN BROADBILL
# 142 GREEN JAY
# 143 GREEN MAGPIE
# 144 GREY PLOVER
# 145 GROVED BILLED ANI
# 146 GUINEA TURACO
# 147 GUINEAFOWL
# 148 GYRFALCON
# 149 HARLEQUIN DUCK
# 150 HARPY EAGLE
# 151 HAWAIIAN GOOSE
# 152 HELMET VANGA
# 153 HIMALAYAN MONAL
# 154 HOATZIN
# 155 HOODED MERGANSER
# 156 HOOPOES
# 157 HORNBILL
# 158 HORNED GUAN
# 159 HORNED LARK
# 160 HORNED SUNGEM
# 161 HOUSE FINCH
# 162 HOUSE SPARROW
# 163 HYACINTH MACAW
# 164 IMPERIAL SHAQ
# 165 INCA TERN
# 166 INDIAN BUSTARD
# 167 INDIAN PITTA
# 168 INDIAN ROLLER
# 169 INDIGO BUNTING
# 170 IWI
# 171 JABIRU
# 172 JAVA SPARROW
# 173 KAGU
# 174 KAKAPO
# 175 KILLDEAR
# 176 KING VULTURE
# 177 KIWI
# 178 KOOKABURRA
# 179 LARK BUNTING
# 180 LAZULI BUNTING
# 181 LILAC ROLLER
# 182 LONG-EARED OWL
# 183 MAGPIE GOOSE
# 184 MALABAR HORNBILL
# 185 MALACHITE KINGFISHER
# 186 MALAGASY WHITE EYE
# 187 MALEO
# 188 MALLARD DUCK
# 189 MANDRIN DUCK
# 190 MANGROVE CUCKOO
# 191 MARABOU STORK
# 192 MASKED BOOBY
# 193 MASKED LAPWING
# 194 MIKADO  PHEASANT
# 195 MOURNING DOVE
# 196 MYNA
# 197 NICOBAR PIGEON
# 198 NOISY FRIARBIRD
# 199 NORTHERN CARDINAL
# 200 NORTHERN FLICKER
# 201 NORTHERN FULMAR
# 202 NORTHERN GANNET
# 203 NORTHERN GOSHAWK
# 204 NORTHERN JACANA
# 205 NORTHERN MOCKINGBIRD
# 206 NORTHERN PARULA
# 207 NORTHERN RED BISHOP
# 208 NORTHERN SHOVELER
# 209 OCELLATED TURKEY
# 210 OKINAWA RAIL
# 211 ORANGE BRESTED BUNTING
# 212 ORIENTAL BAY OWL
# 213 OSPREY
# 214 OSTRICH
# 215 OVENBIRD
# 216 OYSTER CATCHER
# 217 PAINTED BUNTIG
# 218 PALILA
# 219 PARADISE TANAGER
# 220 PARAKETT  AKULET
# 221 PARUS MAJOR
# 222 PATAGONIAN SIERRA FINCH
# 223 PEACOCK
# 224 PELICAN
# 225 PEREGRINE FALCON
# 226 PHILIPPINE EAGLE
# 227 PINK ROBIN
# 228 POMARINE JAEGER
# 229 PUFFIN
# 230 PURPLE FINCH
# 231 PURPLE GALLINULE
# 232 PURPLE MARTIN
# 233 PURPLE SWAMPHEN
# 234 PYGMY KINGFISHER
# 235 QUETZAL
# 236 RAINBOW LORIKEET
# 237 RAZORBILL
# 238 RED BEARDED BEE EATER
# 239 RED BELLIED PITTA
# 240 RED BROWED FINCH
# 241 RED FACED CORMORANT
# 242 RED FACED WARBLER
# 243 RED FODY
# 244 RED HEADED DUCK
# 245 RED HEADED WOODPECKER
# 246 RED HONEY CREEPER
# 247 RED NAPED TROGON
# 248 RED TAILED HAWK
# 249 RED TAILED THRUSH
# 250 RED WINGED BLACKBIRD
# 251 RED WISKERED BULBUL
# 252 REGENT BOWERBIRD
# 253 RING-NECKED PHEASANT
# 254 ROADRUNNER
# 255 ROBIN
# 256 ROCK DOVE
# 257 ROSY FACED LOVEBIRD
# 258 ROUGH LEG BUZZARD
# 259 ROYAL FLYCATCHER
# 260 RUBY THROATED HUMMINGBIRD
# 261 RUDY KINGFISHER
# 262 RUFOUS KINGFISHER
# 263 RUFUOS MOTMOT
# 264 SAMATRAN THRUSH
# 265 SAND MARTIN
# 266 SANDHILL CRANE
# 267 SATYR TRAGOPAN
# 268 SCARLET CROWNED FRUIT DOVE
# 269 SCARLET IBIS
# 270 SCARLET MACAW
# 271 SCARLET TANAGER
# 272 SHOEBILL
# 273 SHORT BILLED DOWITCHER
# 274 SMITHS LONGSPUR
# 275 SNOWY EGRET
# 276 SNOWY OWL
# 277 SORA
# 278 SPANGLED COTINGA
# 279 SPLENDID WREN
# 280 SPOON BILED SANDPIPER
# 281 SPOONBILL
# 282 SPOTTED CATBIRD
# 283 SRI LANKA BLUE MAGPIE
# 284 STEAMER DUCK
# 285 STORK BILLED KINGFISHER
# 286 STRAWBERRY FINCH
# 287 STRIPED OWL
# 288 STRIPPED MANAKIN
# 289 STRIPPED SWALLOW
# 290 SUPERB STARLING
# 291 SWINHOES PHEASANT
# 292 TAIWAN MAGPIE
# 293 TAKAHE
# 294 TASMANIAN HEN
# 295 TEAL DUCK
# 296 TIT MOUSE
# 297 TOUCHAN
# 298 TOWNSENDS WARBLER
# 299 TREE SWALLOW
# 300 TROPICAL KINGBIRD
# 301 TRUMPTER SWAN
# 302 TURKEY VULTURE
# 303 TURQUOISE MOTMOT
# 304 UMBRELLA BIRD
# 305 VARIED THRUSH
# 306 VENEZUELIAN TROUPIAL
# 307 VERMILION FLYCATHER
# 308 VICTORIA CROWNED PIGEON
# 309 VIOLET GREEN SWALLOW
# 310 VULTURINE GUINEAFOWL
# 311 WALL CREAPER
# 312 WATTLED CURASSOW
# 313 WHIMBREL
# 314 WHITE BROWED CRAKE
# 315 WHITE CHEEKED TURACO
# 316 WHITE NECKED RAVEN
# 317 WHITE TAILED TROPIC
# 318 WHITE THROATED BEE EATER
# 319 WILD TURKEY
# 320 WILSONS BIRD OF PARADISE
# 321 WOOD DUCK
# 322 YELLOW BELLIED FLOWERPECKER
# 323 YELLOW CACIQUE
# 324 YELLOW HEADED BLACKBIRD

# %%
aps
# Out:
# [('AFRICAN CROWNED CRANE', 0.5472518888462031, 6.692450523376465),
#  ('AFRICAN FIREFINCH', 0.593358778445241, 4.2752439975738525),
#  ('ALBATROSS', 0.40908182583017355, 3.9904086589813232),
#  ('ALEXANDRINE PARAKEET', 0.504226596876425, 4.302011489868164),
#  ('AMERICAN AVOCET', 0.7964353252176918, 4.370288848876953),
#  ('AMERICAN BITTERN', 0.8528695143609264, 5.840615749359131),
#  ('AMERICAN COOT', 0.72544338042149, 3.9941792488098145),
#  ('AMERICAN GOLDFINCH', 0.28298416112125785, 3.851686477661133),
#  ('AMERICAN KESTREL', 0.5348392511211615, 4.511687994003296),
#  ('AMERICAN PIPIT', 0.7738327190695687, 3.842743158340454),
#  ('AMERICAN REDSTART', 0.4841169624079422, 5.273998022079468),
#  ('ANHINGA', 0.5726486257543564, 3.928269147872925),
#  ('ANNAS HUMMINGBIRD', 0.4962522141753341, 3.9823451042175293),
#  ('ANTBIRD', 0.22425425238084207, 4.919259309768677),
#  ('ARARIPE MANAKIN', 0.2877027034311288, 6.063374757766724),
#  ('ASIAN CRESTED IBIS', 0.364530290403453, 4.693697214126587),
#  ('BALD EAGLE', 0.5203893902823233, 5.938442707061768),
#  ('BALD IBIS', 0.6367352367583041, 4.740312337875366),
#  ('BALI STARLING', 0.7294132519840881, 5.592508554458618),
#  ('BALTIMORE ORIOLE', 0.6073257512696962, 4.744737386703491),
#  ('BANANAQUIT', 0.7411914967672182, 5.268248558044434),
#  ('BANDED BROADBILL', 0.2781970216204239, 4.168190002441406),
#  ('BANDED PITA', 0.9016116688671066, 3.6881330013275146),
#  ('BAR-TAILED GODWIT', 0.5735933501301621, 3.9532175064086914),
#  ('BARN OWL', 0.9375876573459572, 5.297369003295898),
#  ('BARN SWALLOW', 0.39674603493368515, 3.826003074645996),
#  ('BARRED PUFFBIRD', 0.350311357223308, 4.130935192108154),
#  ('BAY-BREASTED WARBLER', 0.7092848832930162, 4.278905868530273),
#  ('BEARDED BARBET', 0.5257812989519423, 4.28796648979187),
#  ('BEARDED BELLBIRD', 0.2519778879998336, 4.068281650543213),
#  ('BEARDED REEDLING', 0.5628275063505827, 3.997586965560913),
#  ('BELTED KINGFISHER', 0.6952630301516843, 4.540126800537109),
#  ('BIRD OF PARADISE', 0.6557192750044384, 6.662060260772705),
#  ('BLACK & YELLOW bROADBILL', 0.6236554527488589, 3.996342420578003),
#  ('BLACK BAZA', 0.628801826483139, 4.125371694564819),
#  ('BLACK FRANCOLIN', 0.30548105531004127, 3.531804323196411),
#  ('BLACK SKIMMER', 0.453014246172135, 4.373281478881836),
#  ('BLACK SWAN', 0.5966386554621849, 4.9394800662994385),
#  ('BLACK TAIL CRAKE', 0.5613564033944629, 4.012164115905762),
#  ('BLACK THROATED BUSHTIT', 0.6736939477498534, 4.589383363723755),
#  ('BLACK THROATED WARBLER', 0.46837672958299104, 4.1334264278411865),
#  ('BLACK VULTURE', 0.7093081094413243, 4.311185121536255),
#  ('BLACK-CAPPED CHICKADEE', 0.6145870029227387, 4.0798234939575195),
#  ('BLACK-NECKED GREBE', 0.5776548354178788, 4.358644485473633),
#  ('BLACK-THROATED SPARROW', 0.7345604913082612, 3.929539918899536),
#  ('BLACKBURNIAM WARBLER', 0.4264833186211134, 4.846781253814697),
#  ('BLONDE CRESTED WOODPECKER', 0.33105255991285404, 3.9558846950531006),
#  ('BLUE COAU', 0.2942662102019183, 4.426931858062744),
#  ('BLUE GROUSE', 0.236466911178827, 4.20568585395813),
#  ('BLUE HERON', 0.3018855885040377, 3.538681745529175),
#  ('BLUE THROATED TOUCANET', 0.34092821958713565, 3.6410231590270996),
#  ('BOBOLINK', 0.0684692391588096, 4.868173837661743),
#  ('BORNEAN BRISTLEHEAD', 0.8956348269284579, 3.354264736175537),
#  ('BORNEAN LEAFBIRD', 0.3356700020490742, 4.57797646522522),
#  ('BORNEAN PHEASANT', 0.16974052046576393, 4.289679527282715),
#  ('BRANDT CORMARANT', 0.5834143236349704, 3.8123741149902344),
#  ('BROWN CREPPER', 0.08495269173908805, 4.556409597396851),
#  ('BROWN NOODY', 0.3798449612403101, 4.048319578170776),
#  ('BROWN THRASHER', 0.22475160385133325, 4.251377820968628),
#  ('BULWERS PHEASANT', 0.689470904918844, 4.633632183074951),
#  ('CACTUS WREN', 0.07994782056764627, 4.217181444168091),
#  ('CALIFORNIA CONDOR', 0.6244272151606856, 4.249383211135864),
#  ('CALIFORNIA GULL', 0.11939453676980256, 4.9967334270477295),
#  ('CALIFORNIA QUAIL', 0.619641958165547, 4.307796001434326),
#  ('CANARY', 0.2745658573375502, 4.03677225112915),
#  ('CAPE GLOSSY STARLING', 0.6528822672596959, 4.63134765625),
#  ('CAPE MAY WARBLER', 0.2708195040137229, 3.8049886226654053),
#  ('CAPPED HERON', 0.4062695029624465, 4.162460088729858),
#  ('CAPUCHINBIRD', 0.8409731291905753, 4.024007320404053),
#  ('CARMINE BEE-EATER', 0.6593384063062533, 3.6301817893981934),
#  ('CASPIAN TERN', 0.4797354530649618, 4.542344331741333),
#  ('CASSOWARY', 0.5263012152143837, 3.6335461139678955),
#  ('CEDAR WAXWING', 0.6003539822856433, 4.065972566604614),
#  ('CERULEAN WARBLER', 0.7615581390999507, 4.37032675743103),
#  ('CHARA DE COLLAR', 0.6109373193378946, 3.544182538986206),
#  ('CHESTNET BELLIED EUPHONIA', 0.5747849429271302, 3.924833059310913),
#  ('CHIPPING SPARROW', 0.7718251814007127, 4.2097389698028564),
#  ('CHUKAR PARTRIDGE', 0.8151392246832886, 4.748003959655762),
#  ('CINNAMON TEAL', 0.450071360888188, 4.804563522338867),
#  ('CLARKS NUTCRACKER', 0.6089208143436267, 3.806730031967163),
#  ('COCK OF THE  ROCK', 0.8172676892174137, 4.439786672592163),
#  ('COCKATOO', 0.7524690446373307, 3.602670907974243),
#  ('COLLARED ARACARI', 0.8477415231251474, 3.8043673038482666),
#  ('COMMON FIRECREST', 0.5483668862006251, 4.243631362915039),
#  ('COMMON GRACKLE', 0.8003709366637183, 4.203017234802246),
#  ('COMMON HOUSE MARTIN', 0.5091562454856091, 4.0189478397369385),
#  ('COMMON LOON', 0.7985131372821022, 3.745530605316162),
#  ('COMMON POORWILL', 0.5220141735161946, 4.071954011917114),
#  ('COMMON STARLING', 0.6168925815150836, 3.885488271713257),
#  ('COUCHS KINGBIRD', 0.19466283208203441, 3.6993744373321533),
#  ('CRESTED AUKLET', 0.5763273924070071, 4.036080360412598),
#  ('CRESTED CARACARA', 0.6358224729083413, 3.512706995010376),
#  ('CRESTED NUTHATCH', 0.5228663504413927, 3.905506134033203),
#  ('CRIMSON SUNBIRD', 0.852404592580269, 4.372637510299683),
#  ('CROW', 0.5895132739020787, 4.063113451004028),
#  ('CROWNED PIGEON', 0.020632159088041436, 4.206071376800537),
#  ('CUBAN TODY', 0.8078348131817864, 4.818749904632568),
#  ('CUBAN TROGON', 0.8009695930462037, 4.351738929748535),
#  ('CURL CRESTED ARACURI', 0.6188341940210944, 4.417548894882202),
#  ('D-ARNAUDS BARBET', 0.6194363440724664, 3.9299566745758057),
#  ('DARK EYED JUNCO', 0.21837472662597318, 3.8921570777893066),
#  ('DOUBLE BARRED FINCH', 0.7361100102701978, 4.701642990112305),
#  ('DOUBLE BRESTED CORMARANT', 0.1815709238291109, 5.249209880828857),
#  ('DOWNY WOODPECKER', 0.49705788068359735, 4.328664302825928),
#  ('EASTERN BLUEBIRD', 0.4101510789932301, 4.186878204345703),
#  ('EASTERN MEADOWLARK', 0.2846868114219348, 3.6128597259521484),
#  ('EASTERN ROSELLA', 0.6730115874435468, 4.885812997817993),
#  ('EASTERN TOWEE', 0.15187209277170297, 4.125405788421631),
#  ('ELEGANT TROGON', 0.3475025872641322, 5.359339475631714),
#  ('ELLIOTS  PHEASANT', 0.76323167108219, 4.033567667007446),
#  ('EMPEROR PENGUIN', 0.8331202377278406, 4.261300325393677),
#  ('EMU', 0.47529554230336124, 4.493794679641724),
#  ('ENGGANO MYNA', 0.8345006406670713, 3.891984462738037),
#  ('EURASIAN GOLDEN ORIOLE', 0.21001571047440679, 3.756648302078247),
#  ('EURASIAN MAGPIE', 0.5735360159139695, 3.926712989807129),
#  ('EVENING GROSBEAK', 0.2578650976060813, 4.0431976318359375),
#  ('FAIRY BLUEBIRD', 0.5545478962337194, 4.435816764831543),
#  ('FIRE TAILLED MYZORNIS', 0.5263979167529312, 4.565154552459717),
#  ('FLAME TANAGER', 0.8148556459101003, 3.8289384841918945),
#  ('FLAMINGO', 0.8605752491030477, 4.922146558761597),
#  ('FRIGATE', 0.2689223195442006, 3.9879608154296875),
#  ('GAMBELS QUAIL', 0.5552907789392056, 4.346124649047852),
#  ('GANG GANG COCKATOO', 0.6219272148528598, 6.314987897872925),
#  ('GILA WOODPECKER', 0.36944626421079774, 3.666633129119873),
#  ('GILDED FLICKER', 0.30713028066991394, 4.199212074279785),
#  ('GLOSSY IBIS', 0.41263262214375396, 3.6643736362457275),
#  ('GO AWAY BIRD', 0.25878612836715914, 3.540290355682373),
#  ('GOLD WING WARBLER', 0.7764848330702744, 3.9419267177581787),
#  ('GOLDEN CHEEKED WARBLER', 0.665490875253128, 4.470785856246948),
#  ('GOLDEN CHLOROPHONIA', 0.7703679065579807, 4.488852262496948),
#  ('GOLDEN EAGLE', 0.3824031156648217, 4.20470404624939),
#  ('GOLDEN PHEASANT', 0.7118813823366174, 5.499470949172974),
#  ('GOLDEN PIPIT', 0.5382522985158343, 4.069356679916382),
#  ('GOULDIAN FINCH', 0.3204060969288982, 4.795153856277466),
#  ('GRAY CATBIRD', 0.5619553700840687, 4.020193099975586),
#  ('GRAY KINGBIRD', 0.7528607057243758, 4.218655109405518),
#  ('GRAY PARTRIDGE', 0.7157273772779384, 4.284684419631958),
#  ('GREAT GRAY OWL', 0.7228415194336177, 6.122188568115234),
#  ('GREAT KISKADEE', 0.4749434674610384, 3.9618074893951416),
#  ('GREAT POTOO', 0.046016032966368664, 5.062852382659912),
#  ('GREATOR SAGE GROUSE', 0.6256846811637989, 3.5822722911834717),
#  ('GREEN BROADBILL', 0.5624113044768225, 4.863850355148315),
#  ('GREEN JAY', 0.3533513347624118, 3.427290201187134),
#  ('GREEN MAGPIE', 0.6283924667019616, 4.236360311508179),
#  ('GREY PLOVER', 0.060778910417068316, 4.115385055541992),
#  ('GROVED BILLED ANI', 0.7924348332784343, 3.7480781078338623),
#  ('GUINEA TURACO', 0.3788760190735294, 4.041546583175659),
#  ('GUINEAFOWL', 0.7394004793106275, 4.607372999191284),
#  ('GYRFALCON', 0.33018280946886164, 3.727160930633545),
#  ('HARLEQUIN DUCK', 0.7760986370989916, 3.9539623260498047),
#  ('HARPY EAGLE', 0.6683268464596462, 4.310470104217529),
#  ('HAWAIIAN GOOSE', 0.630726810980434, 3.946908712387085),
#  ('HELMET VANGA', 0.9096302574613405, 4.495579242706299),
#  ('HIMALAYAN MONAL', 0.8047953148858157, 4.5701518058776855),
#  ('HOATZIN', 0.6287873074102565, 5.111506938934326),
#  ('HOODED MERGANSER', 0.1584814101847026, 3.7939577102661133),
#  ('HOOPOES', 0.29986477995688515, 5.24999213218689),
#  ('HORNBILL', 0.43464075098663574, 5.805111646652222),
#  ('HORNED GUAN', 0.4187974939522905, 3.884608745574951),
#  ('HORNED LARK', 0.8513453765449925, 3.6259331703186035),
#  ('HORNED SUNGEM', 0.6478600752933226, 4.1704254150390625),
#  ('HOUSE FINCH', 0.6783750731137987, 4.5435779094696045),
#  ('HOUSE SPARROW', 0.23172570145661384, 3.7221217155456543),
#  ('HYACINTH MACAW', 0.375068792533746, 4.299829959869385),
#  ('IMPERIAL SHAQ', 0.43241859519446874, 3.736787796020508),
#  ('INCA TERN', 0.7434767156544638, 4.6257312297821045),
#  ('INDIAN BUSTARD', 0.7325135900994679, 3.98679518699646),
#  ('INDIAN PITTA', 0.7689697858872587, 3.650094509124756),
#  ('INDIAN ROLLER', 0.5831611677125377, 3.75091814994812),
#  ('INDIGO BUNTING', 0.9162309789841377, 4.274097919464111),
#  ('IWI', 0.8748921469619005, 3.5024197101593018),
#  ('JABIRU', 0.585263304408462, 4.7454798221588135),
#  ('JAVA SPARROW', 0.5110976042699567, 4.183889150619507),
#  ('KAGU', 0.1433604853461844, 4.19075083732605),
#  ('KAKAPO', 0.4151023051023051, 3.4051079750061035),
#  ('KILLDEAR', 0.1756439047066609, 4.1846394538879395),
#  ('KING VULTURE', 0.7211911028631953, 4.260072708129883),
#  ('KIWI', 0.4723971861880178, 4.066742181777954),
#  ('KOOKABURRA', 0.3813749863169238, 3.8597803115844727),
#  ('LARK BUNTING', 0.1585245217819998, 4.274235963821411),
#  ('LAZULI BUNTING', 0.25097936555080275, 4.2647693157196045),
#  ('LILAC ROLLER', 0.01763738237765064, 4.083488941192627),
#  ('LONG-EARED OWL', 0.4309580766211309, 4.0900719165802),
#  ('MAGPIE GOOSE', 0.8868898053711497, 4.066500663757324),
#  ('MALABAR HORNBILL', 0.8080329596679037, 4.12862753868103),
#  ('MALACHITE KINGFISHER', 0.7302219269042268, 4.1142518520355225),
#  ('MALAGASY WHITE EYE', 0.4028680008149338, 4.266413450241089),
#  ('MALEO', 0.1733958475008538, 3.6979775428771973),
#  ('MALLARD DUCK', 0.5173080313249723, 3.652341604232788),
#  ('MANDRIN DUCK', 0.6645071679122839, 3.752859592437744),
#  ('MANGROVE CUCKOO', 0.05568772552325872, 4.233962535858154),
#  ('MARABOU STORK', 0.6504989404065915, 4.615967035293579),
#  ('MASKED BOOBY', 0.5423691765490941, 4.476182222366333),
#  ('MASKED LAPWING', 0.398771852075196, 4.600016832351685),
#  ('MIKADO  PHEASANT', 0.16826057304813533, 4.288100481033325),
#  ('MOURNING DOVE', 0.6223159629747941, 4.042396306991577),
#  ('MYNA', 0.47417712311329335, 4.714634418487549),
#  ('NICOBAR PIGEON', 0.4108527131782946, 4.818719148635864),
#  ('NOISY FRIARBIRD', 0.33856247886683827, 4.184218883514404),
#  ('NORTHERN CARDINAL', 0.22306890323983408, 4.333805799484253),
#  ('NORTHERN FLICKER', 0.1386100199825232, 4.909035682678223),
#  ('NORTHERN FULMAR', 0.7172957621416924, 4.356784105300903),
#  ('NORTHERN GANNET', 0.6402389551151856, 4.4406750202178955),
#  ('NORTHERN GOSHAWK', 0.1441796726805101, 4.431766986846924),
#  ('NORTHERN JACANA', 0.6116734143049932, 4.2588629722595215),
#  ('NORTHERN MOCKINGBIRD', 0.48232762687002023, 4.352652072906494),
#  ('NORTHERN PARULA', 0.7252585408484032, 4.0544047355651855),
#  ('NORTHERN RED BISHOP', 0.4805515218392146, 4.211152076721191),
#  ('NORTHERN SHOVELER', 0.7049806585046727, 4.662604093551636),
#  ('OCELLATED TURKEY', 0.6802480828991376, 3.953124761581421),
#  ('OKINAWA RAIL', 0.1732036540314252, 4.972445249557495),
#  ('ORANGE BRESTED BUNTING', 0.8649458460280538, 4.606969833374023),
#  ('ORIENTAL BAY OWL', 0.48851918984370757, 3.758324384689331),
#  ('OSPREY', 0.36252359305195875, 4.180176734924316),
#  ('OSTRICH', 0.39613919167108397, 3.781771421432495),
#  ('OVENBIRD', 0.44753842715469855, 4.2041521072387695),
#  ('OYSTER CATCHER', 0.9565217391304348, 4.06462287902832),
#  ('PAINTED BUNTIG', 0.8329134326903611, 4.46013617515564),
#  ('PALILA', 0.6020347468357291, 4.420827865600586),
#  ('PARADISE TANAGER', 0.29905791032233614, 4.574148178100586),
#  ('PARAKETT  AKULET', 0.72965417881179, 4.3115315437316895),
#  ('PARUS MAJOR', 0.09937681737471109, 3.775369882583618),
#  ('PATAGONIAN SIERRA FINCH', 0.6658524010485868, 4.04404616355896),
#  ('PEACOCK', 0.4690748218065275, 4.664328098297119),
#  ('PELICAN', 0.7160172203275652, 4.2500104904174805),
#  ('PEREGRINE FALCON', 0.5465533742739415, 4.049708843231201),
#  ('PHILIPPINE EAGLE', 0.6890969486463729, 4.40144944190979),
#  ('PINK ROBIN', 0.27671494550861336, 4.177485942840576),
#  ('POMARINE JAEGER', 0.3306528864204194, 4.263149261474609),
#  ('PUFFIN', 0.8341827495188265, 4.0436975955963135),
#  ('PURPLE FINCH', 0.41323778089973195, 4.274070501327515),
#  ('PURPLE GALLINULE', 0.6026561203082856, 4.7384538650512695),
#  ('PURPLE MARTIN', 0.28716348593575186, 4.045258522033691),
#  ('PURPLE SWAMPHEN', 0.25658531044768995, 4.846400499343872),
#  ('PYGMY KINGFISHER', 0.2968064015220981, 3.8213469982147217),
#  ('QUETZAL', 0.09998687748650037, 5.477922439575195),
#  ('RAINBOW LORIKEET', 0.8038406272348406, 4.890264987945557),
#  ('RAZORBILL', 0.13859025533755573, 3.686079502105713),
#  ('RED BEARDED BEE EATER', 0.7277108475370158, 3.6455891132354736),
#  ('RED BELLIED PITTA', 0.45050013200646355, 4.009784460067749),
#  ('RED BROWED FINCH', 0.6687808919941182, 4.025078058242798),
#  ('RED FACED CORMORANT', 0.5299581000466612, 3.666592836380005),
#  ('RED FACED WARBLER', 0.5878452121347019, 4.381940126419067),
#  ('RED FODY', 0.691302659319077, 4.66509485244751),
#  ('RED HEADED DUCK', 0.84605325604449, 5.926905632019043),
#  ('RED HEADED WOODPECKER', 0.4449690411867229, 3.6399598121643066),
#  ('RED HONEY CREEPER', 0.6863497153012315, 3.803609609603882),
#  ('RED NAPED TROGON', 0.7048830605208773, 3.935497999191284),
#  ('RED TAILED HAWK', 0.33316141050274334, 4.0428361892700195),
#  ('RED TAILED THRUSH', 0.26515160144689137, 4.006640672683716),
#  ('RED WINGED BLACKBIRD', 0.2996459507309569, 4.381741523742676),
#  ('RED WISKERED BULBUL', 0.6632025960576736, 3.980142593383789),
#  ('REGENT BOWERBIRD', 0.7127692128713907, 4.98416543006897),
#  ('RING-NECKED PHEASANT', 0.7702976991658367, 4.716198205947876),
#  ('ROADRUNNER', 0.39252226708934745, 5.002208709716797),
#  ('ROBIN', 0.45330561961761845, 4.395063400268555),
#  ('ROCK DOVE', 0.25713649096002034, 3.553588390350342),
#  ('ROSY FACED LOVEBIRD', 0.4664630025311608, 3.9079177379608154),
#  ('ROUGH LEG BUZZARD', 0.25194659666831026, 4.12780237197876),
#  ('ROYAL FLYCATCHER', 0.4619513390018384, 4.447397232055664),
#  ('RUBY THROATED HUMMINGBIRD', 0.5783938685950425, 4.8815648555755615),
#  ('RUDY KINGFISHER', 0.8893170217266464, 3.641733407974243),
#  ('RUFOUS KINGFISHER', 0.44024352581747267, 3.3307464122772217),
#  ('RUFUOS MOTMOT', 0.526844054187848, 4.380595445632935),
#  ('SAMATRAN THRUSH', 0.7995515387923793, 5.329608201980591),
#  ('SAND MARTIN', 0.47366671499274937, 4.064044237136841),
#  ('SANDHILL CRANE', 0.8488586337847449, 4.374703407287598),
#  ('SATYR TRAGOPAN', 0.47058823529411764, 5.8537421226501465),
#  ('SCARLET CROWNED FRUIT DOVE', 0.3237996582010611, 3.7454662322998047),
#  ('SCARLET IBIS', 0.8011565268988539, 4.675133466720581),
#  ('SCARLET MACAW', 0.7090489088180552, 4.659855365753174),
#  ('SCARLET TANAGER', 0.7485677361480245, 4.338810205459595),
#  ('SHOEBILL', 0.7020483630525695, 4.025371551513672),
#  ('SHORT BILLED DOWITCHER', 0.4346134260158269, 3.773548126220703),
#  ('SMITHS LONGSPUR', 0.7529105639811877, 3.8920774459838867),
#  ('SNOWY EGRET', 0.47686594708310737, 3.819549560546875),
#  ('SNOWY OWL', 0.49077204088583765, 5.4579596519470215),
#  ('SORA', 0.3705941054990718, 4.746321201324463),
#  ('SPANGLED COTINGA', 0.45779272365236345, 4.07553768157959),
#  ('SPLENDID WREN', 0.4252565303868514, 4.069810628890991),
#  ('SPOON BILED SANDPIPER', 0.20466805728863494, 4.168941974639893),
#  ('SPOONBILL', 0.4788306192576899, 4.0281360149383545),
#  ('SPOTTED CATBIRD', 0.6792604639350904, 4.250914096832275),
#  ('SRI LANKA BLUE MAGPIE', 0.33700666926712297, 3.596045732498169),
#  ('STEAMER DUCK', 0.5218999748586527, 4.2779622077941895),
#  ('STORK BILLED KINGFISHER', 0.28499439739958526, 4.075357913970947),
#  ('STRAWBERRY FINCH', 0.5850222907389476, 4.653381824493408),
#  ('STRIPED OWL', 0.5943644437657152, 4.185075283050537),
#  ('STRIPPED MANAKIN', 0.7455838463480527, 3.7153851985931396),
#  ('STRIPPED SWALLOW', 0.6197261369170981, 3.7812116146087646),
#  ('SUPERB STARLING', 0.5073656960166385, 3.9669883251190186),
#  ('SWINHOES PHEASANT', 0.7012553996377298, 4.721580743789673),
#  ('TAIWAN MAGPIE', 0.3628760455690802, 4.807809591293335),
#  ('TAKAHE', 0.8313671158738861, 4.246434926986694),
#  ('TASMANIAN HEN', 0.5426993809922254, 4.1723856925964355),
#  ('TEAL DUCK', 0.3172817213256504, 4.278546571731567),
#  ('TIT MOUSE', 0.6628147273075146, 4.493884086608887),
#  ('TOUCHAN', 0.2837602689018522, 4.204185247421265),
#  ('TOWNSENDS WARBLER', 0.6239636775485294, 4.629707098007202),
#  ('TREE SWALLOW', 0.599636712757367, 4.734448194503784),
#  ('TROPICAL KINGBIRD', 0.5527769973835481, 4.305976152420044),
#  ('TRUMPTER SWAN', 0.6314567869648289, 3.8325586318969727),
#  ('TURKEY VULTURE', 0.23153885126697468, 4.618571043014526),
#  ('TURQUOISE MOTMOT', 0.34863594268896453, 4.556744813919067),
#  ('UMBRELLA BIRD', 0.7969255347146535, 6.0340540409088135),
#  ('VARIED THRUSH', 0.8137613617000717, 3.814925193786621),
#  ('VENEZUELIAN TROUPIAL', 0.7800451224758016, 3.921952962875366),
#  ('VERMILION FLYCATHER', 0.2871868906522217, 4.013222932815552),
#  ('VICTORIA CROWNED PIGEON', 0.13026230164817212, 3.7514498233795166),
#  ('VIOLET GREEN SWALLOW', 0.3169251542631449, 3.9266297817230225),
#  ('VULTURINE GUINEAFOWL', 0.5727304985480026, 5.814863920211792),
#  ('WALL CREAPER', 0.46483785312483983, 4.4005115032196045),
#  ('WATTLED CURASSOW', 0.5957558376273637, 4.406793832778931),
#  ('WHIMBREL', 0.7924502196087517, 4.147098541259766),
#  ('WHITE BROWED CRAKE', 0.4949107452418503, 4.4276323318481445),
#  ('WHITE CHEEKED TURACO', 0.7567300364183538, 3.694223642349243),
#  ('WHITE NECKED RAVEN', 0.5282841315571944, 4.149980545043945),
#  ('WHITE TAILED TROPIC', 0.44309743014360836, 3.6865310668945312),
#  ('WHITE THROATED BEE EATER', 0.5481817235026141, 4.003168821334839),
#  ('WILD TURKEY', 0.8376336969723371, 4.506525278091431),
#  ('WILSONS BIRD OF PARADISE', 0.856693927134684, 4.169198274612427),
#  ('WOOD DUCK', 0.6906993830386251, 4.623109817504883),
#  ('YELLOW BELLIED FLOWERPECKER', 0.3794403532958304, 3.6527295112609863),
#  ('YELLOW CACIQUE', 0.8412796568218441, 5.043854236602783),
#  ('YELLOW HEADED BLACKBIRD', 0.23748366004560098, 4.823400020599365)]

# %%
ap_at_n = np.array([ap[1] for ap in aps])
query_time = np.array(([ap[2] for ap in aps]))

# %%
mAP_at_n = np.mean(ap_at_n, axis=0)
avg_query_time = np.mean(query_time, axis=0)
print("mAP:", mAP_at_n)
print("avg. query time: ", avg_query_time)
# Out:
# mAP: 0.5281436886942832
# avg. query time:  4.297144265541664

# %%
save_results('/content/drive/MyDrive/CV_Birds/performance/fine_tuning/index/FT_pert-forest_512_5rnd_cosine', 'FT_pert-forest_512_5rnd_cosine_results', aps)

# %%
# !mv /content/tree* /content/drive/MyDrive/CV_Birds/performance/fine_tuning/index/FT_pert-forest_512_5rnd_cosine/pert_forest_structure/

# %%
# !mv /content/pert* /content/drive/MyDrive/CV_Birds/performance/fine_tuning/index/FT_pert-forest_512_5rnd_cosine/pert_forest_structure/
