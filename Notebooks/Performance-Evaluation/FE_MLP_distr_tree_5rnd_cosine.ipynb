# %% [markdown]
# ## Import libraries

# %%
from google.colab import drive
from pathlib import Path
from matplotlib import pyplot as plt 
import pandas as pd
import numpy as np
import time
import os
import csv
import concurrent.futures

# %% [markdown]
# ## Utility functions

# %% [markdown]
# ### Create annot and load descriptors

# %%
def create_annot(path):
  image_list = list(Path(path).glob('*/*.jpg'))
  # the identity name is in the path (the name of the parent directory)
  names_list = [i.parent.name for i in image_list]  # get the identity of each image
  # keep info in a pandas DataFrame
  annot = pd.DataFrame({'identity': names_list, 'image_path': image_list})
  return annot

def concatenate_annots(list_of_paths):
  concat_annot = pd.DataFrame()
  with concurrent.futures.ThreadPoolExecutor() as executor:
    annots = [create_annot(path) for path in list_of_paths]
    for annot in annots:
      concat_annot = concat_annot.append(annot, ignore_index = True)
    return concat_annot

# %%
def load_descriptors(path):
  with open(path, 'rb') as file:
    return np.load(file)

def concatenate_descriptors(list_of_paths):
  concat_descriptors = None
  with concurrent.futures.ThreadPoolExecutor() as executor:
    descriptors = [executor.submit(load_descriptors, path) for path in list_of_paths]
    for descriptor in descriptors:
      new_descriptor = descriptor.result()
      if concat_descriptors is None:
        concat_descriptors = new_descriptor
      else:
        concat_descriptors = np.concatenate([concat_descriptors, new_descriptor])
    return concat_descriptors

# %% [markdown]
# ### Create pivots

# %%
def generate_pivots(descriptors, n, strategy="rnd"):
  if strategy != "rnd":
    print(strategy, "was not implemented. Random pivots were returned")
  pivots_id = np.random.choice(np.arange(len(descriptors)), size=n)
  return descriptors[pivots_id]

def generate_list_of_pivots(descriptors, t, n, strategy="rnd"):
  list_of_pivots = []
  with concurrent.futures.ThreadPoolExecutor() as executor:
    pivots = [executor.submit(generate_pivots, descriptors, n, strategy) for i in range(t)]
    for pivot in concurrent.futures.as_completed(pivots):
      new_pivot = pivot.result()
      list_of_pivots.append(new_pivot)
    return list_of_pivots

# %% [markdown]
# ### Save test results

# %%
def save_results(dir, file_name, results):
  with open(os.path.join(dir, file_name +".csv"), 'w') as f:
    writer = csv.writer(f)
    # write the header
    writer.writerow(["CLASS", "AP", "QUERY TIME"])
    # write the data
    for r in results:
      writer.writerow(r)

# %% [markdown]
# ## Test Performance

# %%
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Create annot and load descriptors for the database

# %%
db_annot = concatenate_annots(['/content/drive/MyDrive/CV_Birds/train', '/content/drive/MyDrive/CV_Birds/mirflickr25k'])
db_annot
# Out:
#                     identity                                         image_path
# 0      AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/train/AFRICAN ...
# 1      AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/train/AFRICAN ...
# 2      AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/train/AFRICAN ...
# 3      AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/train/AFRICAN ...
# 4      AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/train/AFRICAN ...
# ...                      ...                                                ...
# 72327              mirflickr  /content/drive/MyDrive/CV_Birds/mirflickr25k/m...
# 72328              mirflickr  /content/drive/MyDrive/CV_Birds/mirflickr25k/m...
# 72329              mirflickr  /content/drive/MyDrive/CV_Birds/mirflickr25k/m...
# 72330              mirflickr  /content/drive/MyDrive/CV_Birds/mirflickr25k/m...
# 72331              mirflickr  /content/drive/MyDrive/CV_Birds/mirflickr25k/m...
#
# [72332 rows x 2 columns]

# %%
db_descriptors = concatenate_descriptors(['/content/drive/MyDrive/CV_Birds/features/training/ResNet152v2/OneDense512_Dropout_feature_extraction.npy','/content/drive/MyDrive/CV_Birds/features/distractor/ResNet152v2/OneDense512_Dropout_feature_extraction.npy'])
db_descriptors.shape
# Out:
# (72332, 512)

# %% [markdown]
# ### Create annot and load descriptors for the test set

# %%
query_annot = create_annot('/content/drive/MyDrive/CV_Birds/test')
query_annot
# Out:
#                      identity                                         image_path
# 0       AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/test/AFRICAN C...
# 1       AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/test/AFRICAN C...
# 2       AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/test/AFRICAN C...
# 3       AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/test/AFRICAN C...
# 4       AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/test/AFRICAN C...
# ...                       ...                                                ...
# 1620  YELLOW HEADED BLACKBIRD  /content/drive/MyDrive/CV_Birds/test/YELLOW HE...
# 1621  YELLOW HEADED BLACKBIRD  /content/drive/MyDrive/CV_Birds/test/YELLOW HE...
# 1622  YELLOW HEADED BLACKBIRD  /content/drive/MyDrive/CV_Birds/test/YELLOW HE...
# 1623  YELLOW HEADED BLACKBIRD  /content/drive/MyDrive/CV_Birds/test/YELLOW HE...
# 1624  YELLOW HEADED BLACKBIRD  /content/drive/MyDrive/CV_Birds/test/YELLOW HE...
#
# [1625 rows x 2 columns]

# %%
query_descriptors = load_descriptors('/content/drive/MyDrive/CV_Birds/features/test/ResNet152v2/OneDense512_Dropout_feature_extraction.npy')
query_descriptors.shape
# Out:
# (1625, 512)

# %% [markdown]
# To run our tests we select only the first image of each species within the test set. Please note that within the test set we have 5 images per species.

# %%
queries_indexes = [x for x in range(325*5) if x%5 == 0]

# %% [markdown]
# ### Create PP-Index

# %%
def get_descriptor_from_id(id_object):
  return db_descriptors[id_object]

# %%
# %cd "/content/drive/MyDrive/CV_Birds/Notebooks/PP-Index"
# %run PPIndex.ipynb
# Out:
# /content/drive/.shortcut-targets-by-id/1rI5YNBuaSlCB__w522WEkHjw-nFuvIo0/CV_Birds/Notebooks/PP-Index

# %%
pivots = generate_pivots(db_descriptors, 5, "rnd")
rnd_pp_tree = PrefixTree(pivots, length=3, distance_metric='cosine', base_directory="/content", tree_file='tree_structure')
if rnd_pp_tree.is_empty():
  rnd_pp_tree.insert_objects_into_tree(range(len(db_descriptors)))
  rnd_pp_tree.save()
# Out:
# [WARNING]: Tree is still empty
# Inserting objects into tree_structure ...
# --- Insertion into tree tree_structure completed: 62.243 seconds ---

# %% [markdown]
# ### Compute mAP

# %%
birds_db = db_annot.loc[db_annot['identity'] != 'mirflickr']
counts = birds_db.groupby('identity').count()
print("Minimum number of images per species:", int(counts.min()))
print("Maximum number of images per species:", int(counts.max()))
print("Average number of images:", float(counts.sum()/325))
# Out:
# Minimum number of images per species: 116
# Maximum number of images per species: 249
# Average number of images: 145.63692307692307

# %% [markdown]
# Since at most we have 249 images per species, we use $n=250$.

# %%
n = 250

# %% [markdown]
# The formula for Average Precision is the following:
#
# > $AP@n=\frac{1}{GTP}\sum_{k=1}^{n}P@k×rel@k$
#
# where $GTP$ refers to the total number of ground truth positives, $n$ refers to the total number of images we are interested in, $P@k$ refers to the precision@k and $rel@k$ is a relevance function.
#
# The relevance function is an indicator function which equals 1 if the document at rank $k$ is relevant and equals to 0 otherwise.

# %%
def compute_ap(query_index, retrieved_ids):
  query_identity = query_annot['identity'][query_index]
  print(query_index//5, query_identity)
  GTP = len(db_annot.loc[db_annot['identity'] == query_identity])
  relevant = 0
  precision_summation = 0
  for k, id in enumerate(retrieved_ids):
    if db_annot['identity'][id] == query_identity: # relevant result
      relevant = relevant + 1
      precision_at_k = relevant/(k+1)
      precision_summation = precision_summation + precision_at_k
  return (query_identity, precision_summation/GTP)

# %% [markdown]
# For each query, $Q$, we can calculate a corresponding $AP$. Then, the $mAP$ is simply the mean of all the queries that were made.
# > $mAP = \frac{1}{N}\sum_{i=1}^{N}AP_i$
#
# In our case, $N=325$ (one query per species)

# %%
def rnd_pivots_queries(query_index, n):
  start_time = time.time()
  ids, distances = rnd_pp_tree.find_nearest_neighbors(query_descriptors[query_index], n)
  end_time = time.time()
  ids = ids.tolist()
  return compute_ap(query_index, ids) + (end_time - start_time,)

# %%
aps = []
for query_index in queries_indexes:
  aps.append(rnd_pivots_queries(query_index, n))
# Out:
# 0 AFRICAN CROWNED CRANE
# 1 AFRICAN FIREFINCH
# 2 ALBATROSS
# 3 ALEXANDRINE PARAKEET
# 4 AMERICAN AVOCET
# 5 AMERICAN BITTERN
# 6 AMERICAN COOT
# 7 AMERICAN GOLDFINCH
# 8 AMERICAN KESTREL
# 9 AMERICAN PIPIT
# 10 AMERICAN REDSTART
# 11 ANHINGA
# 12 ANNAS HUMMINGBIRD
# 13 ANTBIRD
# 14 ARARIPE MANAKIN
# 15 ASIAN CRESTED IBIS
# 16 BALD EAGLE
# 17 BALD IBIS
# 18 BALI STARLING
# 19 BALTIMORE ORIOLE
# 20 BANANAQUIT
# 21 BANDED BROADBILL
# 22 BANDED PITA
# 23 BAR-TAILED GODWIT
# 24 BARN OWL
# 25 BARN SWALLOW
# 26 BARRED PUFFBIRD
# 27 BAY-BREASTED WARBLER
# 28 BEARDED BARBET
# 29 BEARDED BELLBIRD
# 30 BEARDED REEDLING
# 31 BELTED KINGFISHER
# 32 BIRD OF PARADISE
# 33 BLACK & YELLOW bROADBILL
# 34 BLACK BAZA
# 35 BLACK FRANCOLIN
# 36 BLACK SKIMMER
# 37 BLACK SWAN
# 38 BLACK TAIL CRAKE
# 39 BLACK THROATED BUSHTIT
# 40 BLACK THROATED WARBLER
# 41 BLACK VULTURE
# 42 BLACK-CAPPED CHICKADEE
# 43 BLACK-NECKED GREBE
# 44 BLACK-THROATED SPARROW
# 45 BLACKBURNIAM WARBLER
# 46 BLONDE CRESTED WOODPECKER
# 47 BLUE COAU
# 48 BLUE GROUSE
# 49 BLUE HERON
# 50 BLUE THROATED TOUCANET
# 51 BOBOLINK
# 52 BORNEAN BRISTLEHEAD
# 53 BORNEAN LEAFBIRD
# 54 BORNEAN PHEASANT
# 55 BRANDT CORMARANT
# 56 BROWN CREPPER
# 57 BROWN NOODY
# 58 BROWN THRASHER
# 59 BULWERS PHEASANT
# 60 CACTUS WREN
# 61 CALIFORNIA CONDOR
# 62 CALIFORNIA GULL
# 63 CALIFORNIA QUAIL
# 64 CANARY
# 65 CAPE GLOSSY STARLING
# 66 CAPE MAY WARBLER
# 67 CAPPED HERON
# 68 CAPUCHINBIRD
# 69 CARMINE BEE-EATER
# 70 CASPIAN TERN
# 71 CASSOWARY
# 72 CEDAR WAXWING
# 73 CERULEAN WARBLER
# 74 CHARA DE COLLAR
# 75 CHESTNET BELLIED EUPHONIA
# 76 CHIPPING SPARROW
# 77 CHUKAR PARTRIDGE
# 78 CINNAMON TEAL
# 79 CLARKS NUTCRACKER
# 80 COCK OF THE  ROCK
# 81 COCKATOO
# 82 COLLARED ARACARI
# 83 COMMON FIRECREST
# 84 COMMON GRACKLE
# 85 COMMON HOUSE MARTIN
# 86 COMMON LOON
# 87 COMMON POORWILL
# 88 COMMON STARLING
# 89 COUCHS KINGBIRD
# 90 CRESTED AUKLET
# 91 CRESTED CARACARA
# 92 CRESTED NUTHATCH
# 93 CRIMSON SUNBIRD
# 94 CROW
# 95 CROWNED PIGEON
# 96 CUBAN TODY
# 97 CUBAN TROGON
# 98 CURL CRESTED ARACURI
# 99 D-ARNAUDS BARBET
# 100 DARK EYED JUNCO
# 101 DOUBLE BARRED FINCH
# 102 DOUBLE BRESTED CORMARANT
# 103 DOWNY WOODPECKER
# 104 EASTERN BLUEBIRD
# 105 EASTERN MEADOWLARK
# 106 EASTERN ROSELLA
# 107 EASTERN TOWEE
# 108 ELEGANT TROGON
# 109 ELLIOTS  PHEASANT
# 110 EMPEROR PENGUIN
# 111 EMU
# 112 ENGGANO MYNA
# 113 EURASIAN GOLDEN ORIOLE
# 114 EURASIAN MAGPIE
# 115 EVENING GROSBEAK
# 116 FAIRY BLUEBIRD
# 117 FIRE TAILLED MYZORNIS
# 118 FLAME TANAGER
# 119 FLAMINGO
# 120 FRIGATE
# 121 GAMBELS QUAIL
# 122 GANG GANG COCKATOO
# 123 GILA WOODPECKER
# 124 GILDED FLICKER
# 125 GLOSSY IBIS
# 126 GO AWAY BIRD
# 127 GOLD WING WARBLER
# 128 GOLDEN CHEEKED WARBLER
# 129 GOLDEN CHLOROPHONIA
# 130 GOLDEN EAGLE
# 131 GOLDEN PHEASANT
# 132 GOLDEN PIPIT
# 133 GOULDIAN FINCH
# 134 GRAY CATBIRD
# 135 GRAY KINGBIRD
# 136 GRAY PARTRIDGE
# 137 GREAT GRAY OWL
# 138 GREAT KISKADEE
# 139 GREAT POTOO
# 140 GREATOR SAGE GROUSE
# 141 GREEN BROADBILL
# 142 GREEN JAY
# 143 GREEN MAGPIE
# 144 GREY PLOVER
# 145 GROVED BILLED ANI
# 146 GUINEA TURACO
# 147 GUINEAFOWL
# 148 GYRFALCON
# 149 HARLEQUIN DUCK
# 150 HARPY EAGLE
# 151 HAWAIIAN GOOSE
# 152 HELMET VANGA
# 153 HIMALAYAN MONAL
# 154 HOATZIN
# 155 HOODED MERGANSER
# 156 HOOPOES
# 157 HORNBILL
# 158 HORNED GUAN
# 159 HORNED LARK
# 160 HORNED SUNGEM
# 161 HOUSE FINCH
# 162 HOUSE SPARROW
# 163 HYACINTH MACAW
# 164 IMPERIAL SHAQ
# 165 INCA TERN
# 166 INDIAN BUSTARD
# 167 INDIAN PITTA
# 168 INDIAN ROLLER
# 169 INDIGO BUNTING
# 170 IWI
# 171 JABIRU
# 172 JAVA SPARROW
# 173 KAGU
# 174 KAKAPO
# 175 KILLDEAR
# 176 KING VULTURE
# 177 KIWI
# 178 KOOKABURRA
# 179 LARK BUNTING
# 180 LAZULI BUNTING
# 181 LILAC ROLLER
# 182 LONG-EARED OWL
# 183 MAGPIE GOOSE
# 184 MALABAR HORNBILL
# 185 MALACHITE KINGFISHER
# 186 MALAGASY WHITE EYE
# 187 MALEO
# 188 MALLARD DUCK
# 189 MANDRIN DUCK
# 190 MANGROVE CUCKOO
# 191 MARABOU STORK
# 192 MASKED BOOBY
# 193 MASKED LAPWING
# 194 MIKADO  PHEASANT
# 195 MOURNING DOVE
# 196 MYNA
# 197 NICOBAR PIGEON
# 198 NOISY FRIARBIRD
# 199 NORTHERN CARDINAL
# 200 NORTHERN FLICKER
# 201 NORTHERN FULMAR
# 202 NORTHERN GANNET
# 203 NORTHERN GOSHAWK
# 204 NORTHERN JACANA
# 205 NORTHERN MOCKINGBIRD
# 206 NORTHERN PARULA
# 207 NORTHERN RED BISHOP
# 208 NORTHERN SHOVELER
# 209 OCELLATED TURKEY
# 210 OKINAWA RAIL
# 211 ORANGE BRESTED BUNTING
# 212 ORIENTAL BAY OWL
# 213 OSPREY
# 214 OSTRICH
# 215 OVENBIRD
# 216 OYSTER CATCHER
# 217 PAINTED BUNTIG
# 218 PALILA
# 219 PARADISE TANAGER
# 220 PARAKETT  AKULET
# 221 PARUS MAJOR
# 222 PATAGONIAN SIERRA FINCH
# 223 PEACOCK
# 224 PELICAN
# 225 PEREGRINE FALCON
# 226 PHILIPPINE EAGLE
# 227 PINK ROBIN
# 228 POMARINE JAEGER
# 229 PUFFIN
# 230 PURPLE FINCH
# 231 PURPLE GALLINULE
# 232 PURPLE MARTIN
# 233 PURPLE SWAMPHEN
# 234 PYGMY KINGFISHER
# 235 QUETZAL
# 236 RAINBOW LORIKEET
# 237 RAZORBILL
# 238 RED BEARDED BEE EATER
# 239 RED BELLIED PITTA
# 240 RED BROWED FINCH
# 241 RED FACED CORMORANT
# 242 RED FACED WARBLER
# 243 RED FODY
# 244 RED HEADED DUCK
# 245 RED HEADED WOODPECKER
# 246 RED HONEY CREEPER
# 247 RED NAPED TROGON
# 248 RED TAILED HAWK
# 249 RED TAILED THRUSH
# 250 RED WINGED BLACKBIRD
# 251 RED WISKERED BULBUL
# 252 REGENT BOWERBIRD
# 253 RING-NECKED PHEASANT
# 254 ROADRUNNER
# 255 ROBIN
# 256 ROCK DOVE
# 257 ROSY FACED LOVEBIRD
# 258 ROUGH LEG BUZZARD
# 259 ROYAL FLYCATCHER
# 260 RUBY THROATED HUMMINGBIRD
# 261 RUDY KINGFISHER
# 262 RUFOUS KINGFISHER
# 263 RUFUOS MOTMOT
# 264 SAMATRAN THRUSH
# 265 SAND MARTIN
# 266 SANDHILL CRANE
# 267 SATYR TRAGOPAN
# 268 SCARLET CROWNED FRUIT DOVE
# 269 SCARLET IBIS
# 270 SCARLET MACAW
# 271 SCARLET TANAGER
# 272 SHOEBILL
# 273 SHORT BILLED DOWITCHER
# 274 SMITHS LONGSPUR
# 275 SNOWY EGRET
# 276 SNOWY OWL
# 277 SORA
# 278 SPANGLED COTINGA
# 279 SPLENDID WREN
# 280 SPOON BILED SANDPIPER
# 281 SPOONBILL
# 282 SPOTTED CATBIRD
# 283 SRI LANKA BLUE MAGPIE
# 284 STEAMER DUCK
# 285 STORK BILLED KINGFISHER
# 286 STRAWBERRY FINCH
# 287 STRIPED OWL
# 288 STRIPPED MANAKIN
# 289 STRIPPED SWALLOW
# 290 SUPERB STARLING
# 291 SWINHOES PHEASANT
# 292 TAIWAN MAGPIE
# 293 TAKAHE
# 294 TASMANIAN HEN
# 295 TEAL DUCK
# 296 TIT MOUSE
# 297 TOUCHAN
# 298 TOWNSENDS WARBLER
# 299 TREE SWALLOW
# 300 TROPICAL KINGBIRD
# 301 TRUMPTER SWAN
# 302 TURKEY VULTURE
# 303 TURQUOISE MOTMOT
# 304 UMBRELLA BIRD
# 305 VARIED THRUSH
# 306 VENEZUELIAN TROUPIAL
# 307 VERMILION FLYCATHER
# 308 VICTORIA CROWNED PIGEON
# 309 VIOLET GREEN SWALLOW
# 310 VULTURINE GUINEAFOWL
# 311 WALL CREAPER
# 312 WATTLED CURASSOW
# 313 WHIMBREL
# 314 WHITE BROWED CRAKE
# 315 WHITE CHEEKED TURACO
# 316 WHITE NECKED RAVEN
# 317 WHITE TAILED TROPIC
# 318 WHITE THROATED BEE EATER
# 319 WILD TURKEY
# 320 WILSONS BIRD OF PARADISE
# 321 WOOD DUCK
# 322 YELLOW BELLIED FLOWERPECKER
# 323 YELLOW CACIQUE
# 324 YELLOW HEADED BLACKBIRD

# %%
aps
# Out:
# [('AFRICAN CROWNED CRANE', 0.6408277785296292, 0.5879464149475098),
#  ('AFRICAN FIREFINCH', 0.3267862117841435, 0.7812488079071045),
#  ('ALBATROSS', 0.32994419396082164, 0.712003231048584),
#  ('ALEXANDRINE PARAKEET', 0.23764261898788092, 0.7667620182037354),
#  ('AMERICAN AVOCET', 0.46810939120618256, 0.8935737609863281),
#  ('AMERICAN BITTERN', 0.3587286527514231, 0.8753523826599121),
#  ('AMERICAN COOT', 0.09124472573839662, 0.8266746997833252),
#  ('AMERICAN GOLDFINCH', 0.2592409369268194, 0.9130845069885254),
#  ('AMERICAN KESTREL', 0.08300940956282014, 0.8950326442718506),
#  ('AMERICAN PIPIT', 0.5013657257109271, 0.9555037021636963),
#  ('AMERICAN REDSTART', 0.0891809012574847, 0.4177277088165283),
#  ('ANHINGA', 0.09429806024935225, 0.6678693294525146),
#  ('ANNAS HUMMINGBIRD', 0.022182254196642683, 1.6010191440582275),
#  ('ANTBIRD', 0.047735215417275184, 0.5308074951171875),
#  ('ARARIPE MANAKIN', 0.20282467659823125, 0.6785404682159424),
#  ('ASIAN CRESTED IBIS', 0.19417119262355725, 0.40624451637268066),
#  ('BALD EAGLE', 0.2249174777768547, 0.747124195098877),
#  ('BALD IBIS', 0.07022950594379167, 0.706500768661499),
#  ('BALI STARLING', 0.05045585727403909, 0.6866214275360107),
#  ('BALTIMORE ORIOLE', 0.0010427528675703858, 0.4567301273345947),
#  ('BANANAQUIT', 0.05284365716253094, 0.5668625831604004),
#  ('BANDED BROADBILL', 0.03411994649108051, 0.5645608901977539),
#  ('BANDED PITA', 0.19879518072289157, 0.45453739166259766),
#  ('BAR-TAILED GODWIT', 0.333486832490172, 0.717339038848877),
#  ('BARN OWL', 0.216358024691358, 0.8798584938049316),
#  ('BARN SWALLOW', 0.1879960378639979, 0.9537203311920166),
#  ('BARRED PUFFBIRD', 0.022058823529411766, 0.5408236980438232),
#  ('BAY-BREASTED WARBLER', 0.184389325703811, 0.8633620738983154),
#  ('BEARDED BARBET', 0.020595238095238094, 0.7406754493713379),
#  ('BEARDED BELLBIRD', 0.13579546988281127, 0.3806421756744385),
#  ('BEARDED REEDLING', 0.29331849057966397, 0.8577723503112793),
#  ('BELTED KINGFISHER', 0.25502166001679183, 0.4903244972229004),
#  ('NORTHERN JACANA', 0.2983760683760684, 0.8371727466583252),
#  ('NORTHERN MOCKINGBIRD', 0.00021008403361344536, 0.6564610004425049),
#  ('NORTHERN PARULA', 0.17442840276874336, 0.8701772689819336),
#  ('NORTHERN RED BISHOP', 0.08895166453265044, 0.6570439338684082),
#  ('NORTHERN SHOVELER', 0.023076923076923078, 0.40865373611450195),
#  ('OCELLATED TURKEY', 0.1019473581973582, 0.7382016181945801),
#  ('OKINAWA RAIL', 0.0022644927536231885, 0.7496616840362549),
#  ('ORANGE BRESTED BUNTING', 0.24951250352897533, 0.7461166381835938),
#  ('ORIENTAL BAY OWL', 0.3910509970865333, 0.5417492389678955),
#  ('OSPREY', 0.10006731586690817, 0.5114703178405762),
#  ('OSTRICH', 0.008130081300813009, 0.9018476009368896),
#  ('OVENBIRD', 0.17643874353735145, 0.5436365604400635),
#  ('OYSTER CATCHER', 0.2995169082125604, 0.5579984188079834),
#  ('PAINTED BUNTIG', 0.16729560090720794, 0.6439402103424072),
#  ('PALILA', 0.025252362625932414, 0.9148304462432861),
#  ('PARADISE TANAGER', 0.3836526538746625, 0.8424122333526611),
#  ('PARAKETT  AKULET', 0.4826178560077229, 0.5021693706512451),
#  ('PARUS MAJOR', 0.06613361191471125, 0.438946008682251),
#  ('PATAGONIAN SIERRA FINCH', 0.29320742437054986, 0.8849091529846191),
#  ('PEACOCK', 0.5201584176047223, 0.4386739730834961),
#  ('PELICAN', 0.125, 0.8721554279327393),
#  ('PEREGRINE FALCON', 0.2465094368135324, 0.5021743774414062),
#  ('PHILIPPINE EAGLE', 0.07332910991447578, 0.3992793560028076),
#  ('PINK ROBIN', 0.2605952588634312, 0.6482505798339844),
#  ('POMARINE JAEGER', 0.16074227650650558, 0.8212680816650391),
#  ('PUFFIN', 0.2278384654858079, 0.5177626609802246),
#  ('PURPLE FINCH', 0.25267399555959713, 0.8457286357879639),
#  ('PURPLE GALLINULE', 0.3000301356619416, 0.82525634765625),
#  ('PURPLE MARTIN', 0.1499401140986696, 0.515141487121582),
#  ('PURPLE SWAMPHEN', 0.14928990814683385, 0.8522727489471436),
#  ('PYGMY KINGFISHER', 0.07894686108057855, 0.8451640605926514),
#  ('QUETZAL', 0.029332327029695453, 0.4169015884399414),
#  ('RAINBOW LORIKEET', 0.5096860424829867, 0.41455793380737305),
#  ('RAZORBILL', 0.06434420632827059, 0.5914621353149414),
#  ('RED BEARDED BEE EATER', 0.2335626982773027, 0.5685150623321533),
#  ('RED BELLIED PITTA', 0.18902209178514318, 0.6581358909606934),
#  ('RED BROWED FINCH', 0.025177304964539005, 0.4419825077056885),
#  ('RED FACED CORMORANT', 0.31239452552985186, 0.4339563846588135),
#  ('RED FACED WARBLER', 0.023215473814276206, 0.6497409343719482),
#  ('RED FODY', 0.3706011671021953, 0.8658390045166016),
#  ('RED HEADED DUCK', 0.15747807017543858, 0.3858218193054199),
#  ('RED HEADED WOODPECKER', 0.013109697320223634, 0.3950917720794678),
#  ('RED HONEY CREEPER', 0.33592271789966455, 0.7408323287963867),
#  ('RED NAPED TROGON', 0.12493774834567649, 0.5297832489013672),
#  ('RED TAILED HAWK', 0.03888475583589429, 0.9692573547363281),
#  ('RED TAILED THRUSH', 0.06571733926784733, 0.5117428302764893),
#  ('RED WINGED BLACKBIRD', 0.02914550453920533, 0.45989084243774414),
#  ('RED WISKERED BULBUL', 0.04878048780487805, 0.5112447738647461),
#  ('REGENT BOWERBIRD', 0.49068929138014966, 0.7182462215423584),
#  ('RING-NECKED PHEASANT', 0.0651913875598086, 0.39922475814819336),
#  ('ROADRUNNER', 0.010893504140786749, 0.512455940246582),
#  ('ROBIN', 0.1459862695658, 0.8836824893951416),
#  ('ROCK DOVE', 0.30321406013024765, 0.8848221302032471),
#  ('ROSY FACED LOVEBIRD', 0.27353563616161886, 0.6538355350494385),
#  ('ROUGH LEG BUZZARD', 0.012673786330068425, 0.5928037166595459),
#  ('ROYAL FLYCATCHER', 0.027847284206492084, 0.553466796875),
#  ('RUBY THROATED HUMMINGBIRD', 0.020493827160493826, 0.5605227947235107),
#  ('RUDY KINGFISHER', 0.45337870866496405, 0.7706718444824219),
#  ('RUFOUS KINGFISHER', 0.30806971325679483, 0.8483445644378662),
#  ('RUFUOS MOTMOT', 0.10571645172507986, 0.8166587352752686),
#  ('SAMATRAN THRUSH', 0.07163628472222222, 0.5192160606384277),
#  ('SAND MARTIN', 0.10028852330358955, 0.918229341506958),
#  ('SANDHILL CRANE', 0.5396864068570542, 0.39676380157470703),
#  ('SATYR TRAGOPAN', 0.051871657754010696, 0.5654616355895996),
#  ('SCARLET CROWNED FRUIT DOVE', 0.14074932615450153, 0.673328161239624),
#  ('SCARLET IBIS', 0.0995063949586099, 0.7400116920471191),
#  ('SCARLET MACAW', 0.34734166877564004, 0.3955097198486328),
#  ('SCARLET TANAGER', 0.45662474163590316, 0.7545549869537354),
#  ('SHOEBILL', 0.1657142857142857, 0.4961872100830078),
#  ('SHORT BILLED DOWITCHER', 0.6462759851821106, 0.881568431854248),
#  ('SMITHS LONGSPUR', 0.15115711809348412, 0.8364608287811279),
#  ('SNOWY EGRET', 0.6875778143371561, 0.8477704524993896),
#  ('SNOWY OWL', 0.4446969198199865, 0.6543843746185303),
#  ('SORA', 0.03217677951480821, 0.6455721855163574),
#  ('SPANGLED COTINGA', 0.0228021978021978, 0.5135819911956787),
#  ('SPLENDID WREN', 0.019603055346857, 0.6912581920623779),
#  ('SPOON BILED SANDPIPER', 0.22756762273957035, 0.9011330604553223),
#  ('SPOONBILL', 0.3381596060943887, 0.40186023712158203),
#  ('SPOTTED CATBIRD', 0.05631728424831873, 0.8358709812164307),
#  ('SRI LANKA BLUE MAGPIE', 0.000310077519379845, 0.9825801849365234),
#  ('STEAMER DUCK', 0.21789957489282683, 0.9676718711853027),
#  ('STORK BILLED KINGFISHER', 0.04395421239184123, 0.6481454372406006),
#  ('STRAWBERRY FINCH', 0.25162502410813736, 0.5349044799804688),
#  ('STRIPED OWL', 0.2568947724438781, 0.45188426971435547),
#  ('STRIPPED MANAKIN', 0.11691606467148263, 0.7528796195983887),
#  ('STRIPPED SWALLOW', 0.15594424198782944, 0.3962242603302002),
#  ('SUPERB STARLING', 0.11481657653827607, 0.5230531692504883),
#  ('SWINHOES PHEASANT', 0.1203650559130331, 0.7549045085906982),
#  ('TAIWAN MAGPIE', 0.1539827497417763, 0.5204188823699951),
#  ('TAKAHE', 0.5512569004200379, 0.7849516868591309),
#  ('TASMANIAN HEN', 0.24903835534178506, 0.7642502784729004),
#  ('TEAL DUCK', 0.16141032178768025, 0.568906307220459),
#  ('TIT MOUSE', 0.14986301369863014, 0.6581895351409912),
#  ('TOUCHAN', 0.05101307189542484, 0.45131516456604004),
#  ('TOWNSENDS WARBLER', 0.31164644527793983, 0.40743255615234375),
#  ('TREE SWALLOW', 0.07788720740918674, 0.4644279479980469),
#  ('TROPICAL KINGBIRD', 0.17924994951663237, 0.8834941387176514),
#  ('TRUMPTER SWAN', 0.03381995133819951, 0.3993847370147705),
#  ('TURKEY VULTURE', 0.14081186995463374, 0.5116417407989502),
#  ('TURQUOISE MOTMOT', 0.2262780467656681, 0.8396129608154297),
#  ('UMBRELLA BIRD', 0.4033040748900091, 0.46090102195739746),
#  ('VARIED THRUSH', 0.28384708719687196, 0.5391812324523926),
#  ('VENEZUELIAN TROUPIAL', 0.2954509374571755, 0.4444131851196289),
#  ('VERMILION FLYCATHER', 0.04372759856630824, 0.7452771663665771),
#  ('VICTORIA CROWNED PIGEON', 0.011191344886997062, 0.6564397811889648),
#  ('VIOLET GREEN SWALLOW', 0.041995988660769284, 0.8586909770965576),
#  ('VULTURINE GUINEAFOWL', 0.10213974060127907, 0.5065963268280029),
#  ('WALL CREAPER', 0.02731839434521314, 0.7641334533691406),
#  ('WATTLED CURASSOW', 0.1293164637110714, 0.5040624141693115),
#  ('WHIMBREL', 0.5092813027077033, 0.7960832118988037),
#  ('WHITE BROWED CRAKE', 0.11125450225872636, 0.6568512916564941),
#  ('WHITE CHEEKED TURACO', 0.14764187912684743, 0.5210027694702148),
#  ('WHITE NECKED RAVEN', 0.32009321495749005, 0.5157794952392578),
#  ('WHITE TAILED TROPIC', 0.34267654586095925, 0.7180583477020264),
#  ('WHITE THROATED BEE EATER', 0.020134228187919462, 0.6051938533782959),
#  ('WILD TURKEY', 0.05946180555555555, 0.4491138458251953),
#  ('WILSONS BIRD OF PARADISE', 0.4209348965471414, 0.5728840827941895),
#  ('WOOD DUCK', 0.0694898753894081, 0.42482948303222656),
#  ('YELLOW BELLIED FLOWERPECKER', 0.04273051739198339, 0.6572561264038086),
#  ('YELLOW CACIQUE', 0.06481126400481241, 0.42810726165771484),
#  ('YELLOW HEADED BLACKBIRD', 0.0, 0.44670724868774414)]

# %%
ap_at_n = np.array([ap[1] for ap in aps])
query_time = np.array(([ap[2] for ap in aps]))

# %%
mAP_at_n = np.mean(ap_at_n, axis=0)
avg_query_time = np.mean(query_time, axis=0)
print("mAP:", mAP_at_n)
print("avg. query time: ", avg_query_time)
# Out:
# mAP: 0.1770689258037439
# avg. query time:  0.645363806944627

# %%
save_results('/content/drive/MyDrive/CV_Birds/performance/feature_extraction/index', 'MLP_FE-distr_tree_5rnd_cosine_results', aps)
