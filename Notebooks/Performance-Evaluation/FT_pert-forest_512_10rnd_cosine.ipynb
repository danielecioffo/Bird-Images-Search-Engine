# %% [markdown]
# ## Import libraries

# %%
from google.colab import drive
from pathlib import Path
from matplotlib import pyplot as plt 
import pandas as pd
import numpy as np
import time
import os
import csv
import concurrent.futures

# %% [markdown]
# ## Utility functions

# %% [markdown]
# ### Create annot and load descriptors

# %%
def create_annot(path):
  image_list = list(Path(path).glob('*/*.jpg'))
  # the identity name is in the path (the name of the parent directory)
  names_list = [i.parent.name for i in image_list]  # get the identity of each image
  # keep info in a pandas DataFrame
  annot = pd.DataFrame({'identity': names_list, 'image_path': image_list})
  return annot

def concatenate_annots(list_of_paths):
  concat_annot = pd.DataFrame()
  with concurrent.futures.ThreadPoolExecutor() as executor:
    annots = [executor.submit(create_annot, path) for path in list_of_paths]
    for annot in annots:
      new_annot = annot.result()
      concat_annot = concat_annot.append(new_annot, ignore_index = True)
    return concat_annot

# %%
def load_descriptors(path):
  with open(path, 'rb') as file:
    return np.load(file)

def concatenate_descriptors(list_of_paths):
  concat_descriptors = None
  with concurrent.futures.ThreadPoolExecutor() as executor:
    descriptors = [executor.submit(load_descriptors, path) for path in list_of_paths]
    for descriptor in descriptors:
      new_descriptor = descriptor.result()
      if concat_descriptors is None:
        concat_descriptors = new_descriptor
      else:
        concat_descriptors = np.concatenate([concat_descriptors, new_descriptor])
    return concat_descriptors

# %% [markdown]
# ### Create pivots

# %%
def generate_pivots(descriptors, n, strategy="rnd"):
  if strategy == "kMED":
    kmedoids = sklearn_extra.cluster.KMedoids(n_clusters=n).fit(descriptors)
    return kmedoids.cluster_centers_
  if strategy != "rnd":
    print(strategy, "was not implemented. Random pivots were returned")
  pivots_id = np.random.choice(np.arange(len(descriptors)), size=n)
  return descriptors[pivots_id]

def generate_list_of_pivots(descriptors, t, n, strategy="rnd"):
  list_of_pivots = []
  with concurrent.futures.ThreadPoolExecutor() as executor:
    pivots = [executor.submit(generate_pivots, descriptors, n, strategy) for i in range(t)]
    for pivot in concurrent.futures.as_completed(pivots):
      new_pivot = pivot.result()
      list_of_pivots.append(new_pivot)
    return list_of_pivots

# %% [markdown]
# ### Save test results

# %%
def save_results(dir, file_name, results):
  with open(os.path.join(dir, file_name +".csv"), 'w') as f:
    writer = csv.writer(f)
    # write the header
    writer.writerow(["CLASS", "AP", "QUERY TIME"])
    # write the data
    for r in results:
      writer.writerow(r)

# %% [markdown]
# ## Test Performance

# %%
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Create annot and load descriptors for the database

# %%
db_annot = concatenate_annots(['/content/drive/MyDrive/CV_Birds/train', '/content/drive/MyDrive/CV_Birds/mirflickr25k'])
db_annot
# Out:
#                     identity                                         image_path
# 0      AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/train/AFRICAN ...
# 1      AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/train/AFRICAN ...
# 2      AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/train/AFRICAN ...
# 3      AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/train/AFRICAN ...
# 4      AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/train/AFRICAN ...
# ...                      ...                                                ...
# 72327              mirflickr  /content/drive/MyDrive/CV_Birds/mirflickr25k/m...
# 72328              mirflickr  /content/drive/MyDrive/CV_Birds/mirflickr25k/m...
# 72329              mirflickr  /content/drive/MyDrive/CV_Birds/mirflickr25k/m...
# 72330              mirflickr  /content/drive/MyDrive/CV_Birds/mirflickr25k/m...
# 72331              mirflickr  /content/drive/MyDrive/CV_Birds/mirflickr25k/m...
#
# [72332 rows x 2 columns]

# %%
db_descriptors = concatenate_descriptors(['/content/drive/MyDrive/CV_Birds/features/training/ResNet152v2/OneDense512_Dropout_fine_tuning.npy','/content/drive/MyDrive/CV_Birds/features/distractor/ResNet152v2/OneDense512_Dropout_fine_tuning.npy'])
db_descriptors.shape
# Out:
# (72332, 512)

# %% [markdown]
# ### Create annot and load descriptors for the test set

# %%
query_annot = create_annot('/content/drive/MyDrive/CV_Birds/test')
query_annot
# Out:
#                      identity                                         image_path
# 0       AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/test/AFRICAN C...
# 1       AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/test/AFRICAN C...
# 2       AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/test/AFRICAN C...
# 3       AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/test/AFRICAN C...
# 4       AFRICAN CROWNED CRANE  /content/drive/MyDrive/CV_Birds/test/AFRICAN C...
# ...                       ...                                                ...
# 1620  YELLOW HEADED BLACKBIRD  /content/drive/MyDrive/CV_Birds/test/YELLOW HE...
# 1621  YELLOW HEADED BLACKBIRD  /content/drive/MyDrive/CV_Birds/test/YELLOW HE...
# 1622  YELLOW HEADED BLACKBIRD  /content/drive/MyDrive/CV_Birds/test/YELLOW HE...
# 1623  YELLOW HEADED BLACKBIRD  /content/drive/MyDrive/CV_Birds/test/YELLOW HE...
# 1624  YELLOW HEADED BLACKBIRD  /content/drive/MyDrive/CV_Birds/test/YELLOW HE...
#
# [1625 rows x 2 columns]

# %%
query_descriptors = load_descriptors('/content/drive/MyDrive/CV_Birds/features/test/ResNet152v2/OneDense512_Dropout_fine_tuning.npy')
query_descriptors.shape
# Out:
# (1625, 512)

# %% [markdown]
# To run our tests we select only the first image of each species within the test set. Please note that within the test set we have 5 images per species.

# %%
queries_indexes = [x for x in range(325*5) if x%5 == 0]

# %% [markdown]
# ### Create PP-Index

# %%
# !rm /content/drive/MyDrive/CV_Birds/performance/fine_tuning/index/FT_pert-forest_512_10rnd_cosine/*
# !rm -r /content/drive/MyDrive/CV_Birds/performance/fine_tuning/index/FT_pert-forest_512_10rnd_cosine/pert_forest_structure/*
# Out:
# rm: cannot remove '/content/drive/MyDrive/CV_Birds/performance/fine_tuning/index/FT_pert-forest_512_10rnd_cosine/pert_forest_structure': Is a directory

# %%
def get_descriptor_from_id(id_object):
  return db_descriptors[id_object]

# %%
# %cd "/content/drive/MyDrive/CV_Birds/Notebooks/PP-Index"
# %run PPIndex.ipynb
# Out:
# /content/drive/.shortcut-targets-by-id/1rI5YNBuaSlCB__w522WEkHjw-nFuvIo0/CV_Birds/Notebooks/PP-Index

# %%
pivots = generate_list_of_pivots(db_descriptors, t=3, n=10, strategy="rnd")
rnd_pp_forest = PrefixForest(pivots, length=3, distance_metric='cosine', base_directory="/content", forest_file='pert_forest_structure')
rnd_pp_forest.insert_objects_into_forest(range(len(db_descriptors)))
rnd_pp_forest.save()
# Out:
# [WARNING]: Tree is still empty
# [WARNING]: Tree is still empty
# [WARNING]: Tree is still empty
# [WARNING]: Forest is still empty
# Inserting objects into tree1 ...
# Inserting objects intoInserting objects into tree3 ...
#  tree2 ...
# --- Insertion into tree tree1 completed: 292.037 seconds ---
# --- Insertion into tree tree2 completed: 293.652 seconds ---
# --- Insertion into tree tree3 completed: 298.656 seconds ---

# %% [markdown]
# ### Compute mAP

# %%
birds_db = db_annot.loc[db_annot['identity'] != 'mirflickr']
counts = birds_db.groupby('identity').count()
print("Minimum number of images per species:", int(counts.min()))
print("Maximum number of images per species:", int(counts.max()))
print("Average number of images:", float(counts.sum()/325))
# Out:
# Minimum number of images per species: 116
# Maximum number of images per species: 249
# Average number of images: 145.63692307692307

# %% [markdown]
# Since at most we have 249 images per species, we use $n=250$.

# %%
n = 250

# %% [markdown]
# The formula for Average Precision is the following:
#
# > $AP@n=\frac{1}{GTP}\sum_{k=1}^{n}P@k×rel@k$
#
# where $GTP$ refers to the total number of ground truth positives, $n$ refers to the total number of images we are interested in, $P@k$ refers to the precision@k and $rel@k$ is a relevance function.
#
# The relevance function is an indicator function which equals 1 if the document at rank $k$ is relevant and equals to 0 otherwise.

# %%
def compute_ap(query_index, retrieved_ids):
  query_identity = query_annot['identity'][query_index]
  print(query_index//5, query_identity)
  GTP = len(db_annot.loc[db_annot['identity'] == query_identity])
  relevant = 0
  precision_summation = 0
  for k, id in enumerate(retrieved_ids):
    if db_annot['identity'][id] == query_identity: # relevant result
      relevant = relevant + 1
      precision_at_k = relevant/(k+1)
      precision_summation = precision_summation + precision_at_k
  return (query_identity, precision_summation/GTP)

# %% [markdown]
# For each query, $Q$, we can calculate a corresponding $AP$. Then, the $mAP$ is simply the mean of all the queries that were made.
# > $mAP = \frac{1}{N}\sum_{i=1}^{N}AP_i$
#
# In our case, $N=325$ (one query per species)

# %%
def rnd_pivots_queries(query_index, n):
  start_time = time.time()
  ids, distances = rnd_pp_forest.find_nearest_neighbors(query_descriptors[query_index], n, perturbations=3)
  end_time = time.time()
  ids = ids.tolist()
  return compute_ap(query_index, ids) + (end_time - start_time,)

# %%
aps = []
for query_index in queries_indexes:
  aps.append(rnd_pivots_queries(query_index, n))
# Out:
# 0 AFRICAN CROWNED CRANE
# 1 AFRICAN FIREFINCH
# 2 ALBATROSS
# 3 ALEXANDRINE PARAKEET
# 4 AMERICAN AVOCET
# 5 AMERICAN BITTERN
# 6 AMERICAN COOT
# 7 AMERICAN GOLDFINCH
# 8 AMERICAN KESTREL
# 9 AMERICAN PIPIT
# 10 AMERICAN REDSTART
# 11 ANHINGA
# 12 ANNAS HUMMINGBIRD
# 13 ANTBIRD
# 14 ARARIPE MANAKIN
# 15 ASIAN CRESTED IBIS
# 16 BALD EAGLE
# 17 BALD IBIS
# 18 BALI STARLING
# 19 BALTIMORE ORIOLE
# 20 BANANAQUIT
# 21 BANDED BROADBILL
# 22 BANDED PITA
# 23 BAR-TAILED GODWIT
# 24 BARN OWL
# 25 BARN SWALLOW
# 26 BARRED PUFFBIRD
# 27 BAY-BREASTED WARBLER
# 28 BEARDED BARBET
# 29 BEARDED BELLBIRD
# 30 BEARDED REEDLING
# 31 BELTED KINGFISHER
# 32 BIRD OF PARADISE
# 33 BLACK & YELLOW bROADBILL
# 34 BLACK BAZA
# 35 BLACK FRANCOLIN
# 36 BLACK SKIMMER
# 37 BLACK SWAN
# 38 BLACK TAIL CRAKE
# 39 BLACK THROATED BUSHTIT
# 40 BLACK THROATED WARBLER
# 41 BLACK VULTURE
# 42 BLACK-CAPPED CHICKADEE
# 43 BLACK-NECKED GREBE
# 44 BLACK-THROATED SPARROW
# 45 BLACKBURNIAM WARBLER
# 46 BLONDE CRESTED WOODPECKER
# 47 BLUE COAU
# 48 BLUE GROUSE
# 49 BLUE HERON
# 50 BLUE THROATED TOUCANET
# 51 BOBOLINK
# 52 BORNEAN BRISTLEHEAD
# 53 BORNEAN LEAFBIRD
# 54 BORNEAN PHEASANT
# 55 BRANDT CORMARANT
# 56 BROWN CREPPER
# 57 BROWN NOODY
# 58 BROWN THRASHER
# 59 BULWERS PHEASANT
# 60 CACTUS WREN
# 61 CALIFORNIA CONDOR
# 62 CALIFORNIA GULL
# 63 CALIFORNIA QUAIL
# 64 CANARY
# 65 CAPE GLOSSY STARLING
# 66 CAPE MAY WARBLER
# 67 CAPPED HERON
# 68 CAPUCHINBIRD
# 69 CARMINE BEE-EATER
# 70 CASPIAN TERN
# 71 CASSOWARY
# 72 CEDAR WAXWING
# 73 CERULEAN WARBLER
# 74 CHARA DE COLLAR
# 75 CHESTNET BELLIED EUPHONIA
# 76 CHIPPING SPARROW
# 77 CHUKAR PARTRIDGE
# 78 CINNAMON TEAL
# 79 CLARKS NUTCRACKER
# 80 COCK OF THE  ROCK
# 81 COCKATOO
# 82 COLLARED ARACARI
# 83 COMMON FIRECREST
# 84 COMMON GRACKLE
# 85 COMMON HOUSE MARTIN
# 86 COMMON LOON
# 87 COMMON POORWILL
# 88 COMMON STARLING
# 89 COUCHS KINGBIRD
# 90 CRESTED AUKLET
# 91 CRESTED CARACARA
# 92 CRESTED NUTHATCH
# 93 CRIMSON SUNBIRD
# 94 CROW
# 95 CROWNED PIGEON
# 96 CUBAN TODY
# 97 CUBAN TROGON
# 98 CURL CRESTED ARACURI
# 99 D-ARNAUDS BARBET
# 100 DARK EYED JUNCO
# 101 DOUBLE BARRED FINCH
# 102 DOUBLE BRESTED CORMARANT
# 103 DOWNY WOODPECKER
# 104 EASTERN BLUEBIRD
# 105 EASTERN MEADOWLARK
# 106 EASTERN ROSELLA
# 107 EASTERN TOWEE
# 108 ELEGANT TROGON
# 109 ELLIOTS  PHEASANT
# 110 EMPEROR PENGUIN
# 111 EMU
# 112 ENGGANO MYNA
# 113 EURASIAN GOLDEN ORIOLE
# 114 EURASIAN MAGPIE
# 115 EVENING GROSBEAK
# 116 FAIRY BLUEBIRD
# 117 FIRE TAILLED MYZORNIS
# 118 FLAME TANAGER
# 119 FLAMINGO
# 120 FRIGATE
# 121 GAMBELS QUAIL
# 122 GANG GANG COCKATOO
# 123 GILA WOODPECKER
# 124 GILDED FLICKER
# 125 GLOSSY IBIS
# 126 GO AWAY BIRD
# 127 GOLD WING WARBLER
# 128 GOLDEN CHEEKED WARBLER
# 129 GOLDEN CHLOROPHONIA
# 130 GOLDEN EAGLE
# 131 GOLDEN PHEASANT
# 132 GOLDEN PIPIT
# 133 GOULDIAN FINCH
# 134 GRAY CATBIRD
# 135 GRAY KINGBIRD
# 136 GRAY PARTRIDGE
# 137 GREAT GRAY OWL
# 138 GREAT KISKADEE
# 139 GREAT POTOO
# 140 GREATOR SAGE GROUSE
# 141 GREEN BROADBILL
# 142 GREEN JAY
# 143 GREEN MAGPIE
# 144 GREY PLOVER
# 145 GROVED BILLED ANI
# 146 GUINEA TURACO
# 147 GUINEAFOWL
# 148 GYRFALCON
# 149 HARLEQUIN DUCK
# 150 HARPY EAGLE
# 151 HAWAIIAN GOOSE
# 152 HELMET VANGA
# 153 HIMALAYAN MONAL
# 154 HOATZIN
# 155 HOODED MERGANSER
# 156 HOOPOES
# 157 HORNBILL
# 158 HORNED GUAN
# 159 HORNED LARK
# 160 HORNED SUNGEM
# 161 HOUSE FINCH
# 162 HOUSE SPARROW
# 163 HYACINTH MACAW
# 164 IMPERIAL SHAQ
# 165 INCA TERN
# 166 INDIAN BUSTARD
# 167 INDIAN PITTA
# 168 INDIAN ROLLER
# 169 INDIGO BUNTING
# 170 IWI
# 171 JABIRU
# 172 JAVA SPARROW
# 173 KAGU
# 174 KAKAPO
# 175 KILLDEAR
# 176 KING VULTURE
# 177 KIWI
# 178 KOOKABURRA
# 179 LARK BUNTING
# 180 LAZULI BUNTING
# 181 LILAC ROLLER
# 182 LONG-EARED OWL
# 183 MAGPIE GOOSE
# 184 MALABAR HORNBILL
# 185 MALACHITE KINGFISHER
# 186 MALAGASY WHITE EYE
# 187 MALEO
# 188 MALLARD DUCK
# 189 MANDRIN DUCK
# 190 MANGROVE CUCKOO
# 191 MARABOU STORK
# 192 MASKED BOOBY
# 193 MASKED LAPWING
# 194 MIKADO  PHEASANT
# 195 MOURNING DOVE
# 196 MYNA
# 197 NICOBAR PIGEON
# 198 NOISY FRIARBIRD
# 199 NORTHERN CARDINAL
# 200 NORTHERN FLICKER
# 201 NORTHERN FULMAR
# 202 NORTHERN GANNET
# 203 NORTHERN GOSHAWK
# 204 NORTHERN JACANA
# 205 NORTHERN MOCKINGBIRD
# 206 NORTHERN PARULA
# 207 NORTHERN RED BISHOP
# 208 NORTHERN SHOVELER
# 209 OCELLATED TURKEY
# 210 OKINAWA RAIL
# 211 ORANGE BRESTED BUNTING
# 212 ORIENTAL BAY OWL
# 213 OSPREY
# 214 OSTRICH
# 215 OVENBIRD
# 216 OYSTER CATCHER
# 217 PAINTED BUNTIG
# 218 PALILA
# 219 PARADISE TANAGER
# 220 PARAKETT  AKULET
# 221 PARUS MAJOR
# 222 PATAGONIAN SIERRA FINCH
# 223 PEACOCK
# 224 PELICAN
# 225 PEREGRINE FALCON
# 226 PHILIPPINE EAGLE
# 227 PINK ROBIN
# 228 POMARINE JAEGER
# 229 PUFFIN
# 230 PURPLE FINCH
# 231 PURPLE GALLINULE
# 232 PURPLE MARTIN
# 233 PURPLE SWAMPHEN
# 234 PYGMY KINGFISHER
# 235 QUETZAL
# 236 RAINBOW LORIKEET
# 237 RAZORBILL
# 238 RED BEARDED BEE EATER
# 239 RED BELLIED PITTA
# 240 RED BROWED FINCH
# 241 RED FACED CORMORANT
# 242 RED FACED WARBLER
# 243 RED FODY
# 244 RED HEADED DUCK
# 245 RED HEADED WOODPECKER
# 246 RED HONEY CREEPER
# 247 RED NAPED TROGON
# 248 RED TAILED HAWK
# 249 RED TAILED THRUSH
# 250 RED WINGED BLACKBIRD
# 251 RED WISKERED BULBUL
# 252 REGENT BOWERBIRD
# 253 RING-NECKED PHEASANT
# 254 ROADRUNNER
# 255 ROBIN
# 256 ROCK DOVE
# 257 ROSY FACED LOVEBIRD
# 258 ROUGH LEG BUZZARD
# 259 ROYAL FLYCATCHER
# 260 RUBY THROATED HUMMINGBIRD
# 261 RUDY KINGFISHER
# 262 RUFOUS KINGFISHER
# 263 RUFUOS MOTMOT
# 264 SAMATRAN THRUSH
# 265 SAND MARTIN
# 266 SANDHILL CRANE
# 267 SATYR TRAGOPAN
# 268 SCARLET CROWNED FRUIT DOVE
# 269 SCARLET IBIS
# 270 SCARLET MACAW
# 271 SCARLET TANAGER
# 272 SHOEBILL
# 273 SHORT BILLED DOWITCHER
# 274 SMITHS LONGSPUR
# 275 SNOWY EGRET
# 276 SNOWY OWL
# 277 SORA
# 278 SPANGLED COTINGA
# 279 SPLENDID WREN
# 280 SPOON BILED SANDPIPER
# 281 SPOONBILL
# 282 SPOTTED CATBIRD
# 283 SRI LANKA BLUE MAGPIE
# 284 STEAMER DUCK
# 285 STORK BILLED KINGFISHER
# 286 STRAWBERRY FINCH
# 287 STRIPED OWL
# 288 STRIPPED MANAKIN
# 289 STRIPPED SWALLOW
# 290 SUPERB STARLING
# 291 SWINHOES PHEASANT
# 292 TAIWAN MAGPIE
# 293 TAKAHE
# 294 TASMANIAN HEN
# 295 TEAL DUCK
# 296 TIT MOUSE
# 297 TOUCHAN
# 298 TOWNSENDS WARBLER
# 299 TREE SWALLOW
# 300 TROPICAL KINGBIRD
# 301 TRUMPTER SWAN
# 302 TURKEY VULTURE
# 303 TURQUOISE MOTMOT
# 304 UMBRELLA BIRD
# 305 VARIED THRUSH
# 306 VENEZUELIAN TROUPIAL
# 307 VERMILION FLYCATHER
# 308 VICTORIA CROWNED PIGEON
# 309 VIOLET GREEN SWALLOW
# 310 VULTURINE GUINEAFOWL
# 311 WALL CREAPER
# 312 WATTLED CURASSOW
# 313 WHIMBREL
# 314 WHITE BROWED CRAKE
# 315 WHITE CHEEKED TURACO
# 316 WHITE NECKED RAVEN
# 317 WHITE TAILED TROPIC
# 318 WHITE THROATED BEE EATER
# 319 WILD TURKEY
# 320 WILSONS BIRD OF PARADISE
# 321 WOOD DUCK
# 322 YELLOW BELLIED FLOWERPECKER
# 323 YELLOW CACIQUE
# 324 YELLOW HEADED BLACKBIRD

# %%
aps
# Out:
# [('AFRICAN CROWNED CRANE', 0.6632030714276556, 3.5176162719726562),
#  ('AFRICAN FIREFINCH', 0.5836136582310648, 3.311129093170166),
#  ('ALBATROSS', 0.7863760012169176, 3.3696858882904053),
#  ('ALEXANDRINE PARAKEET', 0.6031530879499646, 3.9920156002044678),
#  ('AMERICAN AVOCET', 0.6116664350442009, 3.211606740951538),
#  ('AMERICAN BITTERN', 0.9546531238616519, 4.498677492141724),
#  ('AMERICAN COOT', 0.9782530666367772, 3.4981741905212402),
#  ('AMERICAN GOLDFINCH', 0.8252213191937343, 3.5098273754119873),
#  ('AMERICAN KESTREL', 0.6452644293943616, 4.330261707305908),
#  ('AMERICAN PIPIT', 0.5908278478468516, 3.245455741882324),
#  ('AMERICAN REDSTART', 0.31204836542836945, 3.7561676502227783),
#  ('ANHINGA', 0.25329489078050965, 3.9518675804138184),
#  ('ANNAS HUMMINGBIRD', 0.518147449011528, 3.1913750171661377),
#  ('ANTBIRD', 0.2052381451179737, 3.380685567855835),
#  ('ARARIPE MANAKIN', 0.7476068510894442, 3.5005404949188232),
#  ('ASIAN CRESTED IBIS', 0.556663313489992, 3.4793481826782227),
#  ('BALD EAGLE', 0.7098197577007996, 3.68747615814209),
#  ('BALD IBIS', 0.8174254958356827, 3.531525135040283),
#  ('BALI STARLING', 0.717119256029674, 3.8203537464141846),
#  ('BALTIMORE ORIOLE', 0.4818492758112711, 3.6197314262390137),
#  ('BANANAQUIT', 0.47994630129777976, 3.4479217529296875),
#  ('BANDED BROADBILL', 0.7819771506609453, 3.286839246749878),
#  ('BANDED PITA', 0.6429854856874062, 3.18096661567688),
#  ('BAR-TAILED GODWIT', 0.49350704566309916, 3.269768476486206),
#  ('BARN OWL', 0.6067519327920439, 3.595832109451294),
#  ('BARN SWALLOW', 0.501976353781032, 3.6286988258361816),
#  ('BARRED PUFFBIRD', 0.6705303101160031, 3.277132987976074),
#  ('HORNBILL', 0.6250224837201551, 3.41941237449646),
#  ('HORNED GUAN', 0.13034587442748305, 3.509385824203491),
#  ('HORNED LARK', 0.7246873399553035, 3.5179102420806885),
#  ('HORNED SUNGEM', 0.6811272134535923, 3.417163848876953),
#  ('HOUSE FINCH', 0.8189847353943692, 3.673490047454834),
#  ('HOUSE SPARROW', 0.3464470047795827, 4.061122417449951),
#  ('HYACINTH MACAW', 0.8904034270363356, 4.19157338142395),
#  ('IMPERIAL SHAQ', 0.12396502500573638, 3.8044886589050293),
#  ('INCA TERN', 0.422752605993533, 3.822420120239258),
#  ('INDIAN BUSTARD', 0.8894363654076352, 3.5367817878723145),
#  ('INDIAN PITTA', 0.28698997509719465, 3.1845672130584717),
#  ('INDIAN ROLLER', 0.17857400841147122, 3.521437406539917),
#  ('INDIGO BUNTING', 0.9219792678976353, 3.332951307296753),
#  ('IWI', 0.8893908270823253, 3.2828757762908936),
#  ('JABIRU', 0.584791411157851, 3.52059268951416),
#  ('JAVA SPARROW', 0.5592876685943916, 3.3388514518737793),
#  ('KAGU', 0.2329602755450505, 3.86824893951416),
#  ('KAKAPO', 0.8225281027359226, 3.6208999156951904),
#  ('KILLDEAR', 0.6252621914151587, 3.5063698291778564),
#  ('KING VULTURE', 0.6893845945892515, 3.4961698055267334),
#  ('KIWI', 0.7293928052694824, 3.216170072555542),
#  ('KOOKABURRA', 0.25827571518472076, 3.195307731628418),
#  ('LARK BUNTING', 0.5375745022972622, 3.5026936531066895),
#  ('LAZULI BUNTING', 0.36805956319547767, 3.4610533714294434),
#  ('LILAC ROLLER', 0.01672856592692555, 3.2577736377716064),
#  ('LONG-EARED OWL', 0.7067791470705932, 3.63509464263916),
#  ('MAGPIE GOOSE', 0.7009614019755277, 3.4198970794677734),
#  ('MALABAR HORNBILL', 0.6884779900703285, 3.5370092391967773),
#  ('MALACHITE KINGFISHER', 0.40087417670989994, 3.568000316619873),
#  ('MALAGASY WHITE EYE', 0.3491766550651972, 3.902585506439209),
#  ('MALEO', 0.1369453441917119, 3.250450611114502),
#  ('MALLARD DUCK', 0.5919635049694332, 3.46942400932312),
#  ('MANDRIN DUCK', 0.9592188633136637, 3.4903526306152344),
#  ('MANGROVE CUCKOO', 0.08297893366433202, 3.409095048904419),
#  ('MARABOU STORK', 0.725567957697961, 3.527189254760742),
#  ('MASKED BOOBY', 0.4482427964204924, 3.402289628982544),
#  ('MASKED LAPWING', 0.5315856967511778, 3.196052074432373),
#  ('MIKADO  PHEASANT', 0.03747906850440551, 3.5148215293884277),
#  ('MOURNING DOVE', 0.11046139334633023, 3.2757742404937744),
#  ('MYNA', 0.8213577053985572, 3.646543502807617),
#  ('NICOBAR PIGEON', 0.5812933496532028, 3.184337854385376),
#  ('NOISY FRIARBIRD', 0.2546642688746643, 3.3356821537017822),
#  ('NORTHERN CARDINAL', 0.23231344299187828, 3.4724345207214355),
#  ('NORTHERN FLICKER', 0.7551990252488177, 3.3564352989196777),
#  ('NORTHERN FULMAR', 0.7665528120435958, 3.2669687271118164),
#  ('NORTHERN GANNET', 0.7023995338158605, 3.350710391998291),
#  ('SWINHOES PHEASANT', 0.2672017920057701, 3.239265203475952),
#  ('TAIWAN MAGPIE', 0.418431989870872, 3.4958720207214355),
#  ('TAKAHE', 0.5619852276859749, 3.679201602935791),
#  ('TASMANIAN HEN', 0.834520126166356, 3.5140202045440674),
#  ('TEAL DUCK', 0.700503449963083, 3.336787700653076),
#  ('TIT MOUSE', 0.6898453337186324, 3.3521783351898193),
#  ('TOUCHAN', 0.9286591572644961, 3.4765820503234863),
#  ('TOWNSENDS WARBLER', 0.5456093028355262, 3.229783773422241),
#  ('TREE SWALLOW', 0.4714899549386335, 3.410813093185425),
#  ('TROPICAL KINGBIRD', 0.20233800988702247, 3.4752278327941895),
#  ('TRUMPTER SWAN', 0.5353396512303786, 3.6477768421173096),
#  ('TURKEY VULTURE', 0.09420717836965302, 3.5082974433898926),
#  ('TURQUOISE MOTMOT', 0.7864409899110183, 3.451812267303467),
#  ('UMBRELLA BIRD', 0.5892032798139616, 3.6584312915802),
#  ('VARIED THRUSH', 0.5039575428777446, 3.5613043308258057),
#  ('VENEZUELIAN TROUPIAL', 0.539013194351044, 3.75368332862854),
#  ('VERMILION FLYCATHER', 0.4954768251460395, 3.2241032123565674),
#  ('VICTORIA CROWNED PIGEON', 0.32482636666604864, 3.1683287620544434),
#  ('VIOLET GREEN SWALLOW', 0.24260864926056228, 3.4218533039093018),
#  ('VULTURINE GUINEAFOWL', 0.2804759481142057, 3.613374710083008),
#  ('WALL CREAPER', 0.295698137564478, 3.398251533508301),
#  ('WATTLED CURASSOW', 0.7435020825636118, 3.4009087085723877),
#  ('WHIMBREL', 0.5348879619929411, 3.886003017425537),
#  ('WHITE BROWED CRAKE', 0.601981953998501, 3.5220043659210205),
#  ('WHITE CHEEKED TURACO', 0.45838034073025175, 3.380317449569702),
#  ('WHITE NECKED RAVEN', 0.7884070399924126, 3.724416732788086),
#  ('WHITE TAILED TROPIC', 0.5661784902602879, 3.3603665828704834),
#  ('WHITE THROATED BEE EATER', 0.3308136635257484, 3.9627509117126465),
#  ('WILD TURKEY', 0.6009784235243619, 3.862576723098755),
#  ('WILSONS BIRD OF PARADISE', 0.8765275763532502, 3.489628791809082),
#  ('WOOD DUCK', 0.6277301192642377, 3.710315704345703),
#  ('YELLOW BELLIED FLOWERPECKER', 0.2263550436932313, 3.38753080368042),
#  ('YELLOW CACIQUE', 0.4908743900030685, 3.3898282051086426),
#  ('YELLOW HEADED BLACKBIRD', 0.5744031640040903, 3.3276267051696777)]

# %%
ap_at_n = np.array([ap[1] for ap in aps])
query_time = np.array(([ap[2] for ap in aps]))

# %%
mAP_at_n = np.mean(ap_at_n, axis=0)
avg_query_time = np.mean(query_time, axis=0)
print("mAP:", mAP_at_n)
print("avg. query time: ", avg_query_time)
# Out:
# mAP: 0.5682935157566553
# avg. query time:  3.4600314419086162

# %%
save_results('/content/drive/MyDrive/CV_Birds/performance/fine_tuning/index/FT_pert-forest_512_10rnd_cosine', 'FT_pert-forest_512_10rnd_cosine_results', aps)

# %%
# !mv /content/tree* /content/drive/MyDrive/CV_Birds/performance/fine_tuning/index/FT_pert-forest_512_10rnd_cosine/pert_forest_structure/

# %%
# !mv /content/pert* /content/drive/MyDrive/CV_Birds/performance/fine_tuning/index/FT_pert-forest_512_10rnd_cosine/pert_forest_structure/
