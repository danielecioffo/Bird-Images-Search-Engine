# %% [markdown]
# # AutoEncoder

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, losses
from tensorflow.keras.models import Sequential
from keras.models import Model
import matplotlib.pyplot as plt
from sklearn import metrics
import pandas as pd
from tensorflow.keras import optimizers
import os
import shutil

# %% [markdown]
# ## Connect to Drive

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Set parameters

# %%
FEATURES_FOLDER = '/content/drive/My Drive/CV_Birds/features'
LOCAL_MODELS_FOLDER = "/content/models"
if not os.path.exists(LOCAL_MODELS_FOLDER):
  os.makedirs(LOCAL_MODELS_FOLDER)
GLOBAL_MODELS_FOLDER = "/content/drive/My Drive/CV_Birds/models/AutoEncoder"

BATCH_SIZE = 256

# %%
callbacks_list = [
    keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=6,
        restore_best_weights=True,
    ),
    keras.callbacks.ModelCheckpoint(
        filepath='autoencoder.keras',
        monitor='val_loss',
        save_best_only=True,
    )
]

# %% [markdown]
# For Finetuning:

# %%
training_features = np.load(FEATURES_FOLDER + '/training/ResNet152v2/OneDense512_Dropout_fine_tuning.npy')

# %%
feature_dimension = training_features.shape[1]
feature_dimension
# Out:
# 512

# %%
validation_features = np.load(FEATURES_FOLDER + '/validation/ResNet152v2/OneDense512_Dropout_fine_tuning.npy')
test_features = np.load(FEATURES_FOLDER + '/test/ResNet152v2/OneDense512_Dropout_fine_tuning.npy')

# %%
distractor_features = np.load(FEATURES_FOLDER + '/distractor/ResNet152v2/OneDense512_Dropout_fine_tuning.npy')

# %% [markdown]
# For feature extraction:

# %%
training_features = np.load(FEATURES_FOLDER + '/training/ResNet152v2/OneDense512_Dropout_feature_extraction.npy')
validation_features = np.load(FEATURES_FOLDER + '/validation/ResNet152v2/OneDense512_Dropout_feature_extraction.npy')
test_features = np.load(FEATURES_FOLDER + '/test/ResNet152v2/OneDense512_Dropout_feature_extraction.npy')
distractor_features = np.load(FEATURES_FOLDER + '/distractor/ResNet152v2/OneDense512_Dropout_feature_extraction.npy')

# %% [markdown]
# # AutoEncoder Class

# %%
class AutoEncoder:
  def __init__(self, train_features, val_features, latent_dim, pace):
    self.train_features = train_features
    self.val_features = val_features
    self.encoder_final_layer = 'Encoder' + str(latent_dim)

    dim = feature_dimension = train_features.shape[1]
    input = keras.Input(shape=(feature_dimension,))
    # Enconder layers
    dim -= pace
    name = 'Encoder' + str(dim)
    x = keras.layers.Dense(dim, activation='relu', name=name)(input)
    while dim != latent_dim:
      dim -= pace
      name = 'Encoder' + str(dim)
      x = keras.layers.Dense(dim, activation='relu', name=name)(x)
    
    # Decoder Layers
    while dim != feature_dimension - pace:
      dim += pace
      name = 'Decoder' + str(dim)
      x = keras.layers.Dense(dim, activation='relu', name=name)(x)
    outputs = keras.layers.Dense(feature_dimension)(x)
    self.model = keras.Model(inputs=input, outputs=outputs)

  def summary(self):
    self.model.summary()

  def compile(self, loss='mean_squared_error', optimizer='sgd'):
    self.model.compile(loss=loss,
                       optimizer=optimizer,
                       metrics=[tf.keras.metrics.CosineSimilarity(axis=1)])
  
  def fit(self, callbacks, epochs=50, patience=5, batch_size=BATCH_SIZE):
    self.history = self.model.fit(self.train_features,
                                  self.train_features,
                                  validation_data=(self.val_features, self.val_features),
                                  callbacks=callbacks,
                                  shuffle=True,
                                  batch_size=batch_size,
                                  epochs=epochs)

  def evaluate(self, test_features):
    test_loss, test_acc = self.model.evaluate((test_features, test_features))
    print(f"Test accuracy: {test_acc:.3f}")

  def predict_features_encoder(self, features, path_name):
    encoder = keras.Model(self.model.input, outputs=self.model.get_layer(self.encoder_final_layer).output)
    features = encoder.predict(features)
    print(features.shape)
    print(features)
    np.save(FEATURES_FOLDER + path_name, features)

  def plot_model(self, model_name):
    keras.utils.plot_model(self.model, model_name, show_shapes=True)

  def plot_loss(self):
      loss = self.history.history['loss']
      val_loss = self.history.history['val_loss']
      plt.plot(range(1, len(loss) + 1), loss, 'r', label='Training Loss')
      plt.plot(range(1, len(loss) + 1), val_loss, 'g', label='Validation Loss')
      plt.title('Training and Validation Loss')
      plt.xlabel('Epochs')
      plt.ylabel('Loss')
      plt.legend()
      plt.plot()

# %% [markdown]
# # ResNet 152 512 to 256 features FineTuning

# %%
autoencoder = AutoEncoder(training_features, validation_features, 256, 64)
autoencoder.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 512)]             0
#
#  Encoder448 (Dense)          (None, 448)               229824
#
#  Encoder384 (Dense)          (None, 384)               172416
#
#  Encoder320 (Dense)          (None, 320)               123200
#
#  Encoder256 (Dense)          (None, 256)               82176
#
#  Decoder320 (Dense)          (None, 320)               82240
#
#  Decoder384 (Dense)          (None, 384)               123264
#
#  Decoder448 (Dense)          (None, 448)               172480
#
#  dense_4 (Dense)             (None, 512)               229888
#
# =================================================================
# Total params: 1,215,488
# Trainable params: 1,215,488
# Non-trainable params: 0
# _________________________________________________________________

# %%
autoencoder.plot_model('autoencoder.png')

# %%
autoencoder.compile()
autoencoder.fit(callbacks_list, epochs=800)
# Out:
# Epoch 1/800
# 185/185 [==============================] - 2s 8ms/step - loss: 0.4580 - cosine_similarity: 0.8981 - val_loss: 0.4299 - val_cosine_similarity: 0.9035
# Epoch 2/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4566 - cosine_similarity: 0.8984 - val_loss: 0.4323 - val_cosine_similarity: 0.9029
# Epoch 3/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4565 - cosine_similarity: 0.8985 - val_loss: 0.4301 - val_cosine_similarity: 0.9034
# Epoch 4/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4561 - cosine_similarity: 0.8986 - val_loss: 0.4279 - val_cosine_similarity: 0.9040
# Epoch 5/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4552 - cosine_similarity: 0.8988 - val_loss: 0.4331 - val_cosine_similarity: 0.9028
# Epoch 6/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4551 - cosine_similarity: 0.8988 - val_loss: 0.4291 - val_cosine_similarity: 0.9037
# Epoch 7/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4549 - cosine_similarity: 0.8988 - val_loss: 0.4260 - val_cosine_similarity: 0.9044
# Epoch 8/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4541 - cosine_similarity: 0.8990 - val_loss: 0.4303 - val_cosine_similarity: 0.9034
# Epoch 9/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4538 - cosine_similarity: 0.8991 - val_loss: 0.4284 - val_cosine_similarity: 0.9038
# Epoch 10/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4534 - cosine_similarity: 0.8992 - val_loss: 0.4247 - val_cosine_similarity: 0.9047
# Epoch 11/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4530 - cosine_similarity: 0.8993 - val_loss: 0.4264 - val_cosine_similarity: 0.9043
# Epoch 12/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4522 - cosine_similarity: 0.8995 - val_loss: 0.4267 - val_cosine_similarity: 0.9042
# Epoch 13/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4519 - cosine_similarity: 0.8995 - val_loss: 0.4268 - val_cosine_similarity: 0.9042
# Epoch 14/800
# 185/185 [==============================] - 1s 8ms/step - loss: 0.4515 - cosine_similarity: 0.8996 - val_loss: 0.4246 - val_cosine_similarity: 0.9048
# Epoch 15/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4513 - cosine_similarity: 0.8997 - val_loss: 0.4209 - val_cosine_similarity: 0.9056
# Epoch 16/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4504 - cosine_similarity: 0.8999 - val_loss: 0.4249 - val_cosine_similarity: 0.9047
# Epoch 17/800
# 185/185 [==============================] - 1s 8ms/step - loss: 0.4502 - cosine_similarity: 0.9000 - val_loss: 0.4238 - val_cosine_similarity: 0.9049
# Epoch 18/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4500 - cosine_similarity: 0.9000 - val_loss: 0.4219 - val_cosine_similarity: 0.9054
# Epoch 19/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4494 - cosine_similarity: 0.9001 - val_loss: 0.4222 - val_cosine_similarity: 0.9053
# Epoch 20/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4493 - cosine_similarity: 0.9001 - val_loss: 0.4205 - val_cosine_similarity: 0.9057
# Epoch 21/800
# 185/185 [==============================] - 1s 8ms/step - loss: 0.4483 - cosine_similarity: 0.9004 - val_loss: 0.4259 - val_cosine_similarity: 0.9045
# Epoch 22/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4477 - cosine_similarity: 0.9005 - val_loss: 0.4210 - val_cosine_similarity: 0.9056
# Epoch 23/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4478 - cosine_similarity: 0.9005 - val_loss: 0.4247 - val_cosine_similarity: 0.9047
# Epoch 24/800
# 185/185 [==============================] - 1s 8ms/step - loss: 0.4472 - cosine_similarity: 0.9007 - val_loss: 0.4203 - val_cosine_similarity: 0.9058
# Epoch 25/800
# 185/185 [==============================] - 1s 8ms/step - loss: 0.4472 - cosine_similarity: 0.9007 - val_loss: 0.4186 - val_cosine_similarity: 0.9062
# Epoch 26/800
# 185/185 [==============================] - 1s 8ms/step - loss: 0.4460 - cosine_similarity: 0.9009 - val_loss: 0.4181 - val_cosine_similarity: 0.9063
# Epoch 27/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4463 - cosine_similarity: 0.9009 - val_loss: 0.4216 - val_cosine_similarity: 0.9055
# Epoch 28/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4453 - cosine_similarity: 0.9011 - val_loss: 0.4184 - val_cosine_similarity: 0.9062
# Epoch 29/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4454 - cosine_similarity: 0.9011 - val_loss: 0.4203 - val_cosine_similarity: 0.9058
# Epoch 30/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4444 - cosine_similarity: 0.9013 - val_loss: 0.4227 - val_cosine_similarity: 0.9052
# Epoch 31/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4443 - cosine_similarity: 0.9013 - val_loss: 0.4224 - val_cosine_similarity: 0.9053
# Epoch 32/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4440 - cosine_similarity: 0.9014 - val_loss: 0.4185 - val_cosine_similarity: 0.9062

# %%
autoencoder.predict_features_encoder(training_features, '/training/AutoEncoder/512to256withPace64.npy')

# %%
autoencoder.predict_features_encoder(test_features, '/test/AutoEncoder/512to256withPace64.npy')

# %%
encoder = keras.Model(autoencoder.model.input, outputs=autoencoder.model.get_layer(autoencoder.encoder_final_layer).output)
features = encoder.predict(training_features)
print(features.shape)
print(features)
# Out:
# (47332, 256)
# [[ 9.195868   0.         0.        ...  4.9020514  7.052516   7.9435887]
#  [ 5.6641865  0.         0.        ...  4.8134475  8.054794  11.099172 ]
#  [ 3.6737359  0.         0.        ...  4.0150657  5.6983767  6.2199116]
#  ...
#  [ 5.750561   0.         0.        ...  5.7983074  8.606042   4.752095 ]
#  [ 5.8153877  0.         0.        ...  6.437734   9.22006    5.7890897]
#  [ 6.7102695  0.         0.        ...  5.274567   9.734262   3.4280245]]

# %%
np.save(FEATURES_FOLDER + '/training/AutoEncoder/512to256withPace64.npy', features)

# %%
features = encoder.predict(test_features)
print(features.shape)
print(features)
np.save(FEATURES_FOLDER + '/test/AutoEncoder/512to256withPace64.npy', features)
# Out:
# (1625, 256)
# [[ 4.312674   0.         0.        ...  6.7134914  4.238811   7.0304623]
#  [ 3.7251554  0.         0.        ...  4.957602   2.7158318  7.8004165]
#  [ 7.5487733  0.         0.        ...  9.545107   9.403517  11.842505 ]
#  ...
#  [ 6.1560497  0.         0.        ...  4.4695544  9.040167   4.426116 ]
#  [ 1.931897   0.         0.        ...  6.401012   9.4310665  3.4554417]
#  [ 7.1203866  0.         0.        ...  3.9933767 10.865172   6.2109866]]

# %%
features = encoder.predict(distractor_features)
print(features.shape)
print(features)
np.save(FEATURES_FOLDER + '/distractor/AutoEncoder/512to256withPace64.npy', features)
# Out:
# (25000, 256)
# [[ 2.4274487   0.          0.         ...  2.806142    2.5323086
#    6.6855717 ]
#  [ 5.010743    0.          0.         ...  4.1745405   3.1924844
#    4.3320932 ]
#  [ 0.03499752  0.          0.         ...  6.329656    5.6457787
#    2.8367631 ]
#  ...
#  [ 3.4716578   0.          0.         ...  5.598138    4.1397676
#    5.058101  ]
#  [ 6.2002625   0.          0.         ...  2.197337    4.8735094
#    4.8600874 ]
#  [ 4.163387    0.          0.         ...  0.         12.308101
#    7.404747  ]]

# %%
! cp autoencoder.keras /content/drive/MyDrive/CV_Birds/models/AutoEncoder/

# %% [markdown]
# # ResNet152v2 512 to 128 Finetuning

# %%
autoencoder = AutoEncoder(training_features, validation_features, 128, 64)
autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 512)]             0
#
#  Encoder448 (Dense)          (None, 448)               229824
#
#  Encoder384 (Dense)          (None, 384)               172416
#
#  Encoder320 (Dense)          (None, 320)               123200
#
#  Encoder256 (Dense)          (None, 256)               82176
#
#  Encoder192 (Dense)          (None, 192)               49344
#
#  Encoder128 (Dense)          (None, 128)               24704
#
#  Decoder192 (Dense)          (None, 192)               24768
#
#  Decoder256 (Dense)          (None, 256)               49408
#
#  Decoder320 (Dense)          (None, 320)               82240
#
#  Decoder384 (Dense)          (None, 384)               123264
#
#  Decoder448 (Dense)          (None, 448)               172480
#
#  dense (Dense)               (None, 512)               229888
#
# =================================================================
# Total params: 1,363,712
# Trainable params: 1,363,712
# Non-trainable params: 0
# _________________________________________________________________

# %%
autoencoder.plot_model('autoencoder.png')

# %%
autoencoder.compile()
autoencoder.fit(callbacks_list, epochs=800)
# Out:
# Epoch 1/800
# 185/185 [==============================] - 3s 10ms/step - loss: 0.5476 - cosine_similarity: 0.8767 - val_loss: 0.5153 - val_cosine_similarity: 0.8830
# Epoch 2/800
# 185/185 [==============================] - 2s 9ms/step - loss: 0.5472 - cosine_similarity: 0.8768 - val_loss: 0.5133 - val_cosine_similarity: 0.8835
# Epoch 3/800
# 185/185 [==============================] - 2s 9ms/step - loss: 0.5470 - cosine_similarity: 0.8769 - val_loss: 0.5193 - val_cosine_similarity: 0.8821
# Epoch 4/800
# 185/185 [==============================] - 2s 9ms/step - loss: 0.5466 - cosine_similarity: 0.8769 - val_loss: 0.5167 - val_cosine_similarity: 0.8827
# Epoch 5/800
# 185/185 [==============================] - 2s 9ms/step - loss: 0.5458 - cosine_similarity: 0.8772 - val_loss: 0.5213 - val_cosine_similarity: 0.8816
# Epoch 6/800
# 185/185 [==============================] - 2s 9ms/step - loss: 0.5458 - cosine_similarity: 0.8771 - val_loss: 0.5130 - val_cosine_similarity: 0.8835
# Epoch 7/800
# 185/185 [==============================] - 2s 9ms/step - loss: 0.5458 - cosine_similarity: 0.8771 - val_loss: 0.5087 - val_cosine_similarity: 0.8846
# Epoch 8/800
# 185/185 [==============================] - 2s 9ms/step - loss: 0.5447 - cosine_similarity: 0.8774 - val_loss: 0.5201 - val_cosine_similarity: 0.8818
# Epoch 9/800
# 185/185 [==============================] - 2s 9ms/step - loss: 0.5442 - cosine_similarity: 0.8775 - val_loss: 0.5101 - val_cosine_similarity: 0.8843
# Epoch 10/800
# 185/185 [==============================] - 2s 9ms/step - loss: 0.5438 - cosine_similarity: 0.8776 - val_loss: 0.5093 - val_cosine_similarity: 0.8845
# Epoch 11/800
# 185/185 [==============================] - 2s 8ms/step - loss: 0.5439 - cosine_similarity: 0.8776 - val_loss: 0.5146 - val_cosine_similarity: 0.8832
# Epoch 12/800
# 185/185 [==============================] - 2s 9ms/step - loss: 0.5430 - cosine_similarity: 0.8778 - val_loss: 0.5120 - val_cosine_similarity: 0.8838
# Epoch 13/800
# 185/185 [==============================] - 2s 9ms/step - loss: 0.5428 - cosine_similarity: 0.8779 - val_loss: 0.5109 - val_cosine_similarity: 0.8841

# %%
autoencoder.predict_features_encoder(training_features, '/training/AutoEncoder/512to128withPace64.npy')
# Out:
# (47332, 128)
# [[ 9.49873    0.         3.6662238 ...  3.4222531  9.934501   5.38992  ]
#  [ 8.82283    0.         7.693001  ...  1.2568046  7.6079645  3.764613 ]
#  [ 8.100039   0.         3.3028147 ...  2.8523085  8.390544   5.5698853]
#  ...
#  [ 2.8285484  0.         9.807598  ...  8.710649   8.182634   6.107458 ]
#  [ 5.7676873  0.         9.587541  ... 11.275144   8.428513   8.149769 ]
#  [ 2.8090334  0.         7.974751  ...  8.699295   5.222485   9.901351 ]]

# %%
autoencoder.predict_features_encoder(test_features, '/test/AutoEncoder/512to128withPace64.npy')
# Out:
# (1625, 128)
# [[ 6.179785   0.         5.780048  ...  2.2905853  9.690669   6.5708756]
#  [ 5.78261    0.         6.6455693 ...  2.225507   9.475985   5.7978067]
#  [18.115143   0.         7.341868  ...  3.4316201 16.21714   11.6665745]
#  ...
#  [ 3.4109862  0.         8.680737  ...  7.7216544  7.7940617  6.8752756]
#  [ 7.2186117  0.         3.9433327 ...  9.629163   7.211761  11.431813 ]
#  [ 4.1829176  0.         6.233928  ... 10.220056   9.355988  10.461566 ]]

# %%
autoencoder.predict_features_encoder(distractor_features, '/distractor/AutoEncoder/512to128withPace64.npy')
# Out:
# (25000, 128)
# [[ 5.8749156  0.         6.843479  ...  3.342217   7.203499   4.9853525]
#  [ 4.136994   0.         5.7078066 ...  3.9104564  6.2266994  4.3197236]
#  [ 8.090802   0.        10.103582  ...  4.478878  10.942012   3.4928403]
#  ...
#  [ 4.252955   0.         5.00579   ...  2.8811474  6.818927   2.8188703]
#  [ 5.1878843  0.         8.587541  ...  6.5327635 10.593627   0.5781613]
#  [ 9.551695   0.        30.397394  ...  9.791951  14.976327   3.795782 ]]

# %%
! cp autoencoder128.keras /content/drive/MyDrive/CV_Birds/models/AutoEncoder/

# %% [markdown]
# # ResNet152v2 512 to 256 Feature Extraction

# %%
autoencoder = AutoEncoder(training_features, validation_features, 256, 64)
autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 512)]             0
#
#  Encoder448 (Dense)          (None, 448)               229824
#
#  Encoder384 (Dense)          (None, 384)               172416
#
#  Encoder320 (Dense)          (None, 320)               123200
#
#  Encoder256 (Dense)          (None, 256)               82176
#
#  Decoder320 (Dense)          (None, 320)               82240
#
#  Decoder384 (Dense)          (None, 384)               123264
#
#  Decoder448 (Dense)          (None, 448)               172480
#
#  dense (Dense)               (None, 512)               229888
#
# =================================================================
# Total params: 1,215,488
# Trainable params: 1,215,488
# Non-trainable params: 0
# _________________________________________________________________

# %%
autoencoder.plot_model('autoencoder.png')

# %%
autoencoder.compile()
autoencoder.fit(callbacks_list, epochs=800)
# Out:
# Epoch 1/800
# 185/185 [==============================] - 2s 8ms/step - loss: 0.4754 - cosine_similarity: 0.8978 - val_loss: 0.4617 - val_cosine_similarity: 0.9031
# Epoch 2/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4747 - cosine_similarity: 0.8979 - val_loss: 0.4579 - val_cosine_similarity: 0.9039
# Epoch 3/800
# 185/185 [==============================] - 2s 9ms/step - loss: 0.4741 - cosine_similarity: 0.8981 - val_loss: 0.4513 - val_cosine_similarity: 0.9054
# Epoch 4/800
# 185/185 [==============================] - 1s 8ms/step - loss: 0.4739 - cosine_similarity: 0.8981 - val_loss: 0.4555 - val_cosine_similarity: 0.9044
# Epoch 5/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4740 - cosine_similarity: 0.8981 - val_loss: 0.4592 - val_cosine_similarity: 0.9037
# Epoch 6/800
# 185/185 [==============================] - 1s 8ms/step - loss: 0.4721 - cosine_similarity: 0.8985 - val_loss: 0.4513 - val_cosine_similarity: 0.9054
# Epoch 7/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4715 - cosine_similarity: 0.8987 - val_loss: 0.4620 - val_cosine_similarity: 0.9030
# Epoch 8/800
# 185/185 [==============================] - 1s 8ms/step - loss: 0.4719 - cosine_similarity: 0.8986 - val_loss: 0.4507 - val_cosine_similarity: 0.9055
# Epoch 9/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4708 - cosine_similarity: 0.8988 - val_loss: 0.4534 - val_cosine_similarity: 0.9049
# Epoch 10/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4700 - cosine_similarity: 0.8990 - val_loss: 0.4514 - val_cosine_similarity: 0.9053
# Epoch 11/800
# 185/185 [==============================] - 1s 8ms/step - loss: 0.4694 - cosine_similarity: 0.8991 - val_loss: 0.4503 - val_cosine_similarity: 0.9056
# Epoch 12/800
# 185/185 [==============================] - 1s 8ms/step - loss: 0.4688 - cosine_similarity: 0.8993 - val_loss: 0.4470 - val_cosine_similarity: 0.9063
# Epoch 13/800
# 185/185 [==============================] - 1s 8ms/step - loss: 0.4684 - cosine_similarity: 0.8994 - val_loss: 0.4483 - val_cosine_similarity: 0.9060
# Epoch 14/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4678 - cosine_similarity: 0.8995 - val_loss: 0.4495 - val_cosine_similarity: 0.9057
# Epoch 15/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4671 - cosine_similarity: 0.8996 - val_loss: 0.4457 - val_cosine_similarity: 0.9066
# Epoch 16/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4671 - cosine_similarity: 0.8996 - val_loss: 0.4470 - val_cosine_similarity: 0.9063
# Epoch 17/800
# 185/185 [==============================] - 1s 8ms/step - loss: 0.4653 - cosine_similarity: 0.9000 - val_loss: 0.4453 - val_cosine_similarity: 0.9067
# Epoch 18/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4656 - cosine_similarity: 0.9000 - val_loss: 0.4457 - val_cosine_similarity: 0.9066
# Epoch 19/800
# 185/185 [==============================] - 1s 8ms/step - loss: 0.4648 - cosine_similarity: 0.9001 - val_loss: 0.4455 - val_cosine_similarity: 0.9066
# Epoch 20/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4645 - cosine_similarity: 0.9002 - val_loss: 0.4464 - val_cosine_similarity: 0.9064
# Epoch 21/800
# 185/185 [==============================] - 1s 8ms/step - loss: 0.4640 - cosine_similarity: 0.9003 - val_loss: 0.4437 - val_cosine_similarity: 0.9070
# Epoch 22/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4635 - cosine_similarity: 0.9004 - val_loss: 0.4535 - val_cosine_similarity: 0.9048
# Epoch 23/800
# 185/185 [==============================] - 1s 8ms/step - loss: 0.4622 - cosine_similarity: 0.9007 - val_loss: 0.4411 - val_cosine_similarity: 0.9076
# Epoch 24/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4624 - cosine_similarity: 0.9007 - val_loss: 0.4493 - val_cosine_similarity: 0.9058
# Epoch 25/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4621 - cosine_similarity: 0.9008 - val_loss: 0.4487 - val_cosine_similarity: 0.9059
# Epoch 26/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4611 - cosine_similarity: 0.9010 - val_loss: 0.4397 - val_cosine_similarity: 0.9079
# Epoch 27/800
# 185/185 [==============================] - 1s 8ms/step - loss: 0.4600 - cosine_similarity: 0.9012 - val_loss: 0.4393 - val_cosine_similarity: 0.9079
# Epoch 28/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4601 - cosine_similarity: 0.9012 - val_loss: 0.4434 - val_cosine_similarity: 0.9071
# Epoch 29/800
# 185/185 [==============================] - 1s 8ms/step - loss: 0.4594 - cosine_similarity: 0.9013 - val_loss: 0.4410 - val_cosine_similarity: 0.9076
# Epoch 30/800
# 185/185 [==============================] - 1s 8ms/step - loss: 0.4594 - cosine_similarity: 0.9013 - val_loss: 0.4391 - val_cosine_similarity: 0.9080
# Epoch 31/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4581 - cosine_similarity: 0.9016 - val_loss: 0.4418 - val_cosine_similarity: 0.9074
# Epoch 32/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4579 - cosine_similarity: 0.9017 - val_loss: 0.4405 - val_cosine_similarity: 0.9077
# Epoch 33/800
# 185/185 [==============================] - 1s 8ms/step - loss: 0.4579 - cosine_similarity: 0.9017 - val_loss: 0.4383 - val_cosine_similarity: 0.9081
# Epoch 34/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4563 - cosine_similarity: 0.9020 - val_loss: 0.4398 - val_cosine_similarity: 0.9078
# Epoch 35/800
# 185/185 [==============================] - 1s 8ms/step - loss: 0.4569 - cosine_similarity: 0.9019 - val_loss: 0.4360 - val_cosine_similarity: 0.9087
# Epoch 36/800
# 185/185 [==============================] - 1s 8ms/step - loss: 0.4551 - cosine_similarity: 0.9023 - val_loss: 0.4333 - val_cosine_similarity: 0.9092
# Epoch 37/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4552 - cosine_similarity: 0.9023 - val_loss: 0.4425 - val_cosine_similarity: 0.9072
# Epoch 38/800
# 185/185 [==============================] - 1s 8ms/step - loss: 0.4548 - cosine_similarity: 0.9024 - val_loss: 0.4370 - val_cosine_similarity: 0.9084
# Epoch 39/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4543 - cosine_similarity: 0.9025 - val_loss: 0.4360 - val_cosine_similarity: 0.9086
# Epoch 40/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4533 - cosine_similarity: 0.9027 - val_loss: 0.4355 - val_cosine_similarity: 0.9088
# Epoch 41/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4537 - cosine_similarity: 0.9026 - val_loss: 0.4337 - val_cosine_similarity: 0.9092
# Epoch 42/800
# 185/185 [==============================] - 1s 8ms/step - loss: 0.4523 - cosine_similarity: 0.9029 - val_loss: 0.4330 - val_cosine_similarity: 0.9093
# Epoch 43/800
# 185/185 [==============================] - 1s 8ms/step - loss: 0.4523 - cosine_similarity: 0.9029 - val_loss: 0.4310 - val_cosine_similarity: 0.9097
# Epoch 44/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4519 - cosine_similarity: 0.9030 - val_loss: 0.4386 - val_cosine_similarity: 0.9081
# Epoch 45/800
# 185/185 [==============================] - 1s 8ms/step - loss: 0.4510 - cosine_similarity: 0.9032 - val_loss: 0.4333 - val_cosine_similarity: 0.9092
# Epoch 46/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4506 - cosine_similarity: 0.9033 - val_loss: 0.4292 - val_cosine_similarity: 0.9101
# Epoch 47/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4504 - cosine_similarity: 0.9033 - val_loss: 0.4293 - val_cosine_similarity: 0.9101
# Epoch 48/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4498 - cosine_similarity: 0.9035 - val_loss: 0.4324 - val_cosine_similarity: 0.9094
# Epoch 49/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4495 - cosine_similarity: 0.9035 - val_loss: 0.4336 - val_cosine_similarity: 0.9092
# Epoch 50/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4481 - cosine_similarity: 0.9038 - val_loss: 0.4326 - val_cosine_similarity: 0.9094
# Epoch 51/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4482 - cosine_similarity: 0.9038 - val_loss: 0.4314 - val_cosine_similarity: 0.9096
# Epoch 52/800
# 185/185 [==============================] - 1s 8ms/step - loss: 0.4475 - cosine_similarity: 0.9040 - val_loss: 0.4286 - val_cosine_similarity: 0.9102
# Epoch 53/800
# 185/185 [==============================] - 1s 8ms/step - loss: 0.4469 - cosine_similarity: 0.9041 - val_loss: 0.4279 - val_cosine_similarity: 0.9104
# Epoch 54/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4467 - cosine_similarity: 0.9042 - val_loss: 0.4282 - val_cosine_similarity: 0.9104
# Epoch 55/800
# 185/185 [==============================] - 1s 8ms/step - loss: 0.4461 - cosine_similarity: 0.9043 - val_loss: 0.4287 - val_cosine_similarity: 0.9102
# Epoch 56/800
# 185/185 [==============================] - 1s 8ms/step - loss: 0.4464 - cosine_similarity: 0.9042 - val_loss: 0.4242 - val_cosine_similarity: 0.9112
# Epoch 57/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4451 - cosine_similarity: 0.9045 - val_loss: 0.4248 - val_cosine_similarity: 0.9111
# Epoch 58/800
# 185/185 [==============================] - 1s 8ms/step - loss: 0.4450 - cosine_similarity: 0.9045 - val_loss: 0.4231 - val_cosine_similarity: 0.9114
# Epoch 59/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4440 - cosine_similarity: 0.9047 - val_loss: 0.4247 - val_cosine_similarity: 0.9111
# Epoch 60/800
# 185/185 [==============================] - 1s 8ms/step - loss: 0.4440 - cosine_similarity: 0.9048 - val_loss: 0.4295 - val_cosine_similarity: 0.9100
# Epoch 61/800
# 185/185 [==============================] - 1s 8ms/step - loss: 0.4440 - cosine_similarity: 0.9047 - val_loss: 0.4227 - val_cosine_similarity: 0.9115
# Epoch 62/800
# 185/185 [==============================] - 1s 8ms/step - loss: 0.4421 - cosine_similarity: 0.9052 - val_loss: 0.4212 - val_cosine_similarity: 0.9118
# Epoch 63/800
# 185/185 [==============================] - 1s 8ms/step - loss: 0.4431 - cosine_similarity: 0.9050 - val_loss: 0.4240 - val_cosine_similarity: 0.9112
# Epoch 64/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4418 - cosine_similarity: 0.9053 - val_loss: 0.4261 - val_cosine_similarity: 0.9108
# Epoch 65/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4415 - cosine_similarity: 0.9053 - val_loss: 0.4225 - val_cosine_similarity: 0.9115
# Epoch 66/800
# 185/185 [==============================] - 1s 8ms/step - loss: 0.4414 - cosine_similarity: 0.9053 - val_loss: 0.4174 - val_cosine_similarity: 0.9127
# Epoch 67/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4403 - cosine_similarity: 0.9056 - val_loss: 0.4206 - val_cosine_similarity: 0.9120
# Epoch 68/800
# 185/185 [==============================] - 1s 8ms/step - loss: 0.4403 - cosine_similarity: 0.9056 - val_loss: 0.4184 - val_cosine_similarity: 0.9124
# Epoch 69/800
# 185/185 [==============================] - 1s 7ms/step - loss: 0.4399 - cosine_similarity: 0.9057 - val_loss: 0.4186 - val_cosine_similarity: 0.9124
# Epoch 70/800
# 185/185 [==============================] - 1s 8ms/step - loss: 0.4393 - cosine_similarity: 0.9058 - val_loss: 0.4200 - val_cosine_similarity: 0.9121
# Epoch 71/800
# 185/185 [==============================] - 1s 8ms/step - loss: 0.4394 - cosine_similarity: 0.9058 - val_loss: 0.4193 - val_cosine_similarity: 0.9122
# Epoch 72/800
# 185/185 [==============================] - 1s 8ms/step - loss: 0.4381 - cosine_similarity: 0.9061 - val_loss: 0.4198 - val_cosine_similarity: 0.9121

# %%
autoencoder.predict_features_encoder(training_features, '/training/AutoEncoder/512to256withPace64_feature_extraction.npy')
# Out:
# (47332, 256)
# [[ 0.         7.85741    4.8072505 ...  0.        11.526674  10.304251 ]
#  [ 0.         5.131463   7.307387  ...  0.        10.300343  13.863658 ]
#  [ 0.         4.4632373  4.5082455 ...  0.         8.203612   6.196382 ]
#  ...
#  [ 0.        10.703678   1.8268989 ...  0.         3.1073825  5.9998307]
#  [ 0.         9.101698   5.8591743 ...  0.         8.225212   7.0080075]
#  [ 0.         8.41263    4.068163  ...  0.         4.482814   7.8149524]]

# %%
autoencoder.predict_features_encoder(test_features, '/test/AutoEncoder/512to256withPace64_feature_extraction.npy')
# Out:
# (1625, 256)
# [[ 0.         4.8632526  7.103323  ...  0.         6.8853297  6.4178576]
#  [ 0.         6.0288143  4.880917  ...  0.         7.0359607  5.3576922]
#  [ 0.         6.29494    7.314261  ...  0.        13.789407  11.367596 ]
#  ...
#  [ 0.        10.634909   2.7248502 ...  0.         3.6018918  7.557374 ]
#  [ 0.         5.810537   3.629338  ...  0.         2.3764591  3.8160381]
#  [ 0.         6.1706696  3.2348762 ...  0.         4.1383724  4.807791 ]]

# %%
autoencoder.predict_features_encoder(distractor_features, '/distractor/AutoEncoder/512to256withPace64_feature_extraction.npy')
# Out:
# (25000, 256)
# [[ 0.          7.325205    4.155388   ...  0.          9.071452
#    8.184651  ]
#  [ 0.          7.768376    4.2125835  ...  0.          7.9366603
#   10.824646  ]
#  [ 0.02880119  7.7105      6.4099507  ...  0.          8.799576
#    5.110255  ]
#  ...
#  [ 0.          8.310111    3.156978   ...  0.          8.130999
#    6.8294177 ]
#  [ 0.          4.820765    4.145028   ...  0.          7.820896
#    3.5790474 ]
#  [ 0.         11.396017    7.3049135  ...  0.         13.513865
#   12.441708  ]]

# %%
! cp autoencoder256_feature_extraction.keras /content/drive/MyDrive/CV_Birds/models/AutoEncoder/

# %% [markdown]
# # ResNet152v2 512 to 128 Feature Extraction

# %%
autoencoder = AutoEncoder(training_features, validation_features, 128, 64)
autoencoder.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 512)]             0
#
#  Encoder448 (Dense)          (None, 448)               229824
#
#  Encoder384 (Dense)          (None, 384)               172416
#
#  Encoder320 (Dense)          (None, 320)               123200
#
#  Encoder256 (Dense)          (None, 256)               82176
#
#  Encoder192 (Dense)          (None, 192)               49344
#
#  Encoder128 (Dense)          (None, 128)               24704
#
#  Decoder192 (Dense)          (None, 192)               24768
#
#  Decoder256 (Dense)          (None, 256)               49408
#
#  Decoder320 (Dense)          (None, 320)               82240
#
#  Decoder384 (Dense)          (None, 384)               123264
#
#  Decoder448 (Dense)          (None, 448)               172480
#
#  dense_1 (Dense)             (None, 512)               229888
#
# =================================================================
# Total params: 1,363,712
# Trainable params: 1,363,712
# Non-trainable params: 0
# _________________________________________________________________

# %%
autoencoder.plot_model('autoencoder.png')

# %%
autoencoder.compile()
autoencoder.fit(callbacks_list, epochs=800)
# Out:
# Epoch 1/800
# 185/185 [==============================] - 3s 10ms/step - loss: 0.6413 - cosine_similarity: 0.8594 - val_loss: 0.6210 - val_cosine_similarity: 0.8674
# Epoch 2/800
# 185/185 [==============================] - 2s 9ms/step - loss: 0.6407 - cosine_similarity: 0.8596 - val_loss: 0.6122 - val_cosine_similarity: 0.8693
# Epoch 3/800
# 185/185 [==============================] - 2s 9ms/step - loss: 0.6401 - cosine_similarity: 0.8597 - val_loss: 0.6168 - val_cosine_similarity: 0.8683
# Epoch 4/800
# 185/185 [==============================] - 2s 9ms/step - loss: 0.6383 - cosine_similarity: 0.8601 - val_loss: 0.6176 - val_cosine_similarity: 0.8681
# Epoch 5/800
# 185/185 [==============================] - 2s 8ms/step - loss: 0.6378 - cosine_similarity: 0.8602 - val_loss: 0.6149 - val_cosine_similarity: 0.8687
# Epoch 6/800
# 185/185 [==============================] - 2s 8ms/step - loss: 0.6364 - cosine_similarity: 0.8605 - val_loss: 0.6127 - val_cosine_similarity: 0.8692
# Epoch 7/800
# 185/185 [==============================] - 2s 9ms/step - loss: 0.6355 - cosine_similarity: 0.8608 - val_loss: 0.6164 - val_cosine_similarity: 0.8684
# Epoch 8/800
# 185/185 [==============================] - 2s 9ms/step - loss: 0.6354 - cosine_similarity: 0.8608 - val_loss: 0.6154 - val_cosine_similarity: 0.8686

# %%
autoencoder.predict_features_encoder(training_features, '/training/AutoEncoder/512to128withPace64_feature_extraction.npy')
# Out:
# (47332, 128)
# [[ 0.         0.         0.        ...  8.075813  16.673262  13.597744 ]
#  [ 0.         0.         0.        ... 16.640043  15.179927  12.970896 ]
#  [ 0.         0.         0.        ...  9.167509   9.841227  10.882952 ]
#  ...
#  [ 0.         0.         0.        ...  8.19948    4.7598386 14.980965 ]
#  [ 0.         0.         0.        ...  7.0964785  7.913847  11.806072 ]
#  [ 0.         0.         0.        ...  7.9192142  5.543435  13.611256 ]]

# %%
autoencoder.predict_features_encoder(test_features, '/test/AutoEncoder/512to128withPace64_feature_extraction.npy')
# Out:
# (1625, 128)
# [[ 0.         0.         0.        ... 12.095595  10.663634  12.708031 ]
#  [ 0.         0.         0.        ... 10.724072  13.293723  10.43426  ]
#  [ 0.         0.         0.        ... 13.318824  15.602181  14.75976  ]
#  ...
#  [ 0.         0.         0.        ...  6.22002    7.3831186 13.982892 ]
#  [ 0.         0.         0.        ...  5.13063    4.323975  13.33562  ]
#  [ 0.         0.         0.        ...  5.5317206  5.7060337 15.30135  ]]

# %%
autoencoder.predict_features_encoder(distractor_features, '/distractor/AutoEncoder/512to128withPace64_feature_extraction.npy')
# Out:
# (25000, 128)
# [[ 0.         0.         0.        ...  9.859884  11.114941   8.086099 ]
#  [ 0.         0.         0.        ...  5.585647  14.122535   9.786284 ]
#  [ 0.         0.         0.        ...  5.7548776  5.637664   6.853354 ]
#  ...
#  [ 0.         0.         0.        ...  6.9875574  7.9005203  4.8430367]
#  [ 0.         0.         0.        ...  9.459765  10.160999   3.7016633]
#  [ 0.         0.         0.        ... 20.241228  16.594048   4.9529614]]

# %%
keras.models.save_model(autoencoder.model, '/content/drive/MyDrive/CV_Birds/models/AutoEncoder/autoencoder128_feature_extraction.keras')

# %%
! cp autoencoder128_feature_extraction.keras /content/drive/MyDrive/CV_Birds/models/AutoEncoder/
